# %% [markdown]
# This is a notebook explaining the mathematics of Linear and Logistic Regression. It is adapted from by [blog](http://ataspinar.com/2016/03/28/regression-logistic-regression-and-maximum-entropy). All of the code is available on [GitHub](https://github.com/taspinar/siml).
#
#
# <h1 style="text-align: center;"> 1. Regression Analysis</h1>
# Regression Analysis is the field of mathematics where the goal is to find a function which best [correlates](http://guessthecorrelation.com/) with a dataset. Let's say we have a dataset containing $ n $ datapoints;
#
# <p style="text-align: center;">$ X = ( x^{(1)}, x^{(2)}, .., x^{(n)} ) $. </p>
#
# For each of these (input) datapoints there is a corresponding (output) $ y^{(i)}$-value.
#
# Here, the $ x$-datapoints are called the [independent variables](https://en.wikipedia.org/wiki/Dependent_and_independent_variables) and $ y$ the dependent variable;
# the value of $ y^{(i)} $ depends on the value of $ x^{(i)} $, while the value of $ x^{(i)}$ may be freely chosen without any restriction imposed on it by any other variable.
#
# The goal of Regression analysis is to find a function $ f(X) $ which can best describe the correlation between $ X $ and $ Y $. In the field of Machine Learning, this function is called the hypothesis function and is denoted as $ h_{\theta}(x) $. If we can find such a function, we can say we have successfully built a Regression model.
#
# <br>
#
# <img src="img/correlation_function.png">
#
# If the input-data lives in a 2D-space, this boils down to finding a curve which fits through the data points. In the 3D case we have to find a plane and in higher dimensions a hyperplane.
#
# To give an example, let's say that we are trying to find a predictive model for the success of students in a course called Machine Learning. We have a dataset $ Y $ which contains the final grade of $ n $ students. Dataset $ X $ contains the values of the independent variables. Our initial assumption is that the final grade only depends on the studying time. The variable $ x^{(i)} $ therefore indicates how many hours student $ i $ has studied. The first thing we would do is visualize this data:
#
# <img src="img/regression_left2-350x288.png">
#
# If the results looks like the figure on the left, then we are out of luck. It looks like the points are distributed randomly and there is no correlation between $ Y$ and $ X$ at all. However, if it looks like the figure on the right, there is probably a strong correlation and we can start looking for the function which describes this correlation.
#
# &nbsp;
#
# This function could for example be:
# <p style="text-align: center;">$ h_{\theta}(X) =  \theta_0+ \theta_1 \cdot x $</p>
# <p style="text-align: left;">or</p>
# <p style="text-align: center;">$ h_{\theta}(X) = \theta_0 + \theta_1 \cdot x^2 $</p>
# where $ \theta $ are the dependent parameters of our model.
#
# <br><br><br>
#
# <h2> 1.2 Multivariate Regression</h2>
# <br>
# In evaluating the results from the previous section, we may find the results unsatisfying; the function does not correlate with the datapoints strongly enough. Our initial assumption is probably not complete. Taking only the studying time into account is not enough.
# The final grade does not only depend on the studying time, but also on how much the students have slept the night before the exam. Now the dataset contains an additional variable which represents the sleeping time.
#
# Our dataset is then given by $ X = ( (x_1^{(1)}, x_2^{(1)}), (x_1^{(2)}, x_2^{(2)}), .., (x_1^{(n)}, x_2^{(n)}) ) $. In this dataset $ x_1^{(i)} $ indicates how many hours student $ i $ has studied and $ x_2^{(i)} $ indicates how many hours he has slept.
#
# <img src="img/regression_multi.png">
#
# This is an example of [Multivariate Regression](https://en.wikipedia.org/wiki/Linear_regression#Simple_and_multiple_regression). The function has to include both variables. For example:
# <p style="text-align: center;">$ h_{\theta}(x) = \theta_0 + \theta_1 \cdot x_1 + \theta_2 \cdot x_2$</p>
# or
# <p style="text-align: center;">$ h_{\theta}(x) = \theta_0 + \theta_1 \cdot x_1 + \theta_2 \cdot x_2^3 $.</p>
#
#
# <h2> 1.3 Linear vs Non-Linear Regression</h2>
# <br>
# All of the above examples are examples of linear regression. We have seen that in some cases $ y^{(i)} $ depends on a linear form of $ x^{(i)} $, but it can also depend on some power of $ x^{(i)}$, or on the log or any other form of $ x^{(i)}$. However, in all cases its dependence on the parameters $\theta$ was linear.
#
# So, what makes linear regression linear is not that $ Y$ depends in a linear way on $ X $, but that it depends in a linear way on $ \theta$.
# $ Y $ needs to be [linear](http://www.investopedia.com/terms/l/linearrelationship.asp) with respect to the model-parameters $ \theta $. Mathematically speaking it needs to satisfy the [superposition principle](http://www.cut-the-knot.org/do_you_know/superposition.shtml).
#
# Examples of nonlinear regression would be:
# <p style="text-align: center;">$ h_{\theta}(x) = \theta_0 + x_1^{\theta_1} $</p>
# or
# <p style="text-align: center;">$ h_{\theta}(x) = \theta_0 + \theta_1 / x_1 $</p>
# &nbsp;
#
# The reason why the distinction is made between linear and nonlinear regression is that nonlinear regression problems are more difficult to solve and therefore more computational intensive algorithms are needed.
#
# Linear regression models can be written as a linear system of equations, which can be solved by finding the closed-form solution $ \theta = ( X^TX )^{-1}X^TY $ with Linear Algebra. See <a href="http://www.stat.purdue.edu/~jennings/stat514/stat512notes/topic3.pdf" target="_blank">these</a> statistics notes for more on solving linear models with linear algebra.
#
# As discussed before, such a closed-form solution can only be found for linear regression problems. However, even when the problem is linear in nature, we need to take into account that calculating the inverse of a $ n $ by $ n $ matrix has a time-complexity of $ O(n^3) $. This means that for large datasets ($ n \gt 10.000 $ ) finding the closed-form solution will take more time than solving it iteratively (gradient descent method) as is done for nonlinear problems. So solving it iteratively is usually preferred for larger datasets, even if it is a linear problem.
#
#
#
# <h2> 1.4 Gradient Descent</h2>
# <br>
# The Gradient Descent method is a general optimization technique in which we try to find the value of the parameters $ \theta $ with an iterative approach.
#
# First, we construct a <a href="https://en.wikipedia.org/wiki/Loss_function" target="_blank">cost function</a> (also known as loss function or error function) which gives the difference between the values of the hypothesis function $h_{\theta}(x)$ (the values you expect $ Y$ to have with the current values of $ \theta$ ) and the actual values of $ Y $. The better your estimation of $ \theta $ is, the better the values of $ h_{\theta}(x) $ will approach the values of $ Y$ and the smaller the cost function will be.
#
# Usually, the cost function is expressed as the squared error of the difference between these functions:
# <p style="text-align: center;">$ J(x) = \frac{1}{2n} \sum_i^n ( h_{\theta}(x^{(i)}) - y^{(i)} )^2 $</p>
# &nbsp;
#
# At each iteration we choose new values for the parameters $ \theta$, and move towards the 'true' values of these parameters, i.e. the values which make this cost function as small as possible. The direction in which we have to move is the negative gradient direction;
#
# <p style="text-align: center;"> $ \Delta\theta = - \alpha \frac{d}{d\theta} J(x) $.</p>
#
# The reason for this is that  a function's value decreases fastest if we move towards the direction of the negative gradient (the <a href="https://en.wikipedia.org/wiki/Directional_derivative" target="_blank">directional derivative</a> is maximal in the direction of the gradient).
#
# Taking all this into account, this is how gradient descent works:
# <ul>
# 	<li>Make an initial but intelligent guess for the values of the parameters $ \theta $.</li>
# 	<li>Keep iterating while the value of the cost function has not met your criteria:
# <ul>
# 	<li>With the current values of $ \theta $, calculate the gradient of the cost function J  ( $ \Delta \theta = - \alpha \frac{d}{d\theta} J(x)$ ).</li>
# 	<li>Update the values for the parameters $ \theta := \theta + \alpha \Delta \theta $</li>
# 	<li>Fill in these new values in the hypothesis function and calculate again the value of the cost function;</li>
# </ul>
# </li>
# </ul>
#
# Just as important as the initial guess of the parameters is the value you choose for the learning rate $ \alpha $. This learning rate determines how fast you move along the slope of the gradient. If the selected value of this learning rate is too small, it will take too many iterations before you reach your convergence criteria. If this value is too large, you might overshoot and not converge.
#
# <h1 style="text-align: center;"> 2. Logistic Regression </h1>
# Logistic Regression is similar to (linear) regression, but adapted for the purpose of classification. The difference is small; for Logistic Regression we also have to iteratively apply the gradient descent method to estimate the values of the parameter $ \theta$. And again, during the iteration, the values are estimated by taking the gradient of the cost function. And also, the cost function is given by the squared error of the difference between the hypothesis function $ h_{\theta}(x)$ and $ Y$. The major difference however, is the hypothesis function itself.
#
# In order to understand the hypothesis function of Logistic Regression, we must first understand the idea behind classification.
#
# When you want to classify something, there are a limited number of classes it can belong to. And for each of these possible classes there can only be two states for $ y^{(i)} $;
# either $ y^{(i)} $ belongs to the specified class and $ y = 1 $, or it does not belong to the class and $ y = 0 $. Even though the output values $ Y $ are binary, the independent variables $ X $ are still continuous. So, we need a function which has as input a large set of continuous variables $ X $ and for each of these variables produces a binary output. This function, the hypothesis function, has the following form:
#
# $ h_{\theta} = \frac{1}{1 + \exp(-z)} = \frac{1}{1 + \exp(-\theta x)} $.
#
# This function is also known as the <a href="https://en.wikipedia.org/wiki/Logistic_function" target="_blank">logistic function</a>, which is a part of the <a href="https://en.wikipedia.org/wiki/Sigmoid_function" target="_blank">sigmoid function</a> family. These functions are widely used in the natural sciences because they provide the simplest model for population growth. However, the reason why the logistic function is used for classification in Machine Learning is its 'S-shape'.
#
# <img src="img/Logistic-curve.svg_-350x233.png"/>
#
# As you can see this function is bounded in the y-direction by 0 and 1. If the variable $ z$ is very negative, the output function will go to zero (it does not belong to the class). If the variable $ z$ is very positive, the output will be one and it does belong to the class.
# (Such a function is called an <a href="https://en.wikipedia.org/wiki/Indicator_function" target="_blank">indicator function</a>.)
#
# The question then is, what will happen to input values which are neither very positive nor very negative, but somewhere 'in the middle'. We have to define a decision boundary, which separates the positive from the negative class. Usually this decision boundary is chosen at the middle of the logistic function, namely at $ z = 0 $ where the output value $ y$ is $ 0.5$.
#
# \begin{equation}
# y =\begin{cases}
# 1, \text{if $z \gt  0 $}.\\
# 0, \text{if $z \lt 0 $}.
# \end{cases}
# \end{equation}
#
# As we can see in the formula of the logistic function, $ z = \theta \cdot x $. Meaning, the dependent parameter $ \theta$ (also known as the feature), maps the input variable $ x$  to a position on the $ z$-axis. With its $ z$-value,  we can use the logistic function to calculate the $ y$ -value. If this $ y$-value $ \gt 0.5 $ we assume it does belong in this class and vice versa.
#
# So the feature $ \theta $ should be chosen such that it predicts the class membership correctly. It is therefore essential to know which features are useful for the classification task. Once the appropriate features are <a href="https://en.wikipedia.org/wiki/Feature_selection" target="_blank">selected</a> , gradient descent can be used to find the optimal value of these features.
#
# How can we do gradient descent with this logistic function? Except for the hypothesis function having a different form, the gradient descent method is exactly the same. We again have a cost function, of which we have to iteratively take the gradient w.r.t. the feature $ \theta $ and update the feature value at each iteration.
#
# This cost function is given by
#
# &nbsp;
#
# \begin{equation}
# \begin{split}
# J(x) = -\frac{1}{2n} \sum_i^n \left(  y^{(i)} log( h_{\theta}(x^{(i)})) + (1-y^{(i)})log(1-h_{\theta}(x^{(i)})) \right) \\
#  = -\frac{1}{2n} \sum_i^n \left( y^{(i)} log(\frac{1}{1+exp(-\theta x)}) + (1-y^{(i)})log(1-\frac{1}{1+exp(-\theta x)}) \right)
# \end{split}
# \end{equation}
#
# &nbsp;
#
# We know that:
# $ log(\frac{1}{1+exp(-\theta x)}) = log(1) - log(1+exp(-\theta x)) = - log(1+exp(-\theta x))$
#
# and
#
# $ log(1-\frac{1}{1+exp(-\theta x)}) = log( \frac{exp(-\theta x)}{1+exp(-\theta x)}) $
#
# $ = log(exp(-\theta x)) - log(1+exp(-\theta x)) $
#
# $ = -\theta x^{(i)} -  log(1+exp(-\theta x)) $
#
# Plugging these two equations back into the cost function gives us:
#
# \begin{equation}
# \begin{split}
# J(x)  = - \frac{1}{2n} \sum_i^n \left( - y^{(i)} log(1+exp(-\theta x)) - (1-y^{(i)})(\theta x^{(i)} +  log(1+exp(-\theta x))) \right) \\
#  = - \frac{1}{2n} \sum_i^n \left(  y^{(i)} \theta x^{(i)} -\theta x^{(i)} -log(1+exp(-\theta x)) \right)
# \end{split}
# \end{equation}
# &nbsp;
#
# The gradient of the cost function with respect to $ \theta $ is given by
#
# \begin{align}
# \frac{d}{d\theta} J(x) = - \frac{1}{2n} \sum_i^n \left(  y^{(i)} x^{(i)} - x^{(i)} + x^{(i)} \frac{ exp(-\theta x)}{1+exp(-\theta x)} \right) \\
#  = - \frac{1}{2n} \sum_i^n \left( x^{(i)} ( y^{(i)} - 1 +\frac{exp(-\theta x)}{1+exp(-\theta x)} ) \right) \\
#  = - \frac{1}{2n} \sum_i^n  \left( x^{(i)} ( y^{(i)} - \frac{1}{1+exp(-\theta x)} ) \right) \\
#  = - \frac{1}{2n} \sum_i^n  \left( x^{(i)} ( y^{(i)} - h_{\theta}(x^{(i)}) )\right)
# \end{align}
#
# &nbsp;
#
# So the gradient of the seemingly difficult cost function, turns out to be a much simpler equation. And with this simple equation, gradient descent for Logistic Regression is again performed in the same way:
#
# <ul>
# 	<li>Make an initial but intelligent guess for the values of the parameters $ \theta $.</li>
# 	<li>Keep iterating while the value of the cost function has not met your criteria:
# <ul>
# 	<li>With the current values of $ \theta $, calculate the gradient of the cost function J  ( $ \Delta \theta = - \alpha \frac{d}{d\theta} J(x)$ ).</li>
# 	<li>Update the values for the parameters $ \theta := \theta + \alpha \Delta \theta $</li>
# 	<li>Fill in these new values in the hypothesis function and calculate again the value of the cost function;</li>
# </ul>
# </li>
# </ul>
#
#
#
# <h2> 2.2 Logistic Regression - Example 1</h2>
# <br>
# Now that we have looked at the theory, let's lets have a look at an example of Logistic Regression. We will start out with the example of students passing a course or not.
#
# Let's generate some data points. There are $n = 300$ students participating in the course Machine Learning and whether a student $ i $ passes ( $ y_i = 1 $) or not ( $ y_i = 0$ ) depends on two variables;
# <ul>
#  	<li>$x_i^{(1)}$ : how many hours student $ i $ has studied for the exam.</li>
#  	<li>$x_i^{(2)}$ : how many hours student $ i $ has slept the day before the exam.</li>
# </ul>
# &nbsp;
#
# In our example, the results are pretty binary; everyone who has studied less than 4 hours fails the course, as well as everyone whose studying time + sleeping time is less than or equal to 13 hours ($x_i^{(1)} + x_i^{(2)} \leq 13$).

# %%
import random
import numpy as np

def func2(x_i):
    if x_i[1]+x_i[2] >= 13: 
        return 0
    else:
        return 1

def generate_data2(no_points):
    X = np.zeros(shape=(no_points, 3))
    Y = np.zeros(shape=no_points)
    for ii in range(no_points):
        X[ii][0] = 1
        X[ii][1] = random.random()*9+0.5
        X[ii][2] = random.random()*9+0.5
        Y[ii] = func2(X[ii])
    return X, Y

X, Y = generate_data2(300)

# %% [markdown]
# The results looks like this (the green dots indicate a pass and the red dots a fail)
#
# <img src="img/logistic_regression_1.png">

# %%
import math
import numpy as np
 
def z_to_y(z_i):
    return 1 if z_i > 0.5 else 0
 
def determine_correct_guesses(X, Y, theta, m):
    determined_z = [np.dot(theta, X[ii]) for ii in range(m)]
    determined_Y = [z_to_y(elem) for elem in determined_z]
    correct_guesses = [y_i - det_y_i for y_i, det_y_i in zip(Y, determined_Y)]
    return correct_guesses
 
def hypothesis(theta, x_i):
    z = np.dot(theta, x_i)
    sigmoid = 1.0 / (1.0 + math.exp(-1.0*z))
    return sigmoid
    
def gradient_descent(X, Y, theta, alpha, m, number_of_iterations):
    for iter in range(0,number_of_iterations):
        cost = (-1.0/m)*sum([Y[ii]*math.log(hypothesis(theta, X[ii]))+(1-Y[ii])*math.log(1-hypothesis(theta, X[ii])) for ii in range(m)])
        grad = (-1.0/m)*sum([X[ii]*(Y[ii]-hypothesis(theta, X[ii])) for ii in range(m)])
        theta = theta - alpha * grad
        correct_guesses = determine_correct_guesses(X, Y, theta, m).count(0)
        print "iteration %s : cost %s : correct_guesses %s" % (iter, cost, correct_guesses)
    return theta
 
numIterations = 1500
alpha = 0.6
m,n = np.shape(X)
theta = np.ones(n)
theta = gradient_descent(X, Y, theta, alpha, m, numIterations)
# Out:
# iteration 0 : cost 3.14176770748 : correct_guesses 242
# iteration 1 : cost 0.651914434128 : correct_guesses 58
# iteration 2 : cost 2.48713812419 : correct_guesses 242
# iteration 3 : cost 4.50965279578 : correct_guesses 242
# iteration 4 : cost 1.88991340592 : correct_guesses 58
# iteration 5 : cost 1.455332961 : correct_guesses 242
# iteration 6 : cost 4.2794780752 : correct_guesses 242
# iteration 7 : cost 1.66221205517 : correct_guesses 58
# iteration 8 : cost 1.83735610079 : correct_guesses 242
# iteration 9 : cost 4.41699480603 : correct_guesses 242
# iteration 10 : cost 1.79667635751 : correct_guesses 62
# iteration 11 : cost 1.54333675159 : correct_guesses 242
# iteration 12 : cost 4.26363222284 : correct_guesses 242
# iteration 13 : cost 1.64454473355 : correct_guesses 62
# iteration 14 : cost 1.7867156196 : correct_guesses 242
# iteration 15 : cost 4.32689383844 : correct_guesses 242
# iteration 16 : cost 1.70608514729 : correct_guesses 64
# iteration 17 : cost 1.63103200006 : correct_guesses 242
# iteration 18 : cost 4.23344244865 : correct_guesses 242
# iteration 19 : cost 1.61306573096 : correct_guesses 65
# iteration 20 : cost 1.76539368832 : correct_guesses 242
# iteration 21 : cost 4.24468451156 : correct_guesses 242
# iteration 22 : cost 1.62342552246 : correct_guesses 67
# iteration 23 : cost 1.70693211191 : correct_guesses 242
# iteration 24 : cost 4.18808651146 : correct_guesses 242
# iteration 25 : cost 1.56684771628 : correct_guesses 69
# iteration 26 : cost 1.77419488516 : correct_guesses 242
# iteration 27 : cost 4.17127532305 : correct_guesses 242
# iteration 28 : cost 1.54959952115 : correct_guesses 71
# iteration 29 : cost 1.76843637395 : correct_guesses 242
# iteration 30 : cost 4.13164261072 : correct_guesses 242
# iteration 31 : cost 1.50984487296 : correct_guesses 75
# iteration 32 : cost 1.80508667255 : correct_guesses 242
# iteration 33 : cost 4.10340414388 : correct_guesses 242
# iteration 34 : cost 1.48137888047 : correct_guesses 78
# iteration 35 : cost 1.82106543717 : correct_guesses 242
# iteration 36 : cost 4.06925592376 : correct_guesses 242
# iteration 37 : cost 1.4471062083 : correct_guesses 82
# iteration 38 : cost 1.84814812301 : correct_guesses 242
# iteration 39 : cost 4.03738804341 : correct_guesses 242
# iteration 40 : cost 1.41511678178 : correct_guesses 84
# iteration 41 : cost 1.87125751028 : correct_guesses 242
# iteration 42 : cost 4.00426402814 : correct_guesses 242
# iteration 43 : cost 1.38191661408 : correct_guesses 86
# iteration 44 : cost 1.89681197658 : correct_guesses 242
# iteration 45 : cost 3.97133937486 : correct_guesses 242
# iteration 46 : cost 1.34894326794 : correct_guesses 87
# iteration 47 : cost 1.9221007469 : correct_guesses 242
# iteration 48 : cost 3.93811025549 : correct_guesses 242
# iteration 49 : cost 1.31569957859 : correct_guesses 88
# iteration 50 : cost 1.94797688564 : correct_guesses 242
# iteration 51 : cost 3.90478176906 : correct_guesses 242
# iteration 52 : cost 1.28238889845 : correct_guesses 90
# iteration 53 : cost 1.97400198685 : correct_guesses 242
# iteration 54 : cost 3.87132589969 : correct_guesses 242
# iteration 55 : cost 1.24898491247 : correct_guesses 90
# iteration 56 : cost 2.00015178745 : correct_guesses 242
# iteration 57 : cost 3.83778636385 : correct_guesses 242
# iteration 58 : cost 1.21553255764 : correct_guesses 90
# iteration 59 : cost 2.02626592818 : correct_guesses 242
# iteration 60 : cost 3.804188899 : correct_guesses 242
# iteration 61 : cost 1.18205956438 : correct_guesses 93
# iteration 62 : cost 2.05220760681 : correct_guesses 242
# iteration 63 : cost 3.77056568973 : correct_guesses 242
# iteration 64 : cost 1.14860052405 : correct_guesses 97
# iteration 65 : cost 2.07781922165 : correct_guesses 242
# iteration 66 : cost 3.73694981951 : correct_guesses 242
# iteration 67 : cost 1.11519151958 : correct_guesses 99
# iteration 68 : cost 2.10293104898 : correct_guesses 242
# iteration 69 : cost 3.70337698829 : correct_guesses 242
# iteration 70 : cost 1.08187174461 : correct_guesses 99
# iteration 71 : cost 2.12735751605 : correct_guesses 242
# iteration 72 : cost 3.66988553248 : correct_guesses 242
# iteration 73 : cost 1.04868361409 : correct_guesses 100
# iteration 74 : cost 2.15089631163 : correct_guesses 242
# iteration 75 : cost 3.6365167782 : correct_guesses 242
# iteration 76 : cost 1.01567308683 : correct_guesses 102
# iteration 77 : cost 2.17332739202 : correct_guesses 242
# iteration 78 : cost 3.6033151943 : correct_guesses 242
# iteration 79 : cost 0.982889821723 : correct_guesses 103
# iteration 80 : cost 2.19441266128 : correct_guesses 242
# iteration 81 : cost 3.57032839776 : correct_guesses 242
# iteration 82 : cost 0.950387161728 : correct_guesses 104
# iteration 83 : cost 2.21389646095 : correct_guesses 242
# iteration 84 : cost 3.5376069383 : correct_guesses 242
# iteration 85 : cost 0.918221870778 : correct_guesses 104
# iteration 86 : cost 2.23150711267 : correct_guesses 242
# iteration 87 : cost 3.50520376026 : correct_guesses 242
# iteration 88 : cost 0.886453555322 : correct_guesses 104
# iteration 89 : cost 2.24695971099 : correct_guesses 242
# iteration 90 : cost 3.4731733357 : correct_guesses 242
# iteration 91 : cost 0.855143706629 : correct_guesses 106
# iteration 92 : cost 2.25996028431 : correct_guesses 242
# iteration 93 : cost 3.44157034347 : correct_guesses 242
# iteration 94 : cost 0.824354317767 : correct_guesses 107
# iteration 95 : cost 2.27021129971 : correct_guesses 242
# iteration 96 : cost 3.41044792132 : correct_guesses 242
# iteration 97 : cost 0.79414606084 : correct_guesses 108
# iteration 98 : cost 2.27741828277 : correct_guesses 242
# iteration 99 : cost 3.37985547496 : correct_guesses 242
# iteration 100 : cost 0.764576055477 : correct_guesses 109
# iteration 101 : cost 2.28129706908 : correct_guesses 242
# iteration 102 : cost 3.34983610538 : correct_guesses 242
# iteration 103 : cost 0.735695313754 : correct_guesses 110
# iteration 104 : cost 2.28158093563 : correct_guesses 242
# iteration 105 : cost 3.32042375971 : correct_guesses 242
# iteration 106 : cost 0.707545999027 : correct_guesses 110
# iteration 107 : cost 2.27802662988 : correct_guesses 242
# iteration 108 : cost 3.29164024821 : correct_guesses 242
# iteration 109 : cost 0.680158671327 : correct_guesses 111
# iteration 110 : cost 2.2704181771 : correct_guesses 242
# iteration 111 : cost 3.2634922535 : correct_guesses 242
# iteration 112 : cost 0.653549692885 : correct_guesses 114
# iteration 113 : cost 2.25856734013 : correct_guesses 242
# iteration 114 : cost 3.23596842078 : correct_guesses 242
# iteration 115 : cost 0.627718920168 : correct_guesses 115
# iteration 116 : cost 2.24230971406 : correct_guesses 242
# iteration 117 : cost 3.2090364934 : correct_guesses 242
# iteration 118 : cost 0.602647707098 : correct_guesses 117
# iteration 119 : cost 2.22149557768 : correct_guesses 242
# iteration 120 : cost 3.18264028654 : correct_guesses 242
# iteration 121 : cost 0.578297089029 : correct_guesses 118
# iteration 122 : cost 2.1959746299 : correct_guesses 242
# iteration 123 : cost 3.15669600586 : correct_guesses 242
# iteration 124 : cost 0.554605809854 : correct_guesses 119
# iteration 125 : cost 2.1655733674 : correct_guesses 242
# iteration 126 : cost 3.13108702966 : correct_guesses 242
# iteration 127 : cost 0.531487578952 : correct_guesses 121
# iteration 128 : cost 2.13006275457 : correct_guesses 242
# iteration 129 : cost 3.10565562631 : correct_guesses 242
# iteration 130 : cost 0.508826536294 : correct_guesses 122
# iteration 131 : cost 2.08911138866 : correct_guesses 242
# iteration 132 : cost 3.0801888872 : correct_guesses 242
# iteration 133 : cost 0.486469192806 : correct_guesses 123
# iteration 134 : cost 2.04221430392 : correct_guesses 242
# iteration 135 : cost 3.05439372 : correct_guesses 242
# iteration 136 : cost 0.464209692437 : correct_guesses 123
# iteration 137 : cost 1.98857685792 : correct_guesses 242
# iteration 138 : cost 3.02785026871 : correct_guesses 242
# iteration 139 : cost 0.441762116572 : correct_guesses 125
# iteration 140 : cost 1.92690889976 : correct_guesses 242
# iteration 141 : cost 2.99991966234 : correct_guesses 242
# iteration 142 : cost 0.418706088935 : correct_guesses 126
# iteration 143 : cost 1.85502416757 : correct_guesses 242
# iteration 144 : cost 2.96954524346 : correct_guesses 242
# iteration 145 : cost 0.394372462095 : correct_guesses 130
# iteration 146 : cost 1.76897242017 : correct_guesses 242
# iteration 147 : cost 2.93477201538 : correct_guesses 244
# iteration 148 : cost 0.367579354779 : correct_guesses 132
# iteration 149 : cost 1.66089886913 : correct_guesses 242
# iteration 150 : cost 2.89138571894 : correct_guesses 250
# iteration 151 : cost 0.335943909712 : correct_guesses 137
# iteration 152 : cost 1.51281873048 : correct_guesses 242
# iteration 153 : cost 2.82808998655 : correct_guesses 256
# iteration 154 : cost 0.293832099025 : correct_guesses 142
# iteration 155 : cost 1.27427813049 : correct_guesses 242
# iteration 156 : cost 2.70252880407 : correct_guesses 272
# iteration 157 : cost 0.22666368205 : correct_guesses 173
# iteration 158 : cost 0.767340967983 : correct_guesses 242
# iteration 159 : cost 2.23232313091 : correct_guesses 261
# iteration 160 : cost 0.204491758214 : correct_guesses 242
# iteration 161 : cost 0.562063119783 : correct_guesses 127
# iteration 162 : cost 1.99385446871 : correct_guesses 242
# iteration 163 : cost 2.8913963219 : correct_guesses 251
# iteration 164 : cost 0.332907586016 : correct_guesses 139
# iteration 165 : cost 1.49537260005 : correct_guesses 242
# iteration 166 : cost 2.76412999542 : correct_guesses 263
# iteration 167 : cost 0.254213913868 : correct_guesses 155
# iteration 168 : cost 1.00952063984 : correct_guesses 242
# iteration 169 : cost 2.45151854322 : correct_guesses 288
# iteration 170 : cost 0.162610999722 : correct_guesses 282
# iteration 171 : cost 0.163411488333 : correct_guesses 276
# iteration 172 : cost 0.197590201934 : correct_guesses 202
# iteration 173 : cost 0.568899248992 : correct_guesses 242
# iteration 174 : cost 1.88511716164 : correct_guesses 222
# iteration 175 : cost 0.393537959119 : correct_guesses 242
# iteration 176 : cost 1.4613665059 : correct_guesses 171
# iteration 177 : cost 0.848996560827 : correct_guesses 242
# iteration 178 : cost 2.28397147124 : correct_guesses 271
# iteration 179 : cost 0.172888012903 : correct_guesses 253
# iteration 180 : cost 0.328861312928 : correct_guesses 143
# iteration 181 : cost 1.44812459783 : correct_guesses 242
# iteration 182 : cost 2.68770652913 : correct_guesses 274
# iteration 183 : cost 0.214735484063 : correct_guesses 184
# iteration 184 : cost 0.71726427047 : correct_guesses 242
# iteration 185 : cost 2.07486045441 : correct_guesses 245
# iteration 186 : cost 0.249104440717 : correct_guesses 242
# iteration 187 : cost 0.873628639115 : correct_guesses 136
# iteration 188 : cost 1.64039218415 : correct_guesses 242
# iteration 189 : cost 2.71386604273 : correct_guesses 271
# iteration 190 : cost 0.225962460686 : correct_guesses 178
# iteration 191 : cost 0.803304363196 : correct_guesses 242
# iteration 192 : cost 2.15367795322 : correct_guesses 254
# iteration 193 : cost 0.205351385656 : correct_guesses 242
# iteration 194 : cost 0.608707123773 : correct_guesses 135
# iteration 195 : cost 1.84936432323 : correct_guesses 242
# iteration 196 : cost 2.71764994895 : correct_guesses 270
# iteration 197 : cost 0.227299882495 : correct_guesses 179
# iteration 198 : cost 0.806649452541 : correct_guesses 242
# iteration 199 : cost 2.12386193758 : correct_guesses 253
# iteration 200 : cost 0.211834969148 : correct_guesses 242
# iteration 201 : cost 0.651087819116 : correct_guesses 135
# iteration 202 : cost 1.80186526872 : correct_guesses 242
# iteration 203 : cost 2.67552342556 : correct_guesses 275
# iteration 204 : cost 0.207612813077 : correct_guesses 197
# iteration 205 : cost 0.657971663363 : correct_guesses 242
# iteration 206 : cost 1.8978540568 : correct_guesses 229
# iteration 207 : cost 0.335907846735 : correct_guesses 242
# iteration 208 : cost 1.19663191887 : correct_guesses 158
# iteration 209 : cost 1.10751198961 : correct_guesses 242
# iteration 210 : cost 2.36655931134 : correct_guesses 291
# iteration 211 : cost 0.146205721586 : correct_guesses 294
# iteration 212 : cost 0.150575728606 : correct_guesses 255
# iteration 213 : cost 0.201376020109 : correct_guesses 242
# iteration 214 : cost 0.599837519872 : correct_guesses 135
# iteration 215 : cost 1.77144676468 : correct_guesses 242
# iteration 216 : cost 2.61767465807 : correct_guesses 280
# iteration 217 : cost 0.183826400259 : correct_guesses 214
# iteration 218 : cost 0.484269087439 : correct_guesses 242
# iteration 219 : cost 1.55814792823 : correct_guesses 202
# iteration 220 : cost 0.627875659155 : correct_guesses 242
# iteration 221 : cost 1.81630906907 : correct_guesses 226
# iteration 222 : cost 0.378725320066 : correct_guesses 242
# iteration 223 : cost 1.30258491078 : correct_guesses 172
# iteration 224 : cost 0.926115631904 : correct_guesses 242
# iteration 225 : cost 2.1629499625 : correct_guesses 266
# iteration 226 : cost 0.176833511789 : correct_guesses 243
# iteration 227 : cost 0.432430055435 : correct_guesses 143
# iteration 228 : cost 1.59366590687 : correct_guesses 242
# iteration 229 : cost 2.51884339773 : correct_guesses 288
# iteration 230 : cost 0.154974496554 : correct_guesses 243
# iteration 231 : cost 0.262207997467 : correct_guesses 242
# iteration 232 : cost 0.889641799226 : correct_guesses 147
# iteration 233 : cost 1.45277925935 : correct_guesses 242
# iteration 234 : cost 2.45058660568 : correct_guesses 293
# iteration 235 : cost 0.143080571056 : correct_guesses 266
# iteration 236 : cost 0.172793799328 : correct_guesses 244
# iteration 237 : cost 0.409998049957 : correct_guesses 146
# iteration 238 : cost 1.51254808552 : correct_guesses 242
# iteration 239 : cost 2.45229341099 : correct_guesses 293
# iteration 240 : cost 0.142397709765 : correct_guesses 265
# iteration 241 : cost 0.175533581262 : correct_guesses 244
# iteration 242 : cost 0.430664720645 : correct_guesses 145
# iteration 243 : cost 1.5374385692 : correct_guesses 242
# iteration 244 : cost 2.4404822445 : correct_guesses 294
# iteration 245 : cost 0.140192010243 : correct_guesses 267
# iteration 246 : cost 0.16581658253 : correct_guesses 251
# iteration 247 : cost 0.366760886935 : correct_guesses 150
# iteration 248 : cost 1.370025222 : correct_guesses 242
# iteration 249 : cost 2.35798891991 : correct_guesses 292
# iteration 250 : cost 0.135034471642 : correct_guesses 292
# iteration 251 : cost 0.134176220812 : correct_guesses 290
# iteration 252 : cost 0.135696006069 : correct_guesses 288
# iteration 253 : cost 0.151887668267 : correct_guesses 240
# iteration 254 : cost 0.278858322631 : correct_guesses 242
# iteration 255 : cost 0.94081526382 : correct_guesses 154
# iteration 256 : cost 1.32620377993 : correct_guesses 242
# iteration 257 : cost 2.31846041432 : correct_guesses 292
# iteration 258 : cost 0.133921602981 : correct_guesses 291
# iteration 259 : cost 0.141205832141 : correct_guesses 254
# iteration 260 : cost 0.202343515683 : correct_guesses 242
# iteration 261 : cost 0.595775385082 : correct_guesses 145
# iteration 262 : cost 1.61046114106 : correct_guesses 242
# iteration 263 : cost 2.40024529872 : correct_guesses 293
# iteration 264 : cost 0.133284910671 : correct_guesses 276
# iteration 265 : cost 0.141779500444 : correct_guesses 274
# iteration 266 : cost 0.211289590798 : correct_guesses 204
# iteration 267 : cost 0.665561490762 : correct_guesses 242
# iteration 268 : cost 1.73640398886 : correct_guesses 227
# iteration 269 : cost 0.387316103571 : correct_guesses 242
# iteration 270 : cost 1.23178115826 : correct_guesses 179
# iteration 271 : cost 0.913176449809 : correct_guesses 242
# iteration 272 : cost 1.99137622829 : correct_guesses 249
# iteration 273 : cost 0.217777195907 : correct_guesses 242
# iteration 274 : cost 0.658592520922 : correct_guesses 147
# iteration 275 : cost 1.54983557641 : correct_guesses 242
# iteration 276 : cost 2.33219011021 : correct_guesses 292
# iteration 277 : cost 0.129361745959 : correct_guesses 293
# iteration 278 : cost 0.129245727282 : correct_guesses 280
# iteration 279 : cost 0.135610078794 : correct_guesses 276
# iteration 280 : cost 0.18423474267 : correct_guesses 218
# iteration 281 : cost 0.500284966584 : correct_guesses 242
# iteration 282 : cost 1.44874560084 : correct_guesses 206
# iteration 283 : cost 0.640043495161 : correct_guesses 242
# iteration 284 : cost 1.65926073395 : correct_guesses 222
# iteration 285 : cost 0.433011781442 : correct_guesses 242
# iteration 286 : cost 1.30350916458 : correct_guesses 193
# iteration 287 : cost 0.795364964166 : correct_guesses 242
# iteration 288 : cost 1.82860085837 : correct_guesses 236
# iteration 289 : cost 0.299162786589 : correct_guesses 242
# iteration 290 : cost 0.950957786589 : correct_guesses 162
# iteration 291 : cost 1.22181708134 : correct_guesses 242
# iteration 292 : cost 2.13903240209 : correct_guesses 269
# iteration 293 : cost 0.151646805269 : correct_guesses 258
# iteration 294 : cost 0.293916526358 : correct_guesses 176
# iteration 295 : cost 1.0066037276 : correct_guesses 242
# iteration 296 : cost 1.98303044732 : correct_guesses 252
# iteration 297 : cost 0.206470347295 : correct_guesses 242
# iteration 298 : cost 0.585372414761 : correct_guesses 150
# iteration 299 : cost 1.49301852177 : correct_guesses 242
# iteration 300 : cost 2.22618232573 : correct_guesses 282
# iteration 301 : cost 0.131690390818 : correct_guesses 279
# iteration 302 : cost 0.170694700326 : correct_guesses 227
# iteration 303 : cost 0.412696220532 : correct_guesses 242
# iteration 304 : cost 1.21565444565 : correct_guesses 190
# iteration 305 : cost 0.862842779864 : correct_guesses 242
# iteration 306 : cost 1.83320779297 : correct_guesses 243
# iteration 307 : cost 0.279940923687 : correct_guesses 242
# iteration 308 : cost 0.859671624223 : correct_guesses 161
# iteration 309 : cost 1.28070486007 : correct_guesses 242
# iteration 310 : cost 2.10300517638 : correct_guesses 267
# iteration 311 : cost 0.153697734984 : correct_guesses 258
# iteration 312 : cost 0.310652819827 : correct_guesses 176
# iteration 313 : cost 1.02332053027 : correct_guesses 242
# iteration 314 : cost 1.93172481924 : correct_guesses 249
# iteration 315 : cost 0.218900112023 : correct_guesses 242
# iteration 316 : cost 0.623432248674 : correct_guesses 154
# iteration 317 : cost 1.43395467147 : correct_guesses 242
# iteration 318 : cost 2.1380240108 : correct_guesses 273
# iteration 319 : cost 0.141681139706 : correct_guesses 266
# iteration 320 : cost 0.243055362011 : correct_guesses 201
# iteration 321 : cost 0.750399359329 : correct_guesses 242
# iteration 322 : cost 1.66544019791 : correct_guesses 228
# iteration 323 : cost 0.382628848792 : correct_guesses 242
# iteration 324 : cost 1.10265181402 : correct_guesses 185
# iteration 325 : cost 0.954983756356 : correct_guesses 242
# iteration 326 : cost 1.84118160422 : correct_guesses 245
# iteration 327 : cost 0.25831411387 : correct_guesses 242
# iteration 328 : cost 0.757207129909 : correct_guesses 161
# iteration 329 : cost 1.32517242297 : correct_guesses 242
# iteration 330 : cost 2.0494221042 : correct_guesses 267
# iteration 331 : cost 0.160885735412 : correct_guesses 254
# iteration 332 : cost 0.348640238519 : correct_guesses 176
# iteration 333 : cost 1.08516721925 : correct_guesses 242
# iteration 334 : cost 1.90236668106 : correct_guesses 249
# iteration 335 : cost 0.219657303191 : correct_guesses 242
# iteration 336 : cost 0.605376592652 : correct_guesses 160
# iteration 337 : cost 1.37519435254 : correct_guesses 242
# iteration 338 : cost 2.04006906363 : correct_guesses 267
# iteration 339 : cost 0.160388626955 : correct_guesses 255
# iteration 340 : cost 0.343717275988 : correct_guesses 178
# iteration 341 : cost 1.05039407084 : correct_guesses 242
# iteration 342 : cost 1.8503321789 : correct_guesses 248
# iteration 343 : cost 0.24113139736 : correct_guesses 242
# iteration 344 : cost 0.67388474577 : correct_guesses 162
# iteration 345 : cost 1.33340271928 : correct_guesses 242
# iteration 346 : cost 1.99259556922 : correct_guesses 263
# iteration 347 : cost 0.172927893703 : correct_guesses 252
# iteration 348 : cost 0.400170084749 : correct_guesses 172
# iteration 349 : cost 1.15868350253 : correct_guesses 242
# iteration 350 : cost 1.88884883259 : correct_guesses 249
# iteration 351 : cost 0.215473508715 : correct_guesses 242
# iteration 352 : cost 0.571874314697 : correct_guesses 163
# iteration 353 : cost 1.32388253934 : correct_guesses 242
# iteration 354 : cost 1.95837115199 : correct_guesses 261
# iteration 355 : cost 0.181915481476 : correct_guesses 249
# iteration 356 : cost 0.434765180896 : correct_guesses 172
# iteration 357 : cost 1.19547490845 : correct_guesses 242
# iteration 358 : cost 1.88018106178 : correct_guesses 249
# iteration 359 : cost 0.214331234074 : correct_guesses 242
# iteration 360 : cost 0.559050215434 : correct_guesses 168
# iteration 361 : cost 1.29619178052 : correct_guesses 242
# iteration 362 : cost 1.916262296 : correct_guesses 256
# iteration 363 : cost 0.194978767048 : correct_guesses 244
# iteration 364 : cost 0.482029939917 : correct_guesses 172
# iteration 365 : cost 1.23214700791 : correct_guesses 242
# iteration 366 : cost 1.87044677572 : correct_guesses 250
# iteration 367 : cost 0.213683329133 : correct_guesses 242
# iteration 368 : cost 0.548310438863 : correct_guesses 170
# iteration 369 : cost 1.26812846079 : correct_guesses 242
# iteration 370 : cost 1.87383967241 : correct_guesses 252
# iteration 371 : cost 0.209366700544 : correct_guesses 242
# iteration 372 : cost 0.528752598699 : correct_guesses 172
# iteration 373 : cost 1.24613884214 : correct_guesses 242
# iteration 374 : cost 1.84865837376 : correct_guesses 249
# iteration 375 : cost 0.218973236389 : correct_guesses 242
# iteration 376 : cost 0.558364521038 : correct_guesses 172
# iteration 377 : cost 1.24839557555 : correct_guesses 242
# iteration 378 : cost 1.83545541401 : correct_guesses 249
# iteration 379 : cost 0.222841624696 : correct_guesses 242
# iteration 380 : cost 0.567058563878 : correct_guesses 172
# iteration 381 : cost 1.23952742639 : correct_guesses 242
# iteration 382 : cost 1.81681459275 : correct_guesses 249
# iteration 383 : cost 0.229612488968 : correct_guesses 242
# iteration 384 : cost 0.58467853452 : correct_guesses 172
# iteration 385 : cost 1.23200452537 : correct_guesses 242
# iteration 386 : cost 1.79890282791 : correct_guesses 249
# iteration 387 : cost 0.236185240214 : correct_guesses 242
# iteration 388 : cost 0.600673122687 : correct_guesses 172
# iteration 389 : cost 1.22242922636 : correct_guesses 242
# iteration 390 : cost 1.78002318979 : correct_guesses 248
# iteration 391 : cost 0.243462454734 : correct_guesses 242
# iteration 392 : cost 0.617874255489 : correct_guesses 173
# iteration 393 : cost 1.21134589447 : correct_guesses 242
# iteration 394 : cost 1.76043544771 : correct_guesses 246
# iteration 395 : cost 0.251334808505 : correct_guesses 242
# iteration 396 : cost 0.635798832919 : correct_guesses 176
# iteration 397 : cost 1.19859937402 : correct_guesses 242
# iteration 398 : cost 1.74004446603 : correct_guesses 246
# iteration 399 : cost 0.259885064946 : correct_guesses 242
# iteration 400 : cost 0.654551517077 : correct_guesses 177
# iteration 401 : cost 1.18410838414 : correct_guesses 242
# iteration 402 : cost 1.71878643329 : correct_guesses 245
# iteration 403 : cost 0.269183796369 : correct_guesses 242
# iteration 404 : cost 0.674175417742 : correct_guesses 177
# iteration 405 : cost 1.16779394802 : correct_guesses 242
# iteration 406 : cost 1.69659173423 : correct_guesses 244
# iteration 407 : cost 0.279310074847 : correct_guesses 242
# iteration 408 : cost 0.694712450336 : correct_guesses 179
# iteration 409 : cost 1.14958660266 : correct_guesses 242
# iteration 410 : cost 1.67338769455 : correct_guesses 243
# iteration 411 : cost 0.290350463931 : correct_guesses 242
# iteration 412 : cost 0.716197360243 : correct_guesses 181
# iteration 413 : cost 1.12943301629 : correct_guesses 242
# iteration 414 : cost 1.64910123887 : correct_guesses 243
# iteration 415 : cost 0.30239779099 : correct_guesses 242
# iteration 416 : cost 0.738652180034 : correct_guesses 186
# iteration 417 : cost 1.10730479986 : correct_guesses 242
# iteration 418 : cost 1.62366308695 : correct_guesses 241
# iteration 419 : cost 0.31554857122 : correct_guesses 242
# iteration 420 : cost 0.762078824904 : correct_guesses 188
# iteration 421 : cost 1.08320982424 : correct_guesses 242
# iteration 422 : cost 1.59701397943 : correct_guesses 237
# iteration 423 : cost 0.329898472331 : correct_guesses 242
# iteration 424 : cost 0.786449605905 : correct_guesses 190
# iteration 425 : cost 1.05720595685 : correct_guesses 242
# iteration 426 : cost 1.56911335134 : correct_guesses 236
# iteration 427 : cost 0.345535141517 : correct_guesses 242
# iteration 428 : cost 0.811695780879 : correct_guesses 192
# iteration 429 : cost 1.02941652739 : correct_guesses 242
# iteration 430 : cost 1.53995067001 : correct_guesses 234
# iteration 431 : cost 0.362527755689 : correct_guesses 242
# iteration 432 : cost 0.837694777079 : correct_guesses 193
# iteration 433 : cost 1.00004596137 : correct_guesses 242
# iteration 434 : cost 1.509559229 : correct_guesses 233
# iteration 435 : cost 0.380912921642 : correct_guesses 242
# iteration 436 : cost 0.86425744784 : correct_guesses 195
# iteration 437 : cost 0.96939298358 : correct_guesses 242
# iteration 438 : cost 1.47803149791 : correct_guesses 232
# iteration 439 : cost 0.400677163551 : correct_guesses 242
# iteration 440 : cost 0.8911175758 : correct_guesses 200
# iteration 441 : cost 0.937857874484 : correct_guesses 242
# iteration 442 : cost 1.44553420541 : correct_guesses 229
# iteration 443 : cost 0.421737267619 : correct_guesses 242
# iteration 444 : cost 0.917926576795 : correct_guesses 201
# iteration 445 : cost 0.905939911478 : correct_guesses 242
# iteration 446 : cost 1.41232034009 : correct_guesses 228
# iteration 447 : cost 0.443921159626 : correct_guesses 242
# iteration 448 : cost 0.944256645452 : correct_guesses 205
# iteration 449 : cost 0.874221818373 : correct_guesses 242
# iteration 450 : cost 1.37873448814 : correct_guesses 227
# iteration 451 : cost 0.466953508824 : correct_guesses 242
# iteration 452 : cost 0.969615064339 : correct_guesses 205
# iteration 453 : cost 0.843340004798 : correct_guesses 242
# iteration 454 : cost 1.34520776464 : correct_guesses 227
# iteration 455 : cost 0.490451362052 : correct_guesses 242
# iteration 456 : cost 0.993470895353 : correct_guesses 207
# iteration 457 : cost 0.813942313971 : correct_guesses 242
# iteration 458 : cost 1.3122393856 : correct_guesses 224
# iteration 459 : cost 0.513935100615 : correct_guesses 242
# iteration 460 : cost 1.0152929256 : correct_guesses 207
# iteration 461 : cost 0.786638094865 : correct_guesses 242
# iteration 462 : cost 1.28036386596 : correct_guesses 222
# iteration 463 : cost 0.536858181842 : correct_guesses 242
# iteration 464 : cost 1.03459501618 : correct_guesses 208
# iteration 465 : cost 0.761947662794 : correct_guesses 242
# iteration 466 : cost 1.25010584164 : correct_guesses 222
# iteration 467 : cost 0.558655174601 : correct_guesses 242
# iteration 468 : cost 1.05098256422 : correct_guesses 209
# iteration 469 : cost 0.740258903287 : correct_guesses 242
# iteration 470 : cost 1.22192812864 : correct_guesses 220
# iteration 471 : cost 0.578802091892 : correct_guesses 242
# iteration 472 : cost 1.06419234549 : correct_guesses 209
# iteration 473 : cost 0.721797780379 : correct_guesses 242
# iteration 474 : cost 1.19618185673 : correct_guesses 220
# iteration 475 : cost 0.596877704963 : correct_guesses 242
# iteration 476 : cost 1.07411819333 : correct_guesses 210
# iteration 477 : cost 0.70661717436 : correct_guesses 242
# iteration 478 : cost 1.17306893708 : correct_guesses 220
# iteration 479 : cost 0.612611933125 : correct_guesses 242
# iteration 480 : cost 1.08081715262 : correct_guesses 213
# iteration 481 : cost 0.694605325525 : correct_guesses 242
# iteration 482 : cost 1.1526254981 : correct_guesses 220
# iteration 483 : cost 0.625909558573 : correct_guesses 242
# iteration 484 : cost 1.08449469031 : correct_guesses 215
# iteration 485 : cost 0.68551178114 : correct_guesses 242
# iteration 486 : cost 1.13473011763 : correct_guesses 220
# iteration 487 : cost 0.636844284063 : correct_guesses 242
# iteration 488 : cost 1.08547219361 : correct_guesses 215
# iteration 489 : cost 0.678985796075 : correct_guesses 242
# iteration 490 : cost 1.11913421521 : correct_guesses 220
# iteration 491 : cost 0.645626794462 : correct_guesses 242
# iteration 492 : cost 1.08414376705 : correct_guesses 217
# iteration 493 : cost 0.674620319714 : correct_guesses 242
# iteration 494 : cost 1.10550644135 : correct_guesses 220
# iteration 495 : cost 0.6525571693 : correct_guesses 242
# iteration 496 : cost 1.08093093336 : correct_guesses 218
# iteration 497 : cost 0.67199448347 : correct_guesses 242
# iteration 498 : cost 1.09348047958 : correct_guesses 219
# iteration 499 : cost 0.657974201128 : correct_guesses 242
# iteration 500 : cost 1.0762429203 : correct_guesses 218
# iteration 501 : cost 0.6707088529 : correct_guesses 242
# iteration 502 : cost 1.0826968662 : correct_guesses 219
# iteration 503 : cost 0.662211974242 : correct_guesses 242
# iteration 504 : cost 1.07044750645 : correct_guesses 219
# iteration 505 : cost 0.670410074612 : correct_guesses 242
# iteration 506 : cost 1.07283304268 : correct_guesses 219
# iteration 507 : cost 0.665569458838 : correct_guesses 242
# iteration 508 : cost 1.06385414031 : correct_guesses 219
# iteration 509 : cost 0.670804135426 : correct_guesses 242
# iteration 510 : cost 1.06362001467 : correct_guesses 219
# iteration 511 : cost 0.668294208331 : correct_guesses 242
# iteration 512 : cost 1.05670831081 : correct_guesses 219
# iteration 513 : cost 0.671659568561 : correct_guesses 242
# iteration 514 : cost 1.0548472255 : correct_guesses 219
# iteration 515 : cost 0.670577980878 : correct_guesses 242
# iteration 516 : cost 1.049194479 : correct_guesses 219
# iteration 517 : cost 0.672803213259 : correct_guesses 242
# iteration 518 : cost 1.04635896271 : correct_guesses 219
# iteration 519 : cost 0.672560609351 : correct_guesses 242
# iteration 520 : cost 1.04144431779 : correct_guesses 219
# iteration 521 : cost 0.674111519536 : correct_guesses 242
# iteration 522 : cost 1.03804593989 : correct_guesses 219
# iteration 523 : cost 0.674338364217 : correct_guesses 242
# iteration 524 : cost 1.03354727926 : correct_guesses 219
# iteration 525 : cost 0.675500084845 : correct_guesses 242
# iteration 526 : cost 1.02983512214 : correct_guesses 219
# iteration 527 : cost 0.67597379254 : correct_guesses 242
# iteration 528 : cost 1.02556124453 : correct_guesses 219
# iteration 529 : cost 0.67691341327 : correct_guesses 242
# iteration 530 : cost 1.02167990905 : correct_guesses 220
# iteration 531 : cost 0.677505039386 : correct_guesses 242
# iteration 532 : cost 1.01752187561 : correct_guesses 220
# iteration 533 : cost 0.678316087727 : correct_guesses 242
# iteration 534 : cost 1.01355183304 : correct_guesses 220
# iteration 535 : cost 0.678953613002 : correct_guesses 242
# iteration 536 : cost 1.00945005366 : correct_guesses 220
# iteration 537 : cost 0.679685847227 : correct_guesses 242
# iteration 538 : cost 1.00543418 : correct_guesses 220
# iteration 539 : cost 0.680330272478 : correct_guesses 242
# iteration 540 : cost 1.00135733925 : correct_guesses 220
# iteration 541 : cost 0.681008566244 : correct_guesses 242
# iteration 542 : cost 0.997317454426 : correct_guesses 220
# iteration 543 : cost 0.68163915998 : correct_guesses 242
# iteration 544 : cost 0.993249710511 : correct_guesses 220
# iteration 545 : cost 0.68227485514 : correct_guesses 242
# iteration 546 : cost 0.989196367711 : correct_guesses 220
# iteration 547 : cost 0.682880510207 : correct_guesses 242
# iteration 548 : cost 0.985129965235 : correct_guesses 220
# iteration 549 : cost 0.683477897999 : correct_guesses 242
# iteration 550 : cost 0.981067958729 : correct_guesses 220
# iteration 551 : cost 0.684052318761 : correct_guesses 242
# iteration 552 : cost 0.976999175109 : correct_guesses 220
# iteration 553 : cost 0.684612155641 : correct_guesses 242
# iteration 554 : cost 0.97293048765 : correct_guesses 220
# iteration 555 : cost 0.685151309505 : correct_guesses 242
# iteration 556 : cost 0.968857517527 : correct_guesses 220
# iteration 557 : cost 0.685672629453 : correct_guesses 242
# iteration 558 : cost 0.964782820662 : correct_guesses 220
# iteration 559 : cost 0.686173463074 : correct_guesses 242
# iteration 560 : cost 0.96070472572 : correct_guesses 220
# iteration 561 : cost 0.686654464756 : correct_guesses 242
# iteration 562 : cost 0.956624106148 : correct_guesses 220
# iteration 563 : cost 0.68711428849 : correct_guesses 242
# iteration 564 : cost 0.952540319489 : correct_guesses 220
# iteration 565 : cost 0.687552747056 : correct_guesses 242
# iteration 566 : cost 0.948453613415 : correct_guesses 220
# iteration 567 : cost 0.687968953743 : correct_guesses 242
# iteration 568 : cost 0.944363717345 : correct_guesses 220
# iteration 569 : cost 0.688362401518 : correct_guesses 242
# iteration 570 : cost 0.940270656754 : correct_guesses 220
# iteration 571 : cost 0.688732343764 : correct_guesses 242
# iteration 572 : cost 0.936174288273 : correct_guesses 220
# iteration 573 : cost 0.689078144732 : correct_guesses 242
# iteration 574 : cost 0.932074561764 : correct_guesses 220
# iteration 575 : cost 0.68939908347 : correct_guesses 242
# iteration 576 : cost 0.927971374542 : correct_guesses 220
# iteration 577 : cost 0.689694461785 : correct_guesses 242
# iteration 578 : cost 0.923864651434 : correct_guesses 220
# iteration 579 : cost 0.689963545371 : correct_guesses 242
# iteration 580 : cost 0.919754301452 : correct_guesses 220
# iteration 581 : cost 0.690205595289 : correct_guesses 242
# iteration 582 : cost 0.915640240968 : correct_guesses 220
# iteration 583 : cost 0.690419851251 : correct_guesses 242
# iteration 584 : cost 0.911522381545 : correct_guesses 220
# iteration 585 : cost 0.690605540299 : correct_guesses 242
# iteration 586 : cost 0.907400636292 : correct_guesses 220
# iteration 587 : cost 0.690761872361 : correct_guesses 242
# iteration 588 : cost 0.903274916651 : correct_guesses 220
# iteration 589 : cost 0.690888042556 : correct_guesses 242
# iteration 590 : cost 0.899145134057 : correct_guesses 220
# iteration 591 : cost 0.690983230148 : correct_guesses 242
# iteration 592 : cost 0.895011199158 : correct_guesses 220
# iteration 593 : cost 0.691046599211 : correct_guesses 242
# iteration 594 : cost 0.890873022241 : correct_guesses 220
# iteration 595 : cost 0.691077298512 : correct_guesses 242
# iteration 596 : cost 0.886730513071 : correct_guesses 220
# iteration 597 : cost 0.691074461833 : correct_guesses 242
# iteration 598 : cost 0.882583581016 : correct_guesses 220
# iteration 599 : cost 0.691037208138 : correct_guesses 242
# iteration 600 : cost 0.878432135038 : correct_guesses 220
# iteration 601 : cost 0.690964641883 : correct_guesses 242
# iteration 602 : cost 0.874276083746 : correct_guesses 220
# iteration 603 : cost 0.69085585332 : correct_guesses 242
# iteration 604 : cost 0.870115335423 : correct_guesses 220
# iteration 605 : cost 0.690709918886 : correct_guesses 242
# iteration 606 : cost 0.865949798067 : correct_guesses 220
# iteration 607 : cost 0.690525901619 : correct_guesses 242
# iteration 608 : cost 0.861779379422 : correct_guesses 220
# iteration 609 : cost 0.690302851644 : correct_guesses 242
# iteration 610 : cost 0.857603987019 : correct_guesses 220
# iteration 611 : cost 0.690039806716 : correct_guesses 242
# iteration 612 : cost 0.853423528212 : correct_guesses 220
# iteration 613 : cost 0.689735792813 : correct_guesses 242
# iteration 614 : cost 0.84923791021 : correct_guesses 220
# iteration 615 : cost 0.689389824811 : correct_guesses 242
# iteration 616 : cost 0.84504704012 : correct_guesses 220
# iteration 617 : cost 0.689000907206 : correct_guesses 242
# iteration 618 : cost 0.840850824976 : correct_guesses 220
# iteration 619 : cost 0.688568034918 : correct_guesses 242
# iteration 620 : cost 0.83664917178 : correct_guesses 220
# iteration 621 : cost 0.688090194163 : correct_guesses 242
# iteration 622 : cost 0.832441987527 : correct_guesses 220
# iteration 623 : cost 0.687566363397 : correct_guesses 242
# iteration 624 : cost 0.828229179244 : correct_guesses 220
# iteration 625 : cost 0.686995514336 : correct_guesses 242
# iteration 626 : cost 0.824010654019 : correct_guesses 220
# iteration 627 : cost 0.686376613059 : correct_guesses 242
# iteration 628 : cost 0.819786319023 : correct_guesses 220
# iteration 629 : cost 0.685708621187 : correct_guesses 242
# iteration 630 : cost 0.815556081543 : correct_guesses 220
# iteration 631 : cost 0.684990497145 : correct_guesses 242
# iteration 632 : cost 0.811319849 : correct_guesses 220
# iteration 633 : cost 0.684221197505 : correct_guesses 242
# iteration 634 : cost 0.807077528969 : correct_guesses 220
# iteration 635 : cost 0.683399678425 : correct_guesses 242
# iteration 636 : cost 0.802829029196 : correct_guesses 220
# iteration 637 : cost 0.682524897156 : correct_guesses 242
# iteration 638 : cost 0.798574257611 : correct_guesses 220
# iteration 639 : cost 0.681595813651 : correct_guesses 242
# iteration 640 : cost 0.794313122332 : correct_guesses 220
# iteration 641 : cost 0.680611392251 : correct_guesses 242
# iteration 642 : cost 0.790045531676 : correct_guesses 220
# iteration 643 : cost 0.679570603462 : correct_guesses 242
# iteration 644 : cost 0.785771394153 : correct_guesses 220
# iteration 645 : cost 0.678472425817 : correct_guesses 242
# iteration 646 : cost 0.781490618463 : correct_guesses 220
# iteration 647 : cost 0.67731584782 : correct_guesses 242
# iteration 648 : cost 0.777203113488 : correct_guesses 220
# iteration 649 : cost 0.676099869976 : correct_guesses 242
# iteration 650 : cost 0.772908788277 : correct_guesses 220
# iteration 651 : cost 0.674823506902 : correct_guesses 242
# iteration 652 : cost 0.768607552027 : correct_guesses 221
# iteration 653 : cost 0.673485789513 : correct_guesses 242
# iteration 654 : cost 0.76429931406 : correct_guesses 221
# iteration 655 : cost 0.672085767286 : correct_guesses 242
# iteration 656 : cost 0.759983983802 : correct_guesses 221
# iteration 657 : cost 0.670622510598 : correct_guesses 242
# iteration 658 : cost 0.755661470744 : correct_guesses 221
# iteration 659 : cost 0.669095113121 : correct_guesses 242
# iteration 660 : cost 0.751331684421 : correct_guesses 221
# iteration 661 : cost 0.667502694294 : correct_guesses 242
# iteration 662 : cost 0.74699453437 : correct_guesses 221
# iteration 663 : cost 0.66584440184 : correct_guesses 242
# iteration 664 : cost 0.7426499301 : correct_guesses 221
# iteration 665 : cost 0.664119414336 : correct_guesses 242
# iteration 666 : cost 0.738297781056 : correct_guesses 222
# iteration 667 : cost 0.662326943833 : correct_guesses 242
# iteration 668 : cost 0.733937996593 : correct_guesses 222
# iteration 669 : cost 0.660466238507 : correct_guesses 242
# iteration 670 : cost 0.729570485946 : correct_guesses 222
# iteration 671 : cost 0.658536585343 : correct_guesses 242
# iteration 672 : cost 0.725195158212 : correct_guesses 222
# iteration 673 : cost 0.656537312841 : correct_guesses 242
# iteration 674 : cost 0.720811922339 : correct_guesses 223
# iteration 675 : cost 0.654467793728 : correct_guesses 242
# iteration 676 : cost 0.716420687129 : correct_guesses 223
# iteration 677 : cost 0.652327447691 : correct_guesses 242
# iteration 678 : cost 0.712021361254 : correct_guesses 223
# iteration 679 : cost 0.650115744085 : correct_guesses 243
# iteration 680 : cost 0.707613853293 : correct_guesses 223
# iteration 681 : cost 0.647832204646 : correct_guesses 243
# iteration 682 : cost 0.703198071791 : correct_guesses 223
# iteration 683 : cost 0.64547640617 : correct_guesses 244
# iteration 684 : cost 0.698773925343 : correct_guesses 223
# iteration 685 : cost 0.643047983162 : correct_guesses 244
# iteration 686 : cost 0.694341322714 : correct_guesses 223
# iteration 687 : cost 0.640546630445 : correct_guesses 244
# iteration 688 : cost 0.689900172995 : correct_guesses 223
# iteration 689 : cost 0.637972105718 : correct_guesses 244
# iteration 690 : cost 0.685450385796 : correct_guesses 223
# iteration 691 : cost 0.635324232054 : correct_guesses 244
# iteration 692 : cost 0.680991871497 : correct_guesses 223
# iteration 693 : cost 0.632602900321 : correct_guesses 244
# iteration 694 : cost 0.676524541542 : correct_guesses 223
# iteration 695 : cost 0.62980807154 : correct_guesses 244
# iteration 696 : cost 0.6720483088 : correct_guesses 223
# iteration 697 : cost 0.626939779138 : correct_guesses 244
# iteration 698 : cost 0.667563087992 : correct_guesses 223
# iteration 699 : cost 0.623998131122 : correct_guesses 244
# iteration 700 : cost 0.663068796187 : correct_guesses 223
# iteration 701 : cost 0.620983312138 : correct_guesses 244
# iteration 702 : cost 0.658565353381 : correct_guesses 224
# iteration 703 : cost 0.617895585424 : correct_guesses 244
# iteration 704 : cost 0.65405268316 : correct_guesses 225
# iteration 705 : cost 0.614735294645 : correct_guesses 244
# iteration 706 : cost 0.649530713452 : correct_guesses 225
# iteration 707 : cost 0.611502865602 : correct_guesses 244
# iteration 708 : cost 0.644999377378 : correct_guesses 226
# iteration 709 : cost 0.608198807804 : correct_guesses 244
# iteration 710 : cost 0.640458614208 : correct_guesses 226
# iteration 711 : cost 0.604823715903 : correct_guesses 246
# iteration 712 : cost 0.635908370415 : correct_guesses 226
# iteration 713 : cost 0.601378270986 : correct_guesses 247
# iteration 714 : cost 0.631348600846 : correct_guesses 226
# iteration 715 : cost 0.597863241699 : correct_guesses 248
# iteration 716 : cost 0.626779270003 : correct_guesses 227
# iteration 717 : cost 0.594279485225 : correct_guesses 248
# iteration 718 : cost 0.622200353431 : correct_guesses 227
# iteration 719 : cost 0.590627948072 : correct_guesses 248
# iteration 720 : cost 0.61761183923 : correct_guesses 227
# iteration 721 : cost 0.586909666697 : correct_guesses 248
# iteration 722 : cost 0.613013729667 : correct_guesses 227
# iteration 723 : cost 0.583125767928 : correct_guesses 249
# iteration 724 : cost 0.608406042895 : correct_guesses 228
# iteration 725 : cost 0.579277469184 : correct_guesses 249
# iteration 726 : cost 0.603788814777 : correct_guesses 228
# iteration 727 : cost 0.575366078484 : correct_guesses 250
# iteration 728 : cost 0.599162100795 : correct_guesses 228
# iteration 729 : cost 0.571392994221 : correct_guesses 251
# iteration 730 : cost 0.594525978036 : correct_guesses 229
# iteration 731 : cost 0.567359704691 : correct_guesses 251
# iteration 732 : cost 0.589880547253 : correct_guesses 229
# iteration 733 : cost 0.563267787361 : correct_guesses 251
# iteration 734 : cost 0.585225934957 : correct_guesses 229
# iteration 735 : cost 0.559118907851 : correct_guesses 251
# iteration 736 : cost 0.580562295548 : correct_guesses 229
# iteration 737 : cost 0.554914818611 : correct_guesses 251
# iteration 738 : cost 0.575889813443 : correct_guesses 229
# iteration 739 : cost 0.550657357279 : correct_guesses 252
# iteration 740 : cost 0.571208705184 : correct_guesses 229
# iteration 741 : cost 0.546348444679 : correct_guesses 252
# iteration 742 : cost 0.566519221486 : correct_guesses 229
# iteration 743 : cost 0.541990082455 : correct_guesses 252
# iteration 744 : cost 0.561821649207 : correct_guesses 229
# iteration 745 : cost 0.537584350305 : correct_guesses 252
# iteration 746 : cost 0.557116313186 : correct_guesses 229
# iteration 747 : cost 0.533133402791 : correct_guesses 252
# iteration 748 : cost 0.552403577938 : correct_guesses 229
# iteration 749 : cost 0.528639465709 : correct_guesses 252
# iteration 750 : cost 0.547683849131 : correct_guesses 230
# iteration 751 : cost 0.524104831991 : correct_guesses 252
# iteration 752 : cost 0.542957574844 : correct_guesses 231
# iteration 753 : cost 0.519531857129 : correct_guesses 253
# iteration 754 : cost 0.538225246534 : correct_guesses 231
# iteration 755 : cost 0.514922954097 : correct_guesses 253
# iteration 756 : cost 0.533487399687 : correct_guesses 231
# iteration 757 : cost 0.510280587775 : correct_guesses 254
# iteration 758 : cost 0.528744614117 : correct_guesses 231
# iteration 759 : cost 0.50560726886 : correct_guesses 254
# iteration 760 : cost 0.52399751386 : correct_guesses 231
# iteration 761 : cost 0.500905547279 : correct_guesses 254
# iteration 762 : cost 0.519246766653 : correct_guesses 232
# iteration 763 : cost 0.496178005104 : correct_guesses 254
# iteration 764 : cost 0.514493082948 : correct_guesses 233
# iteration 765 : cost 0.491427249009 : correct_guesses 254
# iteration 766 : cost 0.509737214452 : correct_guesses 234
# iteration 767 : cost 0.486655902281 : correct_guesses 254
# iteration 768 : cost 0.504979952175 : correct_guesses 235
# iteration 769 : cost 0.481866596436 : correct_guesses 254
# iteration 770 : cost 0.500222123971 : correct_guesses 235
# iteration 771 : cost 0.477061962499 : correct_guesses 254
# iteration 772 : cost 0.495464591579 : correct_guesses 235
# iteration 773 : cost 0.472244621991 : correct_guesses 254
# iteration 774 : cost 0.490708247172 : correct_guesses 236
# iteration 775 : cost 0.467417177716 : correct_guesses 255
# iteration 776 : cost 0.485954009432 : correct_guesses 236
# iteration 777 : cost 0.462582204408 : correct_guesses 256
# iteration 778 : cost 0.48120281918 : correct_guesses 236
# iteration 779 : cost 0.457742239351 : correct_guesses 256
# iteration 780 : cost 0.476455634602 : correct_guesses 236
# iteration 781 : cost 0.452899773041 : correct_guesses 256
# iteration 782 : cost 0.471713426119 : correct_guesses 237
# iteration 783 : cost 0.44805724001 : correct_guesses 256
# iteration 784 : cost 0.466977170955 : correct_guesses 238
# iteration 785 : cost 0.443217009903 : correct_guesses 256
# iteration 786 : cost 0.462247847471 : correct_guesses 238
# iteration 787 : cost 0.438381378913 : correct_guesses 256
# iteration 788 : cost 0.457526429336 : correct_guesses 239
# iteration 789 : cost 0.433552561678 : correct_guesses 256
# iteration 790 : cost 0.452813879616 : correct_guesses 239
# iteration 791 : cost 0.428732683727 : correct_guesses 256
# iteration 792 : cost 0.448111144845 : correct_guesses 240
# iteration 793 : cost 0.423923774569 : correct_guesses 257
# iteration 794 : cost 0.443419149183 : correct_guesses 240
# iteration 795 : cost 0.419127761512 : correct_guesses 258
# iteration 796 : cost 0.438738788722 : correct_guesses 240
# iteration 797 : cost 0.414346464264 : correct_guesses 258
# iteration 798 : cost 0.434070926027 : correct_guesses 240
# iteration 799 : cost 0.40958159039 : correct_guesses 258
# iteration 800 : cost 0.429416384989 : correct_guesses 240
# iteration 801 : cost 0.404834731655 : correct_guesses 258
# iteration 802 : cost 0.424775946052 : correct_guesses 240
# iteration 803 : cost 0.400107361293 : correct_guesses 258
# iteration 804 : cost 0.420150341883 : correct_guesses 242
# iteration 805 : cost 0.39540083221 : correct_guesses 258
# iteration 806 : cost 0.415540253536 : correct_guesses 242
# iteration 807 : cost 0.390716376119 : correct_guesses 258
# iteration 808 : cost 0.410946307152 : correct_guesses 242
# iteration 809 : cost 0.386055103609 : correct_guesses 259
# iteration 810 : cost 0.406369071234 : correct_guesses 242
# iteration 811 : cost 0.381418005097 : correct_guesses 259
# iteration 812 : cost 0.401809054526 : correct_guesses 243
# iteration 813 : cost 0.376805952654 : correct_guesses 259
# iteration 814 : cost 0.397266704502 : correct_guesses 243
# iteration 815 : cost 0.372219702631 : correct_guesses 259
# iteration 816 : cost 0.392742406477 : correct_guesses 243
# iteration 817 : cost 0.367659899056 : correct_guesses 259
# iteration 818 : cost 0.388236483347 : correct_guesses 244
# iteration 819 : cost 0.363127077723 : correct_guesses 259
# iteration 820 : cost 0.38374919593 : correct_guesses 245
# iteration 821 : cost 0.35862167091 : correct_guesses 261
# iteration 822 : cost 0.379280743913 : correct_guesses 245
# iteration 823 : cost 0.354144012671 : correct_guesses 261
# iteration 824 : cost 0.374831267363 : correct_guesses 245
# iteration 825 : cost 0.349694344619 : correct_guesses 261
# iteration 826 : cost 0.370400848802 : correct_guesses 245
# iteration 827 : cost 0.345272822147 : correct_guesses 261
# iteration 828 : cost 0.365989515785 : correct_guesses 245
# iteration 829 : cost 0.340879521007 : correct_guesses 261
# iteration 830 : cost 0.36159724399 : correct_guesses 245
# iteration 831 : cost 0.336514444207 : correct_guesses 262
# iteration 832 : cost 0.357223960753 : correct_guesses 245
# iteration 833 : cost 0.332177529151 : correct_guesses 262
# iteration 834 : cost 0.352869549047 : correct_guesses 245
# iteration 835 : cost 0.327868654986 : correct_guesses 262
# ...
# iteration 1233 : cost 0.0649335485599 : correct_guesses 297
# iteration 1234 : cost 0.0649285226937 : correct_guesses 296
# iteration 1235 : cost 0.064923505653 : correct_guesses 297
# iteration 1236 : cost 0.0649185124868 : correct_guesses 296
# iteration 1237 : cost 0.0649135279111 : correct_guesses 297
# iteration 1238 : cost 0.064908564078 : correct_guesses 296
# iteration 1239 : cost 0.0649036085053 : correct_guesses 297
# iteration 1240 : cost 0.0648986709819 : correct_guesses 296
# iteration 1241 : cost 0.0648937413255 : correct_guesses 297
# iteration 1242 : cost 0.0648888274015 : correct_guesses 296
# iteration 1243 : cost 0.0648839209125 : correct_guesses 297
# iteration 1244 : cost 0.0648790281621 : correct_guesses 296
# iteration 1245 : cost 0.0648741423959 : correct_guesses 297
# iteration 1246 : cost 0.0648692686517 : correct_guesses 296
# iteration 1247 : cost 0.0648644014364 : correct_guesses 297
# iteration 1248 : cost 0.0648595447649 : correct_guesses 296
# iteration 1249 : cost 0.0648546941739 : correct_guesses 297
# iteration 1250 : cost 0.064849852853 : correct_guesses 296
# iteration 1251 : cost 0.0648450171788 : correct_guesses 297
# iteration 1252 : cost 0.0648401896772 : correct_guesses 296
# iteration 1253 : cost 0.0648353674087 : correct_guesses 297
# iteration 1254 : cost 0.0648305523668 : correct_guesses 296
# iteration 1255 : cost 0.0648257421682 : correct_guesses 297
# iteration 1256 : cost 0.0648209383807 : correct_guesses 296
# iteration 1257 : cost 0.0648161390729 : correct_guesses 297
# iteration 1258 : cost 0.0648113454727 : correct_guesses 296
# iteration 1259 : cost 0.0648065560159 : correct_guesses 297
# iteration 1260 : cost 0.06480177166 : correct_guesses 296
# iteration 1261 : cost 0.0647969911384 : correct_guesses 297
# iteration 1262 : cost 0.0647922151945 : correct_guesses 296
# iteration 1263 : cost 0.0647874428028 : correct_guesses 297
# iteration 1264 : cost 0.0647826745371 : correct_guesses 296
# iteration 1265 : cost 0.0647779095677 : correct_guesses 297
# iteration 1266 : cost 0.0647731483348 : correct_guesses 296
# iteration 1267 : cost 0.0647683901668 : correct_guesses 297
# iteration 1268 : cost 0.0647636353993 : correct_guesses 296
# iteration 1269 : cost 0.0647588834885 : correct_guesses 296
# iteration 1270 : cost 0.0647541346884 : correct_guesses 296
# iteration 1271 : cost 0.0647493885587 : correct_guesses 296
# iteration 1272 : cost 0.0647446452895 : correct_guesses 296
# iteration 1273 : cost 0.0647399045243 : correct_guesses 296
# iteration 1274 : cost 0.0647351664042 : correct_guesses 296
# iteration 1275 : cost 0.0647304306399 : correct_guesses 296
# iteration 1276 : cost 0.0647256973347 : correct_guesses 296
# iteration 1277 : cost 0.0647209662541 : correct_guesses 296
# iteration 1278 : cost 0.0647162374723 : correct_guesses 296
# iteration 1279 : cost 0.064711510799 : correct_guesses 296
# iteration 1280 : cost 0.0647067862863 : correct_guesses 296
# iteration 1281 : cost 0.0647020637798 : correct_guesses 296
# iteration 1282 : cost 0.0646973433148 : correct_guesses 296
# iteration 1283 : cost 0.0646926247658 : correct_guesses 296
# iteration 1284 : cost 0.0646879081559 : correct_guesses 296
# iteration 1285 : cost 0.0646831933828 : correct_guesses 296
# iteration 1286 : cost 0.0646784804606 : correct_guesses 296
# iteration 1287 : cost 0.0646737693057 : correct_guesses 296
# iteration 1288 : cost 0.0646690599257 : correct_guesses 296
# iteration 1289 : cost 0.0646643522524 : correct_guesses 296
# iteration 1290 : cost 0.0646596462886 : correct_guesses 296
# iteration 1291 : cost 0.0646549419786 : correct_guesses 296
# iteration 1292 : cost 0.0646502393218 : correct_guesses 296
# iteration 1293 : cost 0.0646455382725 : correct_guesses 296
# iteration 1294 : cost 0.0646408388281 : correct_guesses 296
# iteration 1295 : cost 0.064636140951 : correct_guesses 296
# iteration 1296 : cost 0.0646314446372 : correct_guesses 296
# iteration 1297 : cost 0.0646267498557 : correct_guesses 296
# iteration 1298 : cost 0.0646220566017 : correct_guesses 296
# iteration 1299 : cost 0.0646173648497 : correct_guesses 296
# iteration 1300 : cost 0.0646126745943 : correct_guesses 296
# iteration 1301 : cost 0.0646079858146 : correct_guesses 296
# iteration 1302 : cost 0.064603298505 : correct_guesses 296
# iteration 1303 : cost 0.0645986126482 : correct_guesses 296
# iteration 1304 : cost 0.0645939282389 : correct_guesses 296
# iteration 1305 : cost 0.0645892452625 : correct_guesses 296
# iteration 1306 : cost 0.0645845637139 : correct_guesses 296
# iteration 1307 : cost 0.064579883581 : correct_guesses 296
# iteration 1308 : cost 0.0645752048591 : correct_guesses 296
# iteration 1309 : cost 0.0645705275381 : correct_guesses 296
# iteration 1310 : cost 0.0645658516134 : correct_guesses 296
# iteration 1311 : cost 0.0645611770766 : correct_guesses 296
# iteration 1312 : cost 0.0645565039237 : correct_guesses 296
# iteration 1313 : cost 0.0645518321474 : correct_guesses 296
# iteration 1314 : cost 0.0645471617441 : correct_guesses 296
# iteration 1315 : cost 0.0645424927078 : correct_guesses 296
# iteration 1316 : cost 0.064537825035 : correct_guesses 296
# iteration 1317 : cost 0.0645331587206 : correct_guesses 296
# iteration 1318 : cost 0.0645284937616 : correct_guesses 296
# iteration 1319 : cost 0.0645238301536 : correct_guesses 296
# iteration 1320 : cost 0.0645191678939 : correct_guesses 296
# iteration 1321 : cost 0.0645145069788 : correct_guesses 296
# iteration 1322 : cost 0.0645098474057 : correct_guesses 296
# iteration 1323 : cost 0.0645051891715 : correct_guesses 296
# iteration 1324 : cost 0.0645005322739 : correct_guesses 296
# iteration 1325 : cost 0.0644958767101 : correct_guesses 296
# iteration 1326 : cost 0.0644912224782 : correct_guesses 296
# iteration 1327 : cost 0.0644865695757 : correct_guesses 296
# iteration 1328 : cost 0.0644819180007 : correct_guesses 296
# iteration 1329 : cost 0.0644772677513 : correct_guesses 296
# iteration 1330 : cost 0.0644726188256 : correct_guesses 296
# iteration 1331 : cost 0.0644679712219 : correct_guesses 296
# iteration 1332 : cost 0.0644633249386 : correct_guesses 296
# iteration 1333 : cost 0.0644586799741 : correct_guesses 296
# iteration 1334 : cost 0.064454036327 : correct_guesses 296
# iteration 1335 : cost 0.0644493939959 : correct_guesses 296
# iteration 1336 : cost 0.0644447529793 : correct_guesses 296
# iteration 1337 : cost 0.0644401132761 : correct_guesses 296
# iteration 1338 : cost 0.064435474885 : correct_guesses 296
# iteration 1339 : cost 0.0644308378048 : correct_guesses 296
# iteration 1340 : cost 0.0644262020344 : correct_guesses 296
# iteration 1341 : cost 0.0644215675727 : correct_guesses 296
# iteration 1342 : cost 0.0644169344187 : correct_guesses 296
# iteration 1343 : cost 0.0644123025713 : correct_guesses 296
# iteration 1344 : cost 0.0644076720296 : correct_guesses 296
# iteration 1345 : cost 0.0644030427926 : correct_guesses 296
# iteration 1346 : cost 0.0643984148594 : correct_guesses 296
# iteration 1347 : cost 0.064393788229 : correct_guesses 296
# iteration 1348 : cost 0.0643891629007 : correct_guesses 296
# iteration 1349 : cost 0.0643845388736 : correct_guesses 296
# iteration 1350 : cost 0.0643799161467 : correct_guesses 296
# iteration 1351 : cost 0.0643752947194 : correct_guesses 296
# iteration 1352 : cost 0.0643706745908 : correct_guesses 296
# iteration 1353 : cost 0.0643660557601 : correct_guesses 296
# iteration 1354 : cost 0.0643614382265 : correct_guesses 296
# iteration 1355 : cost 0.0643568219893 : correct_guesses 296
# iteration 1356 : cost 0.0643522070478 : correct_guesses 296
# iteration 1357 : cost 0.0643475934011 : correct_guesses 296
# iteration 1358 : cost 0.0643429810487 : correct_guesses 296
# iteration 1359 : cost 0.0643383699896 : correct_guesses 296
# iteration 1360 : cost 0.0643337602234 : correct_guesses 296
# iteration 1361 : cost 0.0643291517491 : correct_guesses 296
# iteration 1362 : cost 0.0643245445662 : correct_guesses 296
# iteration 1363 : cost 0.0643199386739 : correct_guesses 296
# iteration 1364 : cost 0.0643153340716 : correct_guesses 296
# iteration 1365 : cost 0.0643107307586 : correct_guesses 296
# iteration 1366 : cost 0.0643061287342 : correct_guesses 296
# iteration 1367 : cost 0.0643015279977 : correct_guesses 296
# iteration 1368 : cost 0.0642969285485 : correct_guesses 296
# iteration 1369 : cost 0.0642923303859 : correct_guesses 296
# iteration 1370 : cost 0.0642877335092 : correct_guesses 296
# iteration 1371 : cost 0.0642831379179 : correct_guesses 296
# iteration 1372 : cost 0.0642785436111 : correct_guesses 296
# iteration 1373 : cost 0.0642739505884 : correct_guesses 296
# iteration 1374 : cost 0.064269358849 : correct_guesses 296
# iteration 1375 : cost 0.0642647683922 : correct_guesses 296
# iteration 1376 : cost 0.0642601792175 : correct_guesses 296
# iteration 1377 : cost 0.0642555913243 : correct_guesses 296
# iteration 1378 : cost 0.0642510047118 : correct_guesses 296
# iteration 1379 : cost 0.0642464193794 : correct_guesses 296
# iteration 1380 : cost 0.0642418353265 : correct_guesses 296
# iteration 1381 : cost 0.0642372525524 : correct_guesses 296
# iteration 1382 : cost 0.0642326710566 : correct_guesses 296
# iteration 1383 : cost 0.0642280908383 : correct_guesses 296
# iteration 1384 : cost 0.064223511897 : correct_guesses 296
# iteration 1385 : cost 0.064218934232 : correct_guesses 296
# iteration 1386 : cost 0.0642143578427 : correct_guesses 296
# iteration 1387 : cost 0.0642097827285 : correct_guesses 296
# iteration 1388 : cost 0.0642052088887 : correct_guesses 296
# iteration 1389 : cost 0.0642006363228 : correct_guesses 296
# iteration 1390 : cost 0.06419606503 : correct_guesses 296
# iteration 1391 : cost 0.0641914950097 : correct_guesses 296
# iteration 1392 : cost 0.0641869262614 : correct_guesses 296
# iteration 1393 : cost 0.0641823587845 : correct_guesses 296
# iteration 1394 : cost 0.0641777925782 : correct_guesses 296
# iteration 1395 : cost 0.0641732276419 : correct_guesses 296
# iteration 1396 : cost 0.0641686639751 : correct_guesses 296
# iteration 1397 : cost 0.0641641015772 : correct_guesses 296
# iteration 1398 : cost 0.0641595404474 : correct_guesses 296
# iteration 1399 : cost 0.0641549805852 : correct_guesses 296
# iteration 1400 : cost 0.06415042199 : correct_guesses 296
# iteration 1401 : cost 0.0641458646611 : correct_guesses 296
# iteration 1402 : cost 0.064141308598 : correct_guesses 296
# iteration 1403 : cost 0.0641367537999 : correct_guesses 296
# iteration 1404 : cost 0.0641322002664 : correct_guesses 296
# iteration 1405 : cost 0.0641276479967 : correct_guesses 296
# iteration 1406 : cost 0.0641230969903 : correct_guesses 296
# iteration 1407 : cost 0.0641185472466 : correct_guesses 296
# iteration 1408 : cost 0.0641139987648 : correct_guesses 296
# iteration 1409 : cost 0.0641094515445 : correct_guesses 296
# iteration 1410 : cost 0.064104905585 : correct_guesses 296
# iteration 1411 : cost 0.0641003608857 : correct_guesses 296
# iteration 1412 : cost 0.0640958174459 : correct_guesses 296
# iteration 1413 : cost 0.0640912752652 : correct_guesses 296
# iteration 1414 : cost 0.0640867343427 : correct_guesses 296
# iteration 1415 : cost 0.064082194678 : correct_guesses 296
# iteration 1416 : cost 0.0640776562705 : correct_guesses 296
# iteration 1417 : cost 0.0640731191194 : correct_guesses 296
# iteration 1418 : cost 0.0640685832243 : correct_guesses 296
# iteration 1419 : cost 0.0640640485844 : correct_guesses 296
# iteration 1420 : cost 0.0640595151993 : correct_guesses 296
# iteration 1421 : cost 0.0640549830682 : correct_guesses 296
# iteration 1422 : cost 0.0640504521906 : correct_guesses 296
# iteration 1423 : cost 0.0640459225658 : correct_guesses 296
# iteration 1424 : cost 0.0640413941933 : correct_guesses 296
# iteration 1425 : cost 0.0640368670725 : correct_guesses 296
# iteration 1426 : cost 0.0640323412027 : correct_guesses 296
# iteration 1427 : cost 0.0640278165833 : correct_guesses 296
# iteration 1428 : cost 0.0640232932137 : correct_guesses 296
# iteration 1429 : cost 0.0640187710934 : correct_guesses 296
# iteration 1430 : cost 0.0640142502217 : correct_guesses 296
# iteration 1431 : cost 0.064009730598 : correct_guesses 296
# iteration 1432 : cost 0.0640052122217 : correct_guesses 296
# iteration 1433 : cost 0.0640006950923 : correct_guesses 296
# iteration 1434 : cost 0.063996179209 : correct_guesses 296
# iteration 1435 : cost 0.0639916645713 : correct_guesses 296
# iteration 1436 : cost 0.0639871511786 : correct_guesses 296
# iteration 1437 : cost 0.0639826390303 : correct_guesses 296
# iteration 1438 : cost 0.0639781281258 : correct_guesses 296
# iteration 1439 : cost 0.0639736184645 : correct_guesses 296
# iteration 1440 : cost 0.0639691100458 : correct_guesses 296
# iteration 1441 : cost 0.0639646028691 : correct_guesses 296
# iteration 1442 : cost 0.0639600969337 : correct_guesses 296
# iteration 1443 : cost 0.0639555922392 : correct_guesses 296
# iteration 1444 : cost 0.0639510887848 : correct_guesses 296
# iteration 1445 : cost 0.06394658657 : correct_guesses 296
# iteration 1446 : cost 0.0639420855942 : correct_guesses 296
# iteration 1447 : cost 0.0639375858569 : correct_guesses 296
# iteration 1448 : cost 0.0639330873573 : correct_guesses 296
# iteration 1449 : cost 0.0639285900949 : correct_guesses 296
# iteration 1450 : cost 0.0639240940691 : correct_guesses 296
# iteration 1451 : cost 0.0639195992793 : correct_guesses 296
# iteration 1452 : cost 0.0639151057249 : correct_guesses 296
# iteration 1453 : cost 0.0639106134054 : correct_guesses 296
# iteration 1454 : cost 0.0639061223201 : correct_guesses 296
# iteration 1455 : cost 0.0639016324684 : correct_guesses 296
# iteration 1456 : cost 0.0638971438497 : correct_guesses 296
# iteration 1457 : cost 0.0638926564634 : correct_guesses 296
# iteration 1458 : cost 0.0638881703091 : correct_guesses 296
# iteration 1459 : cost 0.0638836853859 : correct_guesses 296
# iteration 1460 : cost 0.0638792016934 : correct_guesses 296
# iteration 1461 : cost 0.063874719231 : correct_guesses 296
# iteration 1462 : cost 0.0638702379981 : correct_guesses 296
# iteration 1463 : cost 0.063865757994 : correct_guesses 296
# iteration 1464 : cost 0.0638612792182 : correct_guesses 296
# iteration 1465 : cost 0.0638568016702 : correct_guesses 296
# iteration 1466 : cost 0.0638523253492 : correct_guesses 296
# iteration 1467 : cost 0.0638478502548 : correct_guesses 296
# iteration 1468 : cost 0.0638433763863 : correct_guesses 296
# iteration 1469 : cost 0.0638389037431 : correct_guesses 296
# iteration 1470 : cost 0.0638344323247 : correct_guesses 296
# iteration 1471 : cost 0.0638299621305 : correct_guesses 296
# iteration 1472 : cost 0.0638254931598 : correct_guesses 296
# iteration 1473 : cost 0.0638210254121 : correct_guesses 296
# iteration 1474 : cost 0.0638165588869 : correct_guesses 296
# iteration 1475 : cost 0.0638120935834 : correct_guesses 296
# iteration 1476 : cost 0.0638076295012 : correct_guesses 296
# iteration 1477 : cost 0.0638031666396 : correct_guesses 296
# iteration 1478 : cost 0.0637987049981 : correct_guesses 296
# iteration 1479 : cost 0.0637942445761 : correct_guesses 296
# iteration 1480 : cost 0.0637897853729 : correct_guesses 296
# iteration 1481 : cost 0.0637853273881 : correct_guesses 296
# iteration 1482 : cost 0.063780870621 : correct_guesses 296
# iteration 1483 : cost 0.063776415071 : correct_guesses 296
# iteration 1484 : cost 0.0637719607376 : correct_guesses 296
# iteration 1485 : cost 0.0637675076201 : correct_guesses 296
# iteration 1486 : cost 0.0637630557181 : correct_guesses 296
# iteration 1487 : cost 0.0637586050308 : correct_guesses 296
# iteration 1488 : cost 0.0637541555578 : correct_guesses 296
# iteration 1489 : cost 0.0637497072985 : correct_guesses 296
# iteration 1490 : cost 0.0637452602522 : correct_guesses 296
# iteration 1491 : cost 0.0637408144183 : correct_guesses 296
# iteration 1492 : cost 0.0637363697964 : correct_guesses 296
# iteration 1493 : cost 0.0637319263859 : correct_guesses 296
# iteration 1494 : cost 0.063727484186 : correct_guesses 296
# iteration 1495 : cost 0.0637230431964 : correct_guesses 296
# iteration 1496 : cost 0.0637186034163 : correct_guesses 296
# iteration 1497 : cost 0.0637141648452 : correct_guesses 296
# iteration 1498 : cost 0.0637097274826 : correct_guesses 296
# iteration 1499 : cost 0.0637052913279 : correct_guesses 296

# %% [markdown]
# <h2> 2.3 Logistic Regression - Example 2: Medical Data</h2>
# <br>
# Now  that the concept of Logistic Regression is a bit more clear, let's classify real-world data!
# The <a href="https://www.umass.edu/statdata/statdata/stat-logistic.html" target="_blank">University of Massachusetts</a> provides some datasets which are ideal to perform Logistic Regression on. They are small (so my small laptop can also perform it in a reasonable amount of time) and there are various datasets with different (amount of) features.
#
# The dataset "<a href="https://www.umass.edu/statdata/statdata/data/myopia.dat" target="_blank">myopia.dat</a>" contains the medical data of 618 subjects, and has 15 features describing the characteristics of each subject. We can read this data in as follows:

# %%
datafile = '../datasets/myopia.dat'
file = open(datafile, 'r')
no_points = 618
X = np.zeros(shape=(no_points, 16))
Y = np.zeros(shape=no_points)
rownum = 0


for line in file:
    line = line.split()
    Y[rownum] = int(line[2])
    X[rownum][0] = 1
    X[rownum][1] = int(line[3])/10.0
    X[rownum][2] = int(line[4])
    X[rownum][3] = float(line[5])
    X[rownum][4] = float(line[6])/10.0
    X[rownum][5] = float(line[7])/10.0
    X[rownum][6] = float(line[8])/10.0
    X[rownum][7] = float(line[9])/10.0
    X[rownum][8] = int(line[10])/10.0
    X[rownum][9] = int(line[11])/10.0
    X[rownum][10] = int(line[12])/10.0
    X[rownum][11] = int(line[13])/10.0
    X[rownum][12] = int(line[14])/10.0
    X[rownum][13] = int(line[15])/10.0
    X[rownum][14] = int(line[16])
    X[rownum][15] = int(line[17])
    rownum+=1

numIterations = 1500
alpha = 0.5
m,n = np.shape(X)
theta = np.ones(n)
theta = gradient_descent(X, Y, theta, alpha, m, numIterations)
# Out:
# iteration 0 : cost 11.9698579441 : correct_guesses 81
# iteration 1 : cost 4.56421973487 : correct_guesses 537
# iteration 2 : cost 0.510718954433 : correct_guesses 537
# iteration 3 : cost 0.4698345457 : correct_guesses 537
# iteration 4 : cost 0.451492914146 : correct_guesses 537
# iteration 5 : cost 0.437892443184 : correct_guesses 537
# iteration 6 : cost 0.425567050331 : correct_guesses 537
# iteration 7 : cost 0.414285407459 : correct_guesses 537
# iteration 8 : cost 0.40399652646 : correct_guesses 537
# iteration 9 : cost 0.394648639806 : correct_guesses 537
# iteration 10 : cost 0.386185200842 : correct_guesses 537
# iteration 11 : cost 0.37854586289 : correct_guesses 537
# iteration 12 : cost 0.37166772419 : correct_guesses 537
# iteration 13 : cost 0.365486611209 : correct_guesses 537
# iteration 14 : cost 0.359938342915 : correct_guesses 537
# iteration 15 : cost 0.354959927087 : correct_guesses 537
# iteration 16 : cost 0.350490638703 : correct_guesses 537
# iteration 17 : cost 0.346472933995 : correct_guesses 537
# iteration 18 : cost 0.342853164166 : correct_guesses 537
# iteration 19 : cost 0.339582069343 : correct_guesses 537
# iteration 20 : cost 0.336615052637 : correct_guesses 537
# iteration 21 : cost 0.333912252278 : correct_guesses 537
# iteration 22 : cost 0.331438443374 : correct_guesses 537
# iteration 23 : cost 0.329162808184 : correct_guesses 537
# iteration 24 : cost 0.327058615221 : correct_guesses 537
# iteration 25 : cost 0.32510284423 : correct_guesses 537
# iteration 26 : cost 0.323275788032 : correct_guesses 537
# iteration 27 : cost 0.321560655025 : correct_guesses 537
# iteration 28 : cost 0.319943189144 : correct_guesses 537
# iteration 29 : cost 0.31841131793 : correct_guesses 537
# iteration 30 : cost 0.31695483448 : correct_guesses 537
# iteration 31 : cost 0.315565115429 : correct_guesses 537
# iteration 32 : cost 0.314234874598 : correct_guesses 537
# iteration 33 : cost 0.312957950334 : correct_guesses 537
# iteration 34 : cost 0.311729123695 : correct_guesses 537
# iteration 35 : cost 0.310543964157 : correct_guesses 537
# iteration 36 : cost 0.309398699499 : correct_guesses 537
# iteration 37 : cost 0.308290106596 : correct_guesses 537
# iteration 38 : cost 0.307215420117 : correct_guesses 537
# iteration 39 : cost 0.306172256431 : correct_guesses 537
# iteration 40 : cost 0.305158550323 : correct_guesses 537
# iteration 41 : cost 0.304172502476 : correct_guesses 537
# iteration 42 : cost 0.303212535933 : correct_guesses 537
# iteration 43 : cost 0.302277260029 : correct_guesses 537
# iteration 44 : cost 0.301365440544 : correct_guesses 537
# iteration 45 : cost 0.300475974989 : correct_guesses 537
# iteration 46 : cost 0.299607872156 : correct_guesses 537
# iteration 47 : cost 0.298760235174 : correct_guesses 537
# iteration 48 : cost 0.297932247473 : correct_guesses 537
# iteration 49 : cost 0.297123161134 : correct_guesses 537
# iteration 50 : cost 0.29633228722 : correct_guesses 537
# iteration 51 : cost 0.295558987722 : correct_guesses 537
# iteration 52 : cost 0.29480266886 : correct_guesses 537
# iteration 53 : cost 0.294062775477 : correct_guesses 537
# iteration 54 : cost 0.293338786349 : correct_guesses 537
# iteration 55 : cost 0.292630210253 : correct_guesses 537
# iteration 56 : cost 0.291936582647 : correct_guesses 537
# iteration 57 : cost 0.291257462874 : correct_guesses 537
# iteration 58 : cost 0.290592431781 : correct_guesses 537
# iteration 59 : cost 0.2899410897 : correct_guesses 537
# iteration 60 : cost 0.289303054717 : correct_guesses 537
# iteration 61 : cost 0.288677961181 : correct_guesses 537
# iteration 62 : cost 0.288065458422 : correct_guesses 537
# iteration 63 : cost 0.287465209635 : correct_guesses 537
# iteration 64 : cost 0.286876890904 : correct_guesses 537
# iteration 65 : cost 0.286300190343 : correct_guesses 537
# iteration 66 : cost 0.285734807347 : correct_guesses 537
# iteration 67 : cost 0.285180451912 : correct_guesses 537
# iteration 68 : cost 0.284636844038 : correct_guesses 538
# iteration 69 : cost 0.284103713189 : correct_guesses 538
# iteration 70 : cost 0.283580797803 : correct_guesses 538
# iteration 71 : cost 0.283067844848 : correct_guesses 538
# iteration 72 : cost 0.282564609419 : correct_guesses 538
# iteration 73 : cost 0.282070854359 : correct_guesses 539
# iteration 74 : cost 0.281586349922 : correct_guesses 539
# iteration 75 : cost 0.281110873453 : correct_guesses 539
# iteration 76 : cost 0.280644209086 : correct_guesses 539
# iteration 77 : cost 0.280186147474 : correct_guesses 539
# iteration 78 : cost 0.279736485529 : correct_guesses 539
# iteration 79 : cost 0.279295026173 : correct_guesses 539
# iteration 80 : cost 0.278861578115 : correct_guesses 539
# iteration 81 : cost 0.27843595563 : correct_guesses 540
# iteration 82 : cost 0.278017978355 : correct_guesses 540
# iteration 83 : cost 0.277607471096 : correct_guesses 541
# iteration 84 : cost 0.277204263639 : correct_guesses 541
# iteration 85 : cost 0.276808190578 : correct_guesses 541
# iteration 86 : cost 0.276419091147 : correct_guesses 541
# iteration 87 : cost 0.276036809054 : correct_guesses 542
# iteration 88 : cost 0.275661192337 : correct_guesses 542
# iteration 89 : cost 0.27529209321 : correct_guesses 542
# iteration 90 : cost 0.274929367928 : correct_guesses 542
# iteration 91 : cost 0.27457287665 : correct_guesses 542
# iteration 92 : cost 0.27422248331 : correct_guesses 542
# iteration 93 : cost 0.273878055496 : correct_guesses 542
# iteration 94 : cost 0.273539464331 : correct_guesses 542
# iteration 95 : cost 0.273206584356 : correct_guesses 543
# iteration 96 : cost 0.272879293424 : correct_guesses 543
# iteration 97 : cost 0.272557472596 : correct_guesses 543
# iteration 98 : cost 0.272241006033 : correct_guesses 543
# iteration 99 : cost 0.271929780907 : correct_guesses 543
# iteration 100 : cost 0.271623687304 : correct_guesses 543
# iteration 101 : cost 0.27132261813 : correct_guesses 543
# iteration 102 : cost 0.27102646903 : correct_guesses 544
# iteration 103 : cost 0.270735138302 : correct_guesses 544
# iteration 104 : cost 0.270448526815 : correct_guesses 544
# iteration 105 : cost 0.270166537932 : correct_guesses 544
# iteration 106 : cost 0.269889077436 : correct_guesses 544
# iteration 107 : cost 0.269616053457 : correct_guesses 544
# iteration 108 : cost 0.269347376402 : correct_guesses 544
# iteration 109 : cost 0.269082958888 : correct_guesses 544
# iteration 110 : cost 0.268822715674 : correct_guesses 544
# iteration 111 : cost 0.268566563604 : correct_guesses 544
# iteration 112 : cost 0.268314421543 : correct_guesses 544
# iteration 113 : cost 0.268066210316 : correct_guesses 544
# iteration 114 : cost 0.267821852656 : correct_guesses 544
# iteration 115 : cost 0.267581273148 : correct_guesses 544
# iteration 116 : cost 0.267344398174 : correct_guesses 544
# iteration 117 : cost 0.267111155864 : correct_guesses 544
# iteration 118 : cost 0.266881476045 : correct_guesses 544
# iteration 119 : cost 0.266655290197 : correct_guesses 544
# iteration 120 : cost 0.266432531402 : correct_guesses 544
# iteration 121 : cost 0.266213134301 : correct_guesses 544
# iteration 122 : cost 0.265997035053 : correct_guesses 544
# iteration 123 : cost 0.265784171291 : correct_guesses 544
# iteration 124 : cost 0.26557448208 : correct_guesses 544
# iteration 125 : cost 0.265367907882 : correct_guesses 544
# iteration 126 : cost 0.265164390515 : correct_guesses 544
# iteration 127 : cost 0.264963873118 : correct_guesses 544
# iteration 128 : cost 0.264766300112 : correct_guesses 545
# iteration 129 : cost 0.264571617171 : correct_guesses 546
# iteration 130 : cost 0.264379771184 : correct_guesses 547
# iteration 131 : cost 0.264190710224 : correct_guesses 548
# iteration 132 : cost 0.264004383519 : correct_guesses 548
# iteration 133 : cost 0.263820741417 : correct_guesses 548
# iteration 134 : cost 0.263639735361 : correct_guesses 548
# iteration 135 : cost 0.263461317859 : correct_guesses 549
# iteration 136 : cost 0.263285442454 : correct_guesses 548
# iteration 137 : cost 0.263112063701 : correct_guesses 548
# iteration 138 : cost 0.262941137137 : correct_guesses 548
# iteration 139 : cost 0.26277261926 : correct_guesses 548
# iteration 140 : cost 0.262606467502 : correct_guesses 548
# iteration 141 : cost 0.262442640205 : correct_guesses 548
# iteration 142 : cost 0.262281096597 : correct_guesses 548
# iteration 143 : cost 0.262121796775 : correct_guesses 548
# iteration 144 : cost 0.261964701675 : correct_guesses 548
# iteration 145 : cost 0.261809773058 : correct_guesses 548
# iteration 146 : cost 0.261656973486 : correct_guesses 548
# iteration 147 : cost 0.261506266303 : correct_guesses 548
# iteration 148 : cost 0.261357615616 : correct_guesses 548
# iteration 149 : cost 0.261210986275 : correct_guesses 548
# iteration 150 : cost 0.261066343857 : correct_guesses 548
# iteration 151 : cost 0.260923654644 : correct_guesses 548
# iteration 152 : cost 0.260782885612 : correct_guesses 548
# iteration 153 : cost 0.260644004409 : correct_guesses 548
# iteration 154 : cost 0.26050697934 : correct_guesses 548
# iteration 155 : cost 0.260371779356 : correct_guesses 548
# iteration 156 : cost 0.260238374029 : correct_guesses 548
# iteration 157 : cost 0.260106733546 : correct_guesses 548
# iteration 158 : cost 0.25997682869 : correct_guesses 548
# iteration 159 : cost 0.259848630828 : correct_guesses 548
# iteration 160 : cost 0.259722111895 : correct_guesses 548
# iteration 161 : cost 0.259597244382 : correct_guesses 548
# iteration 162 : cost 0.259474001324 : correct_guesses 548
# iteration 163 : cost 0.259352356284 : correct_guesses 548
# iteration 164 : cost 0.259232283347 : correct_guesses 548
# iteration 165 : cost 0.259113757099 : correct_guesses 548
# iteration 166 : cost 0.258996752623 : correct_guesses 548
# iteration 167 : cost 0.258881245486 : correct_guesses 548
# iteration 168 : cost 0.258767211724 : correct_guesses 548
# iteration 169 : cost 0.258654627837 : correct_guesses 548
# iteration 170 : cost 0.258543470774 : correct_guesses 547
# iteration 171 : cost 0.258433717925 : correct_guesses 547
# iteration 172 : cost 0.25832534711 : correct_guesses 547
# iteration 173 : cost 0.258218336572 : correct_guesses 547
# iteration 174 : cost 0.258112664963 : correct_guesses 547
# iteration 175 : cost 0.258008311339 : correct_guesses 547
# iteration 176 : cost 0.257905255148 : correct_guesses 548
# iteration 177 : cost 0.257803476226 : correct_guesses 548
# iteration 178 : cost 0.257702954781 : correct_guesses 548
# iteration 179 : cost 0.257603671391 : correct_guesses 548
# iteration 180 : cost 0.257505606995 : correct_guesses 548
# iteration 181 : cost 0.257408742882 : correct_guesses 548
# iteration 182 : cost 0.257313060688 : correct_guesses 548
# iteration 183 : cost 0.257218542382 : correct_guesses 548
# iteration 184 : cost 0.257125170268 : correct_guesses 548
# iteration 185 : cost 0.257032926967 : correct_guesses 548
# iteration 186 : cost 0.256941795421 : correct_guesses 548
# iteration 187 : cost 0.256851758876 : correct_guesses 549
# iteration 188 : cost 0.256762800885 : correct_guesses 549
# iteration 189 : cost 0.256674905294 : correct_guesses 549
# iteration 190 : cost 0.256588056239 : correct_guesses 549
# iteration 191 : cost 0.25650223814 : correct_guesses 549
# iteration 192 : cost 0.256417435696 : correct_guesses 549
# iteration 193 : cost 0.256333633876 : correct_guesses 549
# iteration 194 : cost 0.256250817916 : correct_guesses 549
# iteration 195 : cost 0.256168973312 : correct_guesses 550
# iteration 196 : cost 0.256088085816 : correct_guesses 550
# iteration 197 : cost 0.256008141429 : correct_guesses 550
# iteration 198 : cost 0.255929126398 : correct_guesses 550
# iteration 199 : cost 0.25585102721 : correct_guesses 550
# iteration 200 : cost 0.255773830584 : correct_guesses 550
# iteration 201 : cost 0.255697523474 : correct_guesses 550
# iteration 202 : cost 0.255622093054 : correct_guesses 550
# iteration 203 : cost 0.255547526724 : correct_guesses 550
# iteration 204 : cost 0.255473812095 : correct_guesses 550
# iteration 205 : cost 0.255400936995 : correct_guesses 550
# iteration 206 : cost 0.255328889458 : correct_guesses 550
# iteration 207 : cost 0.25525765772 : correct_guesses 550
# iteration 208 : cost 0.255187230218 : correct_guesses 550
# iteration 209 : cost 0.255117595586 : correct_guesses 550
# iteration 210 : cost 0.255048742646 : correct_guesses 550
# iteration 211 : cost 0.254980660412 : correct_guesses 550
# iteration 212 : cost 0.254913338079 : correct_guesses 550
# iteration 213 : cost 0.254846765026 : correct_guesses 550
# iteration 214 : cost 0.254780930805 : correct_guesses 550
# iteration 215 : cost 0.254715825144 : correct_guesses 550
# iteration 216 : cost 0.254651437943 : correct_guesses 551
# iteration 217 : cost 0.254587759264 : correct_guesses 551
# iteration 218 : cost 0.254524779338 : correct_guesses 551
# iteration 219 : cost 0.254462488553 : correct_guesses 551
# iteration 220 : cost 0.254400877456 : correct_guesses 551
# iteration 221 : cost 0.254339936748 : correct_guesses 551
# iteration 222 : cost 0.254279657282 : correct_guesses 551
# iteration 223 : cost 0.254220030059 : correct_guesses 551
# iteration 224 : cost 0.254161046226 : correct_guesses 551
# iteration 225 : cost 0.254102697073 : correct_guesses 551
# iteration 226 : cost 0.254044974031 : correct_guesses 551
# iteration 227 : cost 0.253987868668 : correct_guesses 551
# iteration 228 : cost 0.253931372688 : correct_guesses 551
# iteration 229 : cost 0.253875477925 : correct_guesses 551
# iteration 230 : cost 0.253820176346 : correct_guesses 551
# iteration 231 : cost 0.253765460044 : correct_guesses 551
# iteration 232 : cost 0.25371132124 : correct_guesses 551
# iteration 233 : cost 0.253657752273 : correct_guesses 551
# iteration 234 : cost 0.253604745609 : correct_guesses 551
# iteration 235 : cost 0.253552293826 : correct_guesses 551
# iteration 236 : cost 0.253500389624 : correct_guesses 551
# iteration 237 : cost 0.253449025813 : correct_guesses 551
# iteration 238 : cost 0.253398195319 : correct_guesses 551
# iteration 239 : cost 0.253347891174 : correct_guesses 551
# iteration 240 : cost 0.25329810652 : correct_guesses 551
# iteration 241 : cost 0.253248834607 : correct_guesses 551
# iteration 242 : cost 0.253200068786 : correct_guesses 551
# iteration 243 : cost 0.253151802512 : correct_guesses 551
# iteration 244 : cost 0.253104029341 : correct_guesses 551
# iteration 245 : cost 0.253056742926 : correct_guesses 551
# iteration 246 : cost 0.253009937019 : correct_guesses 551
# iteration 247 : cost 0.252963605465 : correct_guesses 551
# iteration 248 : cost 0.252917742204 : correct_guesses 551
# iteration 249 : cost 0.252872341269 : correct_guesses 551
# iteration 250 : cost 0.25282739678 : correct_guesses 551
# iteration 251 : cost 0.252782902948 : correct_guesses 551
# iteration 252 : cost 0.252738854071 : correct_guesses 551
# iteration 253 : cost 0.252695244532 : correct_guesses 551
# iteration 254 : cost 0.252652068799 : correct_guesses 551
# iteration 255 : cost 0.252609321421 : correct_guesses 551
# iteration 256 : cost 0.252566997029 : correct_guesses 551
# iteration 257 : cost 0.252525090335 : correct_guesses 551
# iteration 258 : cost 0.252483596127 : correct_guesses 551
# iteration 259 : cost 0.252442509273 : correct_guesses 551
# iteration 260 : cost 0.252401824714 : correct_guesses 551
# iteration 261 : cost 0.252361537466 : correct_guesses 551
# iteration 262 : cost 0.252321642621 : correct_guesses 551
# iteration 263 : cost 0.252282135338 : correct_guesses 551
# iteration 264 : cost 0.252243010851 : correct_guesses 551
# iteration 265 : cost 0.252204264462 : correct_guesses 551
# iteration 266 : cost 0.25216589154 : correct_guesses 551
# iteration 267 : cost 0.252127887522 : correct_guesses 551
# iteration 268 : cost 0.252090247913 : correct_guesses 551
# iteration 269 : cost 0.252052968281 : correct_guesses 551
# iteration 270 : cost 0.252016044257 : correct_guesses 551
# iteration 271 : cost 0.251979471536 : correct_guesses 551
# iteration 272 : cost 0.251943245876 : correct_guesses 551
# iteration 273 : cost 0.251907363093 : correct_guesses 551
# iteration 274 : cost 0.251871819064 : correct_guesses 550
# iteration 275 : cost 0.251836609725 : correct_guesses 550
# iteration 276 : cost 0.25180173107 : correct_guesses 550
# iteration 277 : cost 0.251767179149 : correct_guesses 550
# iteration 278 : cost 0.251732950067 : correct_guesses 550
# iteration 279 : cost 0.251699039985 : correct_guesses 550
# iteration 280 : cost 0.25166544512 : correct_guesses 550
# iteration 281 : cost 0.251632161738 : correct_guesses 550
# iteration 282 : cost 0.251599186161 : correct_guesses 550
# iteration 283 : cost 0.25156651476 : correct_guesses 550
# iteration 284 : cost 0.251534143958 : correct_guesses 550
# iteration 285 : cost 0.251502070227 : correct_guesses 550
# iteration 286 : cost 0.251470290089 : correct_guesses 550
# iteration 287 : cost 0.251438800112 : correct_guesses 550
# iteration 288 : cost 0.251407596915 : correct_guesses 550
# iteration 289 : cost 0.25137667716 : correct_guesses 550
# iteration 290 : cost 0.251346037557 : correct_guesses 550
# iteration 291 : cost 0.251315674862 : correct_guesses 550
# iteration 292 : cost 0.251285585872 : correct_guesses 551
# iteration 293 : cost 0.251255767431 : correct_guesses 551
# iteration 294 : cost 0.251226216426 : correct_guesses 551
# iteration 295 : cost 0.251196929784 : correct_guesses 551
# iteration 296 : cost 0.251167904476 : correct_guesses 551
# iteration 297 : cost 0.251139137514 : correct_guesses 551
# iteration 298 : cost 0.251110625948 : correct_guesses 551
# iteration 299 : cost 0.251082366871 : correct_guesses 551
# iteration 300 : cost 0.251054357413 : correct_guesses 551
# iteration 301 : cost 0.251026594743 : correct_guesses 551
# iteration 302 : cost 0.25099907607 : correct_guesses 551
# iteration 303 : cost 0.250971798636 : correct_guesses 551
# iteration 304 : cost 0.250944759725 : correct_guesses 551
# iteration 305 : cost 0.250917956653 : correct_guesses 551
# iteration 306 : cost 0.250891386775 : correct_guesses 551
# iteration 307 : cost 0.250865047478 : correct_guesses 551
# iteration 308 : cost 0.250838936185 : correct_guesses 551
# iteration 309 : cost 0.250813050355 : correct_guesses 551
# iteration 310 : cost 0.250787387477 : correct_guesses 551
# iteration 311 : cost 0.250761945075 : correct_guesses 551
# iteration 312 : cost 0.250736720707 : correct_guesses 551
# iteration 313 : cost 0.250711711959 : correct_guesses 551
# iteration 314 : cost 0.250686916453 : correct_guesses 551
# iteration 315 : cost 0.250662331839 : correct_guesses 551
# iteration 316 : cost 0.250637955798 : correct_guesses 551
# iteration 317 : cost 0.250613786043 : correct_guesses 551
# iteration 318 : cost 0.250589820315 : correct_guesses 551
# iteration 319 : cost 0.250566056385 : correct_guesses 551
# iteration 320 : cost 0.250542492053 : correct_guesses 551
# iteration 321 : cost 0.250519125145 : correct_guesses 551
# iteration 322 : cost 0.250495953519 : correct_guesses 551
# iteration 323 : cost 0.250472975058 : correct_guesses 551
# iteration 324 : cost 0.250450187673 : correct_guesses 551
# iteration 325 : cost 0.2504275893 : correct_guesses 551
# iteration 326 : cost 0.250405177905 : correct_guesses 551
# iteration 327 : cost 0.250382951476 : correct_guesses 551
# iteration 328 : cost 0.250360908028 : correct_guesses 551
# iteration 329 : cost 0.250339045603 : correct_guesses 551
# iteration 330 : cost 0.250317362266 : correct_guesses 551
# iteration 331 : cost 0.250295856106 : correct_guesses 551
# iteration 332 : cost 0.250274525238 : correct_guesses 551
# iteration 333 : cost 0.2502533678 : correct_guesses 551
# iteration 334 : cost 0.250232381952 : correct_guesses 551
# iteration 335 : cost 0.250211565879 : correct_guesses 551
# iteration 336 : cost 0.250190917788 : correct_guesses 550
# iteration 337 : cost 0.250170435908 : correct_guesses 550
# iteration 338 : cost 0.250150118492 : correct_guesses 551
# iteration 339 : cost 0.250129963812 : correct_guesses 551
# iteration 340 : cost 0.250109970163 : correct_guesses 551
# iteration 341 : cost 0.250090135862 : correct_guesses 551
# iteration 342 : cost 0.250070459245 : correct_guesses 551
# iteration 343 : cost 0.25005093867 : correct_guesses 551
# iteration 344 : cost 0.250031572514 : correct_guesses 551
# iteration 345 : cost 0.250012359176 : correct_guesses 551
# iteration 346 : cost 0.249993297073 : correct_guesses 551
# iteration 347 : cost 0.249974384641 : correct_guesses 551
# iteration 348 : cost 0.249955620337 : correct_guesses 551
# iteration 349 : cost 0.249937002636 : correct_guesses 551
# iteration 350 : cost 0.249918530031 : correct_guesses 552
# iteration 351 : cost 0.249900201035 : correct_guesses 552
# iteration 352 : cost 0.249882014177 : correct_guesses 552
# iteration 353 : cost 0.249863968005 : correct_guesses 552
# iteration 354 : cost 0.249846061085 : correct_guesses 552
# iteration 355 : cost 0.249828291999 : correct_guesses 552
# iteration 356 : cost 0.249810659348 : correct_guesses 552
# iteration 357 : cost 0.249793161749 : correct_guesses 552
# iteration 358 : cost 0.249775797835 : correct_guesses 552
# iteration 359 : cost 0.249758566255 : correct_guesses 552
# iteration 360 : cost 0.249741465677 : correct_guesses 552
# iteration 361 : cost 0.249724494782 : correct_guesses 552
# iteration 362 : cost 0.249707652268 : correct_guesses 552
# iteration 363 : cost 0.249690936849 : correct_guesses 552
# iteration 364 : cost 0.249674347253 : correct_guesses 552
# iteration 365 : cost 0.249657882224 : correct_guesses 552
# iteration 366 : cost 0.24964154052 : correct_guesses 552
# iteration 367 : cost 0.249625320916 : correct_guesses 552
# iteration 368 : cost 0.249609222199 : correct_guesses 552
# iteration 369 : cost 0.249593243172 : correct_guesses 552
# iteration 370 : cost 0.249577382651 : correct_guesses 552
# iteration 371 : cost 0.249561639465 : correct_guesses 552
# iteration 372 : cost 0.24954601246 : correct_guesses 552
# iteration 373 : cost 0.249530500493 : correct_guesses 552
# iteration 374 : cost 0.249515102435 : correct_guesses 552
# iteration 375 : cost 0.249499817169 : correct_guesses 552
# iteration 376 : cost 0.249484643594 : correct_guesses 552
# iteration 377 : cost 0.249469580619 : correct_guesses 552
# iteration 378 : cost 0.249454627166 : correct_guesses 552
# iteration 379 : cost 0.249439782172 : correct_guesses 552
# iteration 380 : cost 0.249425044584 : correct_guesses 552
# iteration 381 : cost 0.24941041336 : correct_guesses 552
# iteration 382 : cost 0.249395887474 : correct_guesses 552
# iteration 383 : cost 0.249381465909 : correct_guesses 552
# iteration 384 : cost 0.249367147659 : correct_guesses 552
# iteration 385 : cost 0.249352931732 : correct_guesses 552
# iteration 386 : cost 0.249338817146 : correct_guesses 552
# iteration 387 : cost 0.24932480293 : correct_guesses 552
# iteration 388 : cost 0.249310888125 : correct_guesses 552
# iteration 389 : cost 0.249297071783 : correct_guesses 552
# iteration 390 : cost 0.249283352965 : correct_guesses 552
# iteration 391 : cost 0.249269730746 : correct_guesses 552
# iteration 392 : cost 0.249256204207 : correct_guesses 552
# iteration 393 : cost 0.249242772443 : correct_guesses 552
# iteration 394 : cost 0.249229434559 : correct_guesses 552
# iteration 395 : cost 0.249216189668 : correct_guesses 552
# iteration 396 : cost 0.249203036895 : correct_guesses 552
# iteration 397 : cost 0.249189975373 : correct_guesses 552
# iteration 398 : cost 0.249177004248 : correct_guesses 552
# iteration 399 : cost 0.249164122671 : correct_guesses 552
# iteration 400 : cost 0.249151329807 : correct_guesses 552
# iteration 401 : cost 0.249138624828 : correct_guesses 552
# iteration 402 : cost 0.249126006914 : correct_guesses 552
# iteration 403 : cost 0.249113475257 : correct_guesses 552
# iteration 404 : cost 0.249101029057 : correct_guesses 552
# iteration 405 : cost 0.249088667522 : correct_guesses 552
# iteration 406 : cost 0.249076389869 : correct_guesses 552
# iteration 407 : cost 0.249064195325 : correct_guesses 552
# iteration 408 : cost 0.249052083125 : correct_guesses 552
# iteration 409 : cost 0.24904005251 : correct_guesses 552
# iteration 410 : cost 0.249028102734 : correct_guesses 552
# iteration 411 : cost 0.249016233055 : correct_guesses 552
# iteration 412 : cost 0.249004442741 : correct_guesses 552
# iteration 413 : cost 0.248992731068 : correct_guesses 552
# iteration 414 : cost 0.248981097321 : correct_guesses 552
# iteration 415 : cost 0.24896954079 : correct_guesses 552
# iteration 416 : cost 0.248958060775 : correct_guesses 552
# iteration 417 : cost 0.248946656583 : correct_guesses 552
# iteration 418 : cost 0.248935327529 : correct_guesses 552
# iteration 419 : cost 0.248924072934 : correct_guesses 552
# iteration 420 : cost 0.248912892129 : correct_guesses 552
# iteration 421 : cost 0.248901784449 : correct_guesses 552
# iteration 422 : cost 0.248890749239 : correct_guesses 552
# iteration 423 : cost 0.248879785849 : correct_guesses 552
# iteration 424 : cost 0.248868893638 : correct_guesses 552
# iteration 425 : cost 0.248858071969 : correct_guesses 552
# iteration 426 : cost 0.248847320216 : correct_guesses 552
# iteration 427 : cost 0.248836637757 : correct_guesses 552
# iteration 428 : cost 0.248826023975 : correct_guesses 552
# iteration 429 : cost 0.248815478265 : correct_guesses 552
# iteration 430 : cost 0.248805000022 : correct_guesses 552
# iteration 431 : cost 0.248794588652 : correct_guesses 552
# iteration 432 : cost 0.248784243567 : correct_guesses 552
# iteration 433 : cost 0.248773964182 : correct_guesses 552
# iteration 434 : cost 0.248763749922 : correct_guesses 553
# iteration 435 : cost 0.248753600217 : correct_guesses 553
# iteration 436 : cost 0.248743514501 : correct_guesses 553
# iteration 437 : cost 0.248733492216 : correct_guesses 553
# iteration 438 : cost 0.24872353281 : correct_guesses 553
# iteration 439 : cost 0.248713635737 : correct_guesses 553
# iteration 440 : cost 0.248703800454 : correct_guesses 553
# iteration 441 : cost 0.248694026427 : correct_guesses 553
# iteration 442 : cost 0.248684313126 : correct_guesses 553
# iteration 443 : cost 0.248674660027 : correct_guesses 553
# iteration 444 : cost 0.248665066612 : correct_guesses 553
# iteration 445 : cost 0.248655532367 : correct_guesses 553
# iteration 446 : cost 0.248646056784 : correct_guesses 553
# iteration 447 : cost 0.248636639362 : correct_guesses 553
# iteration 448 : cost 0.248627279601 : correct_guesses 553
# iteration 449 : cost 0.248617977011 : correct_guesses 553
# iteration 450 : cost 0.248608731105 : correct_guesses 553
# iteration 451 : cost 0.248599541399 : correct_guesses 553
# iteration 452 : cost 0.248590407418 : correct_guesses 553
# iteration 453 : cost 0.248581328689 : correct_guesses 553
# iteration 454 : cost 0.248572304746 : correct_guesses 553
# iteration 455 : cost 0.248563335124 : correct_guesses 553
# iteration 456 : cost 0.248554419368 : correct_guesses 553
# iteration 457 : cost 0.248545557023 : correct_guesses 553
# iteration 458 : cost 0.248536747643 : correct_guesses 553
# iteration 459 : cost 0.248527990782 : correct_guesses 553
# iteration 460 : cost 0.248519286001 : correct_guesses 553
# iteration 461 : cost 0.248510632867 : correct_guesses 553
# iteration 462 : cost 0.248502030949 : correct_guesses 553
# iteration 463 : cost 0.24849347982 : correct_guesses 553
# iteration 464 : cost 0.248484979059 : correct_guesses 553
# iteration 465 : cost 0.24847652825 : correct_guesses 553
# iteration 466 : cost 0.248468126978 : correct_guesses 553
# iteration 467 : cost 0.248459774835 : correct_guesses 553
# iteration 468 : cost 0.248451471416 : correct_guesses 553
# iteration 469 : cost 0.248443216321 : correct_guesses 553
# iteration 470 : cost 0.248435009153 : correct_guesses 553
# iteration 471 : cost 0.248426849519 : correct_guesses 553
# iteration 472 : cost 0.24841873703 : correct_guesses 553
# iteration 473 : cost 0.248410671302 : correct_guesses 553
# iteration 474 : cost 0.248402651954 : correct_guesses 553
# iteration 475 : cost 0.248394678609 : correct_guesses 553
# iteration 476 : cost 0.248386750892 : correct_guesses 553
# iteration 477 : cost 0.248378868435 : correct_guesses 553
# iteration 478 : cost 0.248371030872 : correct_guesses 553
# iteration 479 : cost 0.24836323784 : correct_guesses 553
# iteration 480 : cost 0.24835548898 : correct_guesses 553
# iteration 481 : cost 0.248347783937 : correct_guesses 553
# iteration 482 : cost 0.24834012236 : correct_guesses 553
# iteration 483 : cost 0.248332503901 : correct_guesses 553
# iteration 484 : cost 0.248324928213 : correct_guesses 553
# iteration 485 : cost 0.248317394958 : correct_guesses 553
# iteration 486 : cost 0.248309903795 : correct_guesses 553
# iteration 487 : cost 0.248302454391 : correct_guesses 553
# iteration 488 : cost 0.248295046414 : correct_guesses 553
# iteration 489 : cost 0.248287679536 : correct_guesses 553
# iteration 490 : cost 0.248280353432 : correct_guesses 553
# iteration 491 : cost 0.24827306778 : correct_guesses 553
# iteration 492 : cost 0.248265822262 : correct_guesses 553
# iteration 493 : cost 0.248258616562 : correct_guesses 553
# iteration 494 : cost 0.248251450368 : correct_guesses 553
# iteration 495 : cost 0.24824432337 : correct_guesses 553
# iteration 496 : cost 0.248237235261 : correct_guesses 553
# iteration 497 : cost 0.248230185739 : correct_guesses 553
# iteration 498 : cost 0.248223174503 : correct_guesses 553
# iteration 499 : cost 0.248216201255 : correct_guesses 553
# iteration 500 : cost 0.2482092657 : correct_guesses 553
# iteration 501 : cost 0.248202367547 : correct_guesses 553
# iteration 502 : cost 0.248195506507 : correct_guesses 553
# iteration 503 : cost 0.248188682292 : correct_guesses 553
# iteration 504 : cost 0.24818189462 : correct_guesses 553
# iteration 505 : cost 0.24817514321 : correct_guesses 553
# iteration 506 : cost 0.248168427784 : correct_guesses 553
# iteration 507 : cost 0.248161748065 : correct_guesses 553
# iteration 508 : cost 0.248155103782 : correct_guesses 553
# iteration 509 : cost 0.248148494663 : correct_guesses 553
# iteration 510 : cost 0.248141920441 : correct_guesses 553
# iteration 511 : cost 0.248135380852 : correct_guesses 553
# iteration 512 : cost 0.248128875631 : correct_guesses 553
# iteration 513 : cost 0.24812240452 : correct_guesses 553
# iteration 514 : cost 0.24811596726 : correct_guesses 553
# iteration 515 : cost 0.248109563596 : correct_guesses 553
# iteration 516 : cost 0.248103193275 : correct_guesses 553
# iteration 517 : cost 0.248096856047 : correct_guesses 553
# iteration 518 : cost 0.248090551664 : correct_guesses 553
# iteration 519 : cost 0.248084279879 : correct_guesses 553
# iteration 520 : cost 0.248078040449 : correct_guesses 553
# iteration 521 : cost 0.248071833134 : correct_guesses 553
# iteration 522 : cost 0.248065657693 : correct_guesses 553
# iteration 523 : cost 0.248059513891 : correct_guesses 553
# iteration 524 : cost 0.248053401492 : correct_guesses 553
# iteration 525 : cost 0.248047320265 : correct_guesses 553
# iteration 526 : cost 0.248041269979 : correct_guesses 553
# iteration 527 : cost 0.248035250406 : correct_guesses 553
# iteration 528 : cost 0.248029261321 : correct_guesses 553
# iteration 529 : cost 0.248023302498 : correct_guesses 553
# iteration 530 : cost 0.248017373718 : correct_guesses 553
# iteration 531 : cost 0.248011474758 : correct_guesses 553
# iteration 532 : cost 0.248005605403 : correct_guesses 553
# iteration 533 : cost 0.247999765437 : correct_guesses 553
# iteration 534 : cost 0.247993954645 : correct_guesses 553
# iteration 535 : cost 0.247988172816 : correct_guesses 553
# iteration 536 : cost 0.24798241974 : correct_guesses 553
# iteration 537 : cost 0.247976695209 : correct_guesses 553
# iteration 538 : cost 0.247970999017 : correct_guesses 553
# iteration 539 : cost 0.24796533096 : correct_guesses 553
# iteration 540 : cost 0.247959690836 : correct_guesses 553
# iteration 541 : cost 0.247954078445 : correct_guesses 553
# iteration 542 : cost 0.247948493587 : correct_guesses 553
# iteration 543 : cost 0.247942936066 : correct_guesses 553
# iteration 544 : cost 0.247937405686 : correct_guesses 553
# iteration 545 : cost 0.247931902256 : correct_guesses 553
# iteration 546 : cost 0.247926425582 : correct_guesses 553
# iteration 547 : cost 0.247920975476 : correct_guesses 553
# iteration 548 : cost 0.247915551749 : correct_guesses 553
# iteration 549 : cost 0.247910154215 : correct_guesses 553
# iteration 550 : cost 0.24790478269 : correct_guesses 553
# iteration 551 : cost 0.247899436989 : correct_guesses 553
# iteration 552 : cost 0.247894116932 : correct_guesses 553
# iteration 553 : cost 0.247888822339 : correct_guesses 553
# iteration 554 : cost 0.247883553032 : correct_guesses 553
# iteration 555 : cost 0.247878308834 : correct_guesses 553
# iteration 556 : cost 0.24787308957 : correct_guesses 553
# iteration 557 : cost 0.247867895067 : correct_guesses 553
# iteration 558 : cost 0.247862725152 : correct_guesses 553
# iteration 559 : cost 0.247857579656 : correct_guesses 553
# iteration 560 : cost 0.247852458409 : correct_guesses 553
# iteration 561 : cost 0.247847361245 : correct_guesses 553
# iteration 562 : cost 0.247842287996 : correct_guesses 553
# iteration 563 : cost 0.2478372385 : correct_guesses 553
# iteration 564 : cost 0.247832212592 : correct_guesses 553
# iteration 565 : cost 0.247827210111 : correct_guesses 553
# iteration 566 : cost 0.247822230897 : correct_guesses 553
# iteration 567 : cost 0.247817274791 : correct_guesses 553
# iteration 568 : cost 0.247812341636 : correct_guesses 553
# iteration 569 : cost 0.247807431277 : correct_guesses 553
# iteration 570 : cost 0.247802543557 : correct_guesses 553
# iteration 571 : cost 0.247797678324 : correct_guesses 553
# iteration 572 : cost 0.247792835427 : correct_guesses 553
# iteration 573 : cost 0.247788014713 : correct_guesses 553
# iteration 574 : cost 0.247783216035 : correct_guesses 553
# iteration 575 : cost 0.247778439245 : correct_guesses 553
# iteration 576 : cost 0.247773684194 : correct_guesses 553
# iteration 577 : cost 0.247768950738 : correct_guesses 553
# iteration 578 : cost 0.247764238733 : correct_guesses 553
# iteration 579 : cost 0.247759548036 : correct_guesses 553
# iteration 580 : cost 0.247754878505 : correct_guesses 553
# iteration 581 : cost 0.247750229999 : correct_guesses 553
# iteration 582 : cost 0.24774560238 : correct_guesses 553
# iteration 583 : cost 0.247740995508 : correct_guesses 553
# iteration 584 : cost 0.247736409247 : correct_guesses 553
# iteration 585 : cost 0.247731843462 : correct_guesses 553
# iteration 586 : cost 0.247727298018 : correct_guesses 553
# iteration 587 : cost 0.247722772781 : correct_guesses 553
# iteration 588 : cost 0.247718267618 : correct_guesses 553
# iteration 589 : cost 0.2477137824 : correct_guesses 553
# iteration 590 : cost 0.247709316995 : correct_guesses 553
# iteration 591 : cost 0.247704871275 : correct_guesses 553
# iteration 592 : cost 0.247700445111 : correct_guesses 553
# iteration 593 : cost 0.247696038377 : correct_guesses 553
# iteration 594 : cost 0.247691650948 : correct_guesses 553
# iteration 595 : cost 0.247687282698 : correct_guesses 553
# iteration 596 : cost 0.247682933504 : correct_guesses 553
# iteration 597 : cost 0.247678603243 : correct_guesses 553
# iteration 598 : cost 0.247674291794 : correct_guesses 553
# iteration 599 : cost 0.247669999036 : correct_guesses 553
# iteration 600 : cost 0.247665724849 : correct_guesses 553
# iteration 601 : cost 0.247661469116 : correct_guesses 553
# iteration 602 : cost 0.247657231718 : correct_guesses 553
# iteration 603 : cost 0.247653012538 : correct_guesses 553
# iteration 604 : cost 0.247648811462 : correct_guesses 553
# iteration 605 : cost 0.247644628375 : correct_guesses 553
# iteration 606 : cost 0.247640463163 : correct_guesses 553
# iteration 607 : cost 0.247636315712 : correct_guesses 553
# iteration 608 : cost 0.247632185912 : correct_guesses 553
# iteration 609 : cost 0.247628073651 : correct_guesses 553
# iteration 610 : cost 0.24762397882 : correct_guesses 553
# iteration 611 : cost 0.247619901309 : correct_guesses 553
# iteration 612 : cost 0.24761584101 : correct_guesses 553
# iteration 613 : cost 0.247611797816 : correct_guesses 553
# iteration 614 : cost 0.24760777162 : correct_guesses 553
# iteration 615 : cost 0.247603762317 : correct_guesses 553
# iteration 616 : cost 0.247599769803 : correct_guesses 553
# iteration 617 : cost 0.247595793972 : correct_guesses 553
# iteration 618 : cost 0.247591834723 : correct_guesses 553
# iteration 619 : cost 0.247587891953 : correct_guesses 553
# iteration 620 : cost 0.24758396556 : correct_guesses 553
# iteration 621 : cost 0.247580055445 : correct_guesses 553
# iteration 622 : cost 0.247576161507 : correct_guesses 553
# iteration 623 : cost 0.247572283649 : correct_guesses 553
# iteration 624 : cost 0.24756842177 : correct_guesses 553
# iteration 625 : cost 0.247564575775 : correct_guesses 553
# iteration 626 : cost 0.247560745567 : correct_guesses 553
# iteration 627 : cost 0.24755693105 : correct_guesses 553
# iteration 628 : cost 0.247553132129 : correct_guesses 553
# iteration 629 : cost 0.247549348709 : correct_guesses 553
# iteration 630 : cost 0.247545580699 : correct_guesses 553
# iteration 631 : cost 0.247541828003 : correct_guesses 553
# iteration 632 : cost 0.247538090532 : correct_guesses 553
# iteration 633 : cost 0.247534368193 : correct_guesses 553
# iteration 634 : cost 0.247530660896 : correct_guesses 553
# iteration 635 : cost 0.247526968551 : correct_guesses 553
# iteration 636 : cost 0.247523291069 : correct_guesses 553
# iteration 637 : cost 0.247519628361 : correct_guesses 553
# iteration 638 : cost 0.247515980341 : correct_guesses 553
# iteration 639 : cost 0.247512346921 : correct_guesses 553
# iteration 640 : cost 0.247508728014 : correct_guesses 553
# iteration 641 : cost 0.247505123536 : correct_guesses 553
# iteration 642 : cost 0.2475015334 : correct_guesses 553
# iteration 643 : cost 0.247497957524 : correct_guesses 553
# iteration 644 : cost 0.247494395822 : correct_guesses 553
# iteration 645 : cost 0.247490848213 : correct_guesses 553
# iteration 646 : cost 0.247487314614 : correct_guesses 553
# iteration 647 : cost 0.247483794943 : correct_guesses 553
# iteration 648 : cost 0.247480289119 : correct_guesses 553
# iteration 649 : cost 0.247476797062 : correct_guesses 553
# iteration 650 : cost 0.247473318692 : correct_guesses 553
# iteration 651 : cost 0.247469853929 : correct_guesses 553
# iteration 652 : cost 0.247466402696 : correct_guesses 553
# iteration 653 : cost 0.247462964914 : correct_guesses 553
# iteration 654 : cost 0.247459540506 : correct_guesses 553
# iteration 655 : cost 0.247456129395 : correct_guesses 553
# iteration 656 : cost 0.247452731506 : correct_guesses 553
# iteration 657 : cost 0.247449346761 : correct_guesses 553
# iteration 658 : cost 0.247445975087 : correct_guesses 553
# iteration 659 : cost 0.247442616409 : correct_guesses 553
# iteration 660 : cost 0.247439270653 : correct_guesses 553
# iteration 661 : cost 0.247435937746 : correct_guesses 553
# iteration 662 : cost 0.247432617615 : correct_guesses 553
# iteration 663 : cost 0.247429310187 : correct_guesses 553
# iteration 664 : cost 0.247426015392 : correct_guesses 553
# iteration 665 : cost 0.247422733159 : correct_guesses 553
# iteration 666 : cost 0.247419463415 : correct_guesses 553
# iteration 667 : cost 0.247416206093 : correct_guesses 553
# iteration 668 : cost 0.247412961121 : correct_guesses 553
# iteration 669 : cost 0.247409728431 : correct_guesses 553
# iteration 670 : cost 0.247406507956 : correct_guesses 553
# iteration 671 : cost 0.247403299626 : correct_guesses 553
# iteration 672 : cost 0.247400103374 : correct_guesses 553
# iteration 673 : cost 0.247396919133 : correct_guesses 553
# iteration 674 : cost 0.247393746838 : correct_guesses 553
# iteration 675 : cost 0.247390586421 : correct_guesses 553
# iteration 676 : cost 0.247387437818 : correct_guesses 553
# iteration 677 : cost 0.247384300964 : correct_guesses 553
# iteration 678 : cost 0.247381175794 : correct_guesses 553
# iteration 679 : cost 0.247378062244 : correct_guesses 553
# iteration 680 : cost 0.247374960251 : correct_guesses 553
# iteration 681 : cost 0.247371869751 : correct_guesses 553
# iteration 682 : cost 0.247368790683 : correct_guesses 553
# iteration 683 : cost 0.247365722983 : correct_guesses 553
# iteration 684 : cost 0.247362666591 : correct_guesses 553
# iteration 685 : cost 0.247359621445 : correct_guesses 553
# iteration 686 : cost 0.247356587484 : correct_guesses 553
# iteration 687 : cost 0.247353564648 : correct_guesses 553
# iteration 688 : cost 0.247350552878 : correct_guesses 553
# iteration 689 : cost 0.247347552113 : correct_guesses 553
# iteration 690 : cost 0.247344562295 : correct_guesses 553
# iteration 691 : cost 0.247341583365 : correct_guesses 553
# iteration 692 : cost 0.247338615265 : correct_guesses 553
# iteration 693 : cost 0.247335657937 : correct_guesses 553
# iteration 694 : cost 0.247332711324 : correct_guesses 553
# iteration 695 : cost 0.24732977537 : correct_guesses 553
# iteration 696 : cost 0.247326850017 : correct_guesses 553
# iteration 697 : cost 0.247323935209 : correct_guesses 553
# iteration 698 : cost 0.247321030892 : correct_guesses 553
# iteration 699 : cost 0.247318137009 : correct_guesses 553
# iteration 700 : cost 0.247315253506 : correct_guesses 553
# iteration 701 : cost 0.247312380328 : correct_guesses 553
# iteration 702 : cost 0.247309517422 : correct_guesses 553
# iteration 703 : cost 0.247306664733 : correct_guesses 553
# iteration 704 : cost 0.247303822208 : correct_guesses 553
# iteration 705 : cost 0.247300989794 : correct_guesses 553
# iteration 706 : cost 0.247298167439 : correct_guesses 553
# iteration 707 : cost 0.247295355091 : correct_guesses 553
# iteration 708 : cost 0.247292552697 : correct_guesses 553
# iteration 709 : cost 0.247289760207 : correct_guesses 553
# iteration 710 : cost 0.247286977568 : correct_guesses 553
# iteration 711 : cost 0.247284204731 : correct_guesses 553
# iteration 712 : cost 0.247281441646 : correct_guesses 553
# iteration 713 : cost 0.247278688261 : correct_guesses 553
# iteration 714 : cost 0.247275944528 : correct_guesses 553
# iteration 715 : cost 0.247273210396 : correct_guesses 553
# iteration 716 : cost 0.247270485818 : correct_guesses 553
# iteration 717 : cost 0.247267770744 : correct_guesses 553
# iteration 718 : cost 0.247265065127 : correct_guesses 553
# iteration 719 : cost 0.247262368917 : correct_guesses 553
# iteration 720 : cost 0.247259682069 : correct_guesses 553
# iteration 721 : cost 0.247257004533 : correct_guesses 553
# iteration 722 : cost 0.247254336264 : correct_guesses 553
# iteration 723 : cost 0.247251677215 : correct_guesses 553
# iteration 724 : cost 0.247249027339 : correct_guesses 553
# iteration 725 : cost 0.24724638659 : correct_guesses 553
# iteration 726 : cost 0.247243754923 : correct_guesses 553
# iteration 727 : cost 0.247241132293 : correct_guesses 553
# iteration 728 : cost 0.247238518653 : correct_guesses 553
# iteration 729 : cost 0.247235913961 : correct_guesses 553
# iteration 730 : cost 0.24723331817 : correct_guesses 553
# iteration 731 : cost 0.247230731237 : correct_guesses 553
# iteration 732 : cost 0.247228153119 : correct_guesses 553
# iteration 733 : cost 0.247225583771 : correct_guesses 553
# iteration 734 : cost 0.24722302315 : correct_guesses 553
# iteration 735 : cost 0.247220471214 : correct_guesses 553
# iteration 736 : cost 0.24721792792 : correct_guesses 553
# iteration 737 : cost 0.247215393225 : correct_guesses 553
# iteration 738 : cost 0.247212867087 : correct_guesses 553
# iteration 739 : cost 0.247210349465 : correct_guesses 553
# iteration 740 : cost 0.247207840317 : correct_guesses 553
# iteration 741 : cost 0.247205339601 : correct_guesses 553
# iteration 742 : cost 0.247202847277 : correct_guesses 553
# iteration 743 : cost 0.247200363304 : correct_guesses 553
# iteration 744 : cost 0.247197887642 : correct_guesses 553
# iteration 745 : cost 0.247195420251 : correct_guesses 553
# iteration 746 : cost 0.24719296109 : correct_guesses 553
# iteration 747 : cost 0.24719051012 : correct_guesses 553
# iteration 748 : cost 0.247188067302 : correct_guesses 553
# iteration 749 : cost 0.247185632596 : correct_guesses 553
# iteration 750 : cost 0.247183205964 : correct_guesses 553
# iteration 751 : cost 0.247180787367 : correct_guesses 553
# iteration 752 : cost 0.247178376767 : correct_guesses 553
# iteration 753 : cost 0.247175974126 : correct_guesses 553
# iteration 754 : cost 0.247173579406 : correct_guesses 553
# iteration 755 : cost 0.247171192569 : correct_guesses 553
# iteration 756 : cost 0.247168813578 : correct_guesses 553
# iteration 757 : cost 0.247166442396 : correct_guesses 553
# iteration 758 : cost 0.247164078986 : correct_guesses 553
# iteration 759 : cost 0.247161723312 : correct_guesses 553
# iteration 760 : cost 0.247159375336 : correct_guesses 553
# iteration 761 : cost 0.247157035024 : correct_guesses 553
# iteration 762 : cost 0.247154702339 : correct_guesses 553
# iteration 763 : cost 0.247152377245 : correct_guesses 553
# iteration 764 : cost 0.247150059708 : correct_guesses 553
# iteration 765 : cost 0.247147749691 : correct_guesses 553
# iteration 766 : cost 0.24714544716 : correct_guesses 553
# iteration 767 : cost 0.24714315208 : correct_guesses 553
# iteration 768 : cost 0.247140864417 : correct_guesses 553
# iteration 769 : cost 0.247138584136 : correct_guesses 553
# iteration 770 : cost 0.247136311203 : correct_guesses 553
# iteration 771 : cost 0.247134045585 : correct_guesses 553
# iteration 772 : cost 0.247131787247 : correct_guesses 553
# iteration 773 : cost 0.247129536157 : correct_guesses 553
# iteration 774 : cost 0.24712729228 : correct_guesses 553
# iteration 775 : cost 0.247125055585 : correct_guesses 553
# iteration 776 : cost 0.247122826037 : correct_guesses 553
# iteration 777 : cost 0.247120603605 : correct_guesses 553
# iteration 778 : cost 0.247118388257 : correct_guesses 553
# iteration 779 : cost 0.247116179959 : correct_guesses 553
# iteration 780 : cost 0.24711397868 : correct_guesses 553
# iteration 781 : cost 0.247111784389 : correct_guesses 553
# iteration 782 : cost 0.247109597053 : correct_guesses 553
# iteration 783 : cost 0.247107416641 : correct_guesses 553
# iteration 784 : cost 0.247105243123 : correct_guesses 553
# iteration 785 : cost 0.247103076466 : correct_guesses 553
# iteration 786 : cost 0.247100916641 : correct_guesses 553
# iteration 787 : cost 0.247098763617 : correct_guesses 553
# iteration 788 : cost 0.247096617362 : correct_guesses 553
# iteration 789 : cost 0.247094477848 : correct_guesses 553
# iteration 790 : cost 0.247092345043 : correct_guesses 553
# iteration 791 : cost 0.247090218919 : correct_guesses 553
# iteration 792 : cost 0.247088099445 : correct_guesses 553
# iteration 793 : cost 0.247085986591 : correct_guesses 553
# iteration 794 : cost 0.24708388033 : correct_guesses 553
# iteration 795 : cost 0.24708178063 : correct_guesses 553
# iteration 796 : cost 0.247079687464 : correct_guesses 553
# iteration 797 : cost 0.247077600803 : correct_guesses 553
# iteration 798 : cost 0.247075520618 : correct_guesses 553
# iteration 799 : cost 0.247073446881 : correct_guesses 553
# iteration 800 : cost 0.247071379562 : correct_guesses 553
# iteration 801 : cost 0.247069318636 : correct_guesses 553
# iteration 802 : cost 0.247067264072 : correct_guesses 553
# iteration 803 : cost 0.247065215844 : correct_guesses 553
# iteration 804 : cost 0.247063173924 : correct_guesses 553
# iteration 805 : cost 0.247061138285 : correct_guesses 553
# iteration 806 : cost 0.247059108899 : correct_guesses 553
# iteration 807 : cost 0.24705708574 : correct_guesses 553
# iteration 808 : cost 0.247055068779 : correct_guesses 553
# iteration 809 : cost 0.247053057992 : correct_guesses 553
# iteration 810 : cost 0.24705105335 : correct_guesses 553
# iteration 811 : cost 0.247049054828 : correct_guesses 553
# iteration 812 : cost 0.247047062399 : correct_guesses 553
# iteration 813 : cost 0.247045076037 : correct_guesses 553
# iteration 814 : cost 0.247043095717 : correct_guesses 553
# iteration 815 : cost 0.247041121411 : correct_guesses 553
# iteration 816 : cost 0.247039153096 : correct_guesses 553
# iteration 817 : cost 0.247037190744 : correct_guesses 553
# iteration 818 : cost 0.247035234331 : correct_guesses 553
# iteration 819 : cost 0.247033283832 : correct_guesses 553
# iteration 820 : cost 0.247031339221 : correct_guesses 553
# iteration 821 : cost 0.247029400474 : correct_guesses 553
# iteration 822 : cost 0.247027467565 : correct_guesses 553
# iteration 823 : cost 0.247025540471 : correct_guesses 553
# iteration 824 : cost 0.247023619166 : correct_guesses 553
# iteration 825 : cost 0.247021703626 : correct_guesses 553
# iteration 826 : cost 0.247019793828 : correct_guesses 553
# iteration 827 : cost 0.247017889746 : correct_guesses 553
# iteration 828 : cost 0.247015991358 : correct_guesses 553
# iteration 829 : cost 0.247014098639 : correct_guesses 553
# iteration 830 : cost 0.247012211565 : correct_guesses 553
# ...
# iteration 1229 : cost 0.24654893009 : correct_guesses 553
# iteration 1230 : cost 0.246548234756 : correct_guesses 553
# iteration 1231 : cost 0.2465475409 : correct_guesses 553
# iteration 1232 : cost 0.246546848518 : correct_guesses 553
# iteration 1233 : cost 0.246546157605 : correct_guesses 553
# iteration 1234 : cost 0.246545468157 : correct_guesses 553
# iteration 1235 : cost 0.246544780171 : correct_guesses 553
# iteration 1236 : cost 0.246544093641 : correct_guesses 553
# iteration 1237 : cost 0.246543408564 : correct_guesses 553
# iteration 1238 : cost 0.246542724935 : correct_guesses 553
# iteration 1239 : cost 0.246542042751 : correct_guesses 553
# iteration 1240 : cost 0.246541362008 : correct_guesses 553
# iteration 1241 : cost 0.2465406827 : correct_guesses 553
# iteration 1242 : cost 0.246540004825 : correct_guesses 553
# iteration 1243 : cost 0.246539328378 : correct_guesses 553
# iteration 1244 : cost 0.246538653355 : correct_guesses 553
# iteration 1245 : cost 0.246537979752 : correct_guesses 553
# iteration 1246 : cost 0.246537307565 : correct_guesses 553
# iteration 1247 : cost 0.24653663679 : correct_guesses 553
# iteration 1248 : cost 0.246535967422 : correct_guesses 553
# iteration 1249 : cost 0.246535299459 : correct_guesses 553
# iteration 1250 : cost 0.246534632896 : correct_guesses 553
# iteration 1251 : cost 0.246533967729 : correct_guesses 553
# iteration 1252 : cost 0.246533303954 : correct_guesses 553
# iteration 1253 : cost 0.246532641567 : correct_guesses 553
# iteration 1254 : cost 0.246531980565 : correct_guesses 553
# iteration 1255 : cost 0.246531320943 : correct_guesses 553
# iteration 1256 : cost 0.246530662697 : correct_guesses 553
# iteration 1257 : cost 0.246530005824 : correct_guesses 553
# iteration 1258 : cost 0.246529350319 : correct_guesses 553
# iteration 1259 : cost 0.246528696179 : correct_guesses 553
# iteration 1260 : cost 0.2465280434 : correct_guesses 553
# iteration 1261 : cost 0.246527391979 : correct_guesses 553
# iteration 1262 : cost 0.24652674191 : correct_guesses 553
# iteration 1263 : cost 0.246526093191 : correct_guesses 553
# iteration 1264 : cost 0.246525445818 : correct_guesses 553
# iteration 1265 : cost 0.246524799787 : correct_guesses 553
# iteration 1266 : cost 0.246524155094 : correct_guesses 553
# iteration 1267 : cost 0.246523511735 : correct_guesses 553
# iteration 1268 : cost 0.246522869707 : correct_guesses 553
# iteration 1269 : cost 0.246522229005 : correct_guesses 553
# iteration 1270 : cost 0.246521589627 : correct_guesses 553
# iteration 1271 : cost 0.246520951568 : correct_guesses 553
# iteration 1272 : cost 0.246520314825 : correct_guesses 553
# iteration 1273 : cost 0.246519679394 : correct_guesses 553
# iteration 1274 : cost 0.246519045272 : correct_guesses 553
# iteration 1275 : cost 0.246518412454 : correct_guesses 553
# iteration 1276 : cost 0.246517780937 : correct_guesses 553
# iteration 1277 : cost 0.246517150718 : correct_guesses 553
# iteration 1278 : cost 0.246516521792 : correct_guesses 553
# iteration 1279 : cost 0.246515894156 : correct_guesses 553
# iteration 1280 : cost 0.246515267807 : correct_guesses 553
# iteration 1281 : cost 0.246514642741 : correct_guesses 553
# iteration 1282 : cost 0.246514018955 : correct_guesses 553
# iteration 1283 : cost 0.246513396444 : correct_guesses 553
# iteration 1284 : cost 0.246512775205 : correct_guesses 553
# iteration 1285 : cost 0.246512155235 : correct_guesses 553
# iteration 1286 : cost 0.24651153653 : correct_guesses 553
# iteration 1287 : cost 0.246510919087 : correct_guesses 553
# iteration 1288 : cost 0.246510302902 : correct_guesses 553
# iteration 1289 : cost 0.246509687971 : correct_guesses 553
# iteration 1290 : cost 0.246509074291 : correct_guesses 553
# iteration 1291 : cost 0.246508461859 : correct_guesses 553
# iteration 1292 : cost 0.246507850671 : correct_guesses 553
# iteration 1293 : cost 0.246507240724 : correct_guesses 553
# iteration 1294 : cost 0.246506632014 : correct_guesses 553
# iteration 1295 : cost 0.246506024538 : correct_guesses 553
# iteration 1296 : cost 0.246505418292 : correct_guesses 553
# iteration 1297 : cost 0.246504813273 : correct_guesses 553
# iteration 1298 : cost 0.246504209477 : correct_guesses 553
# iteration 1299 : cost 0.246503606902 : correct_guesses 553
# iteration 1300 : cost 0.246503005543 : correct_guesses 553
# iteration 1301 : cost 0.246502405398 : correct_guesses 553
# iteration 1302 : cost 0.246501806462 : correct_guesses 553
# iteration 1303 : cost 0.246501208733 : correct_guesses 553
# iteration 1304 : cost 0.246500612208 : correct_guesses 553
# iteration 1305 : cost 0.246500016882 : correct_guesses 553
# iteration 1306 : cost 0.246499422753 : correct_guesses 553
# iteration 1307 : cost 0.246498829818 : correct_guesses 553
# iteration 1308 : cost 0.246498238072 : correct_guesses 553
# iteration 1309 : cost 0.246497647513 : correct_guesses 553
# iteration 1310 : cost 0.246497058137 : correct_guesses 553
# iteration 1311 : cost 0.246496469942 : correct_guesses 553
# iteration 1312 : cost 0.246495882923 : correct_guesses 553
# iteration 1313 : cost 0.246495297078 : correct_guesses 553
# iteration 1314 : cost 0.246494712404 : correct_guesses 553
# iteration 1315 : cost 0.246494128897 : correct_guesses 553
# iteration 1316 : cost 0.246493546553 : correct_guesses 553
# iteration 1317 : cost 0.24649296537 : correct_guesses 553
# iteration 1318 : cost 0.246492385345 : correct_guesses 553
# iteration 1319 : cost 0.246491806474 : correct_guesses 553
# iteration 1320 : cost 0.246491228755 : correct_guesses 553
# iteration 1321 : cost 0.246490652183 : correct_guesses 553
# iteration 1322 : cost 0.246490076756 : correct_guesses 553
# iteration 1323 : cost 0.246489502471 : correct_guesses 553
# iteration 1324 : cost 0.246488929324 : correct_guesses 553
# iteration 1325 : cost 0.246488357312 : correct_guesses 553
# iteration 1326 : cost 0.246487786433 : correct_guesses 553
# iteration 1327 : cost 0.246487216683 : correct_guesses 553
# iteration 1328 : cost 0.246486648059 : correct_guesses 553
# iteration 1329 : cost 0.246486080558 : correct_guesses 553
# iteration 1330 : cost 0.246485514177 : correct_guesses 553
# iteration 1331 : cost 0.246484948913 : correct_guesses 553
# iteration 1332 : cost 0.246484384762 : correct_guesses 553
# iteration 1333 : cost 0.246483821722 : correct_guesses 553
# iteration 1334 : cost 0.24648325979 : correct_guesses 553
# iteration 1335 : cost 0.246482698962 : correct_guesses 553
# iteration 1336 : cost 0.246482139235 : correct_guesses 553
# iteration 1337 : cost 0.246481580608 : correct_guesses 553
# iteration 1338 : cost 0.246481023075 : correct_guesses 553
# iteration 1339 : cost 0.246480466636 : correct_guesses 553
# iteration 1340 : cost 0.246479911286 : correct_guesses 553
# iteration 1341 : cost 0.246479357022 : correct_guesses 553
# iteration 1342 : cost 0.246478803842 : correct_guesses 553
# iteration 1343 : cost 0.246478251742 : correct_guesses 553
# iteration 1344 : cost 0.24647770072 : correct_guesses 553
# iteration 1345 : cost 0.246477150773 : correct_guesses 553
# iteration 1346 : cost 0.246476601898 : correct_guesses 553
# iteration 1347 : cost 0.246476054091 : correct_guesses 553
# iteration 1348 : cost 0.24647550735 : correct_guesses 553
# iteration 1349 : cost 0.246474961673 : correct_guesses 553
# iteration 1350 : cost 0.246474417055 : correct_guesses 553
# iteration 1351 : cost 0.246473873495 : correct_guesses 553
# iteration 1352 : cost 0.246473330989 : correct_guesses 553
# iteration 1353 : cost 0.246472789534 : correct_guesses 553
# iteration 1354 : cost 0.246472249128 : correct_guesses 553
# iteration 1355 : cost 0.246471709768 : correct_guesses 553
# iteration 1356 : cost 0.246471171451 : correct_guesses 553
# iteration 1357 : cost 0.246470634173 : correct_guesses 553
# iteration 1358 : cost 0.246470097933 : correct_guesses 553
# iteration 1359 : cost 0.246469562727 : correct_guesses 553
# iteration 1360 : cost 0.246469028553 : correct_guesses 553
# iteration 1361 : cost 0.246468495407 : correct_guesses 553
# iteration 1362 : cost 0.246467963288 : correct_guesses 553
# iteration 1363 : cost 0.246467432191 : correct_guesses 553
# iteration 1364 : cost 0.246466902115 : correct_guesses 553
# iteration 1365 : cost 0.246466373057 : correct_guesses 553
# iteration 1366 : cost 0.246465845014 : correct_guesses 553
# iteration 1367 : cost 0.246465317982 : correct_guesses 553
# iteration 1368 : cost 0.24646479196 : correct_guesses 553
# iteration 1369 : cost 0.246464266945 : correct_guesses 553
# iteration 1370 : cost 0.246463742933 : correct_guesses 553
# iteration 1371 : cost 0.246463219923 : correct_guesses 553
# iteration 1372 : cost 0.246462697911 : correct_guesses 553
# iteration 1373 : cost 0.246462176894 : correct_guesses 553
# iteration 1374 : cost 0.246461656871 : correct_guesses 553
# iteration 1375 : cost 0.246461137838 : correct_guesses 553
# iteration 1376 : cost 0.246460619793 : correct_guesses 553
# iteration 1377 : cost 0.246460102733 : correct_guesses 553
# iteration 1378 : cost 0.246459586655 : correct_guesses 553
# iteration 1379 : cost 0.246459071556 : correct_guesses 553
# iteration 1380 : cost 0.246458557435 : correct_guesses 553
# iteration 1381 : cost 0.246458044288 : correct_guesses 553
# iteration 1382 : cost 0.246457532113 : correct_guesses 553
# iteration 1383 : cost 0.246457020907 : correct_guesses 553
# iteration 1384 : cost 0.246456510667 : correct_guesses 553
# iteration 1385 : cost 0.246456001392 : correct_guesses 553
# iteration 1386 : cost 0.246455493077 : correct_guesses 553
# iteration 1387 : cost 0.246454985721 : correct_guesses 553
# iteration 1388 : cost 0.246454479322 : correct_guesses 553
# iteration 1389 : cost 0.246453973876 : correct_guesses 553
# iteration 1390 : cost 0.246453469381 : correct_guesses 553
# iteration 1391 : cost 0.246452965834 : correct_guesses 553
# iteration 1392 : cost 0.246452463233 : correct_guesses 553
# iteration 1393 : cost 0.246451961575 : correct_guesses 553
# iteration 1394 : cost 0.246451460858 : correct_guesses 553
# iteration 1395 : cost 0.246450961079 : correct_guesses 553
# iteration 1396 : cost 0.246450462236 : correct_guesses 553
# iteration 1397 : cost 0.246449964326 : correct_guesses 553
# iteration 1398 : cost 0.246449467347 : correct_guesses 553
# iteration 1399 : cost 0.246448971295 : correct_guesses 553
# iteration 1400 : cost 0.24644847617 : correct_guesses 553
# iteration 1401 : cost 0.246447981967 : correct_guesses 553
# iteration 1402 : cost 0.246447488686 : correct_guesses 553
# iteration 1403 : cost 0.246446996322 : correct_guesses 553
# iteration 1404 : cost 0.246446504874 : correct_guesses 553
# iteration 1405 : cost 0.24644601434 : correct_guesses 553
# iteration 1406 : cost 0.246445524716 : correct_guesses 553
# iteration 1407 : cost 0.246445036 : correct_guesses 553
# iteration 1408 : cost 0.246444548191 : correct_guesses 553
# iteration 1409 : cost 0.246444061285 : correct_guesses 553
# iteration 1410 : cost 0.24644357528 : correct_guesses 552
# iteration 1411 : cost 0.246443090174 : correct_guesses 552
# iteration 1412 : cost 0.246442605964 : correct_guesses 552
# iteration 1413 : cost 0.246442122647 : correct_guesses 552
# iteration 1414 : cost 0.246441640223 : correct_guesses 552
# iteration 1415 : cost 0.246441158687 : correct_guesses 551
# iteration 1416 : cost 0.246440678038 : correct_guesses 551
# iteration 1417 : cost 0.246440198273 : correct_guesses 551
# iteration 1418 : cost 0.24643971939 : correct_guesses 551
# iteration 1419 : cost 0.246439241387 : correct_guesses 551
# iteration 1420 : cost 0.246438764261 : correct_guesses 551
# iteration 1421 : cost 0.24643828801 : correct_guesses 551
# iteration 1422 : cost 0.246437812632 : correct_guesses 551
# iteration 1423 : cost 0.246437338123 : correct_guesses 551
# iteration 1424 : cost 0.246436864483 : correct_guesses 551
# iteration 1425 : cost 0.246436391708 : correct_guesses 551
# iteration 1426 : cost 0.246435919796 : correct_guesses 551
# iteration 1427 : cost 0.246435448745 : correct_guesses 551
# iteration 1428 : cost 0.246434978553 : correct_guesses 551
# iteration 1429 : cost 0.246434509218 : correct_guesses 551
# iteration 1430 : cost 0.246434040736 : correct_guesses 551
# iteration 1431 : cost 0.246433573106 : correct_guesses 551
# iteration 1432 : cost 0.246433106326 : correct_guesses 551
# iteration 1433 : cost 0.246432640392 : correct_guesses 551
# iteration 1434 : cost 0.246432175304 : correct_guesses 551
# iteration 1435 : cost 0.246431711059 : correct_guesses 551
# iteration 1436 : cost 0.246431247654 : correct_guesses 551
# iteration 1437 : cost 0.246430785087 : correct_guesses 551
# iteration 1438 : cost 0.246430323357 : correct_guesses 551
# iteration 1439 : cost 0.24642986246 : correct_guesses 551
# iteration 1440 : cost 0.246429402394 : correct_guesses 551
# iteration 1441 : cost 0.246428943159 : correct_guesses 551
# iteration 1442 : cost 0.24642848475 : correct_guesses 551
# iteration 1443 : cost 0.246428027166 : correct_guesses 551
# iteration 1444 : cost 0.246427570405 : correct_guesses 551
# iteration 1445 : cost 0.246427114464 : correct_guesses 551
# iteration 1446 : cost 0.246426659342 : correct_guesses 551
# iteration 1447 : cost 0.246426205036 : correct_guesses 551
# iteration 1448 : cost 0.246425751545 : correct_guesses 551
# iteration 1449 : cost 0.246425298865 : correct_guesses 551
# iteration 1450 : cost 0.246424846994 : correct_guesses 551
# iteration 1451 : cost 0.246424395932 : correct_guesses 551
# iteration 1452 : cost 0.246423945675 : correct_guesses 551
# iteration 1453 : cost 0.246423496221 : correct_guesses 551
# iteration 1454 : cost 0.246423047568 : correct_guesses 551
# iteration 1455 : cost 0.246422599714 : correct_guesses 551
# iteration 1456 : cost 0.246422152658 : correct_guesses 551
# iteration 1457 : cost 0.246421706396 : correct_guesses 551
# iteration 1458 : cost 0.246421260926 : correct_guesses 551
# iteration 1459 : cost 0.246420816248 : correct_guesses 551
# iteration 1460 : cost 0.246420372358 : correct_guesses 551
# iteration 1461 : cost 0.246419929254 : correct_guesses 551
# iteration 1462 : cost 0.246419486935 : correct_guesses 551
# iteration 1463 : cost 0.246419045398 : correct_guesses 551
# iteration 1464 : cost 0.246418604641 : correct_guesses 551
# iteration 1465 : cost 0.246418164662 : correct_guesses 551
# iteration 1466 : cost 0.246417725459 : correct_guesses 551
# iteration 1467 : cost 0.246417287031 : correct_guesses 551
# iteration 1468 : cost 0.246416849374 : correct_guesses 551
# iteration 1469 : cost 0.246416412487 : correct_guesses 551
# iteration 1470 : cost 0.246415976368 : correct_guesses 551
# iteration 1471 : cost 0.246415541015 : correct_guesses 551
# iteration 1472 : cost 0.246415106426 : correct_guesses 551
# iteration 1473 : cost 0.246414672599 : correct_guesses 551
# iteration 1474 : cost 0.246414239531 : correct_guesses 551
# iteration 1475 : cost 0.246413807221 : correct_guesses 551
# iteration 1476 : cost 0.246413375668 : correct_guesses 551
# iteration 1477 : cost 0.246412944867 : correct_guesses 551
# iteration 1478 : cost 0.246412514819 : correct_guesses 551
# iteration 1479 : cost 0.246412085521 : correct_guesses 551
# iteration 1480 : cost 0.24641165697 : correct_guesses 551
# iteration 1481 : cost 0.246411229166 : correct_guesses 551
# iteration 1482 : cost 0.246410802105 : correct_guesses 551
# iteration 1483 : cost 0.246410375786 : correct_guesses 551
# iteration 1484 : cost 0.246409950207 : correct_guesses 551
# iteration 1485 : cost 0.246409525367 : correct_guesses 551
# iteration 1486 : cost 0.246409101262 : correct_guesses 551
# iteration 1487 : cost 0.246408677892 : correct_guesses 551
# iteration 1488 : cost 0.246408255254 : correct_guesses 551
# iteration 1489 : cost 0.246407833346 : correct_guesses 551
# iteration 1490 : cost 0.246407412167 : correct_guesses 551
# iteration 1491 : cost 0.246406991714 : correct_guesses 551
# iteration 1492 : cost 0.246406571985 : correct_guesses 551
# iteration 1493 : cost 0.24640615298 : correct_guesses 551
# iteration 1494 : cost 0.246405734695 : correct_guesses 551
# iteration 1495 : cost 0.246405317129 : correct_guesses 551
# iteration 1496 : cost 0.24640490028 : correct_guesses 551
# iteration 1497 : cost 0.246404484146 : correct_guesses 551
# iteration 1498 : cost 0.246404068726 : correct_guesses 551
# iteration 1499 : cost 0.246403654016 : correct_guesses 551

# %% [markdown]
# While reading in, all values are normalized to a value around 1. This is done in order to speed up the calculations and to ensure that you never take the logarithm of a zero value (log functions don't really like that).
#
# Once the data has been read into the $X$ and $Y$ matrices, logistic regression can be applied. This simple algorithm for logistic regression correctly classifies ~550 of the 618 subjects, giving it an accuracy of ~90%.
