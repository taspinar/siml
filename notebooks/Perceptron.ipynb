# %% [markdown]
# <h1 style="text-align: left;">1. Introduction:</h1>
# Most tasks in Machine Learning can be reduced to classification tasks. For example, we have a medical dataset and we want to classify who has diabetes (positive class) and who doesn't (negative class). We have a dataset from the financial world and want to know which customers will default on their credit (positive class) and which customers will not (negative class).
# To do this, we can train a Classifier with a 'training dataset' and after such a Classifier is trained (we have determined  its model parameters) and can accurately classify the training set, we  can use it to classify new data (test set). If the training is done properly, the Classifier should predict the class probabilities of the new data with a similar accuracy.
#
#
# <img src="https://raw.githubusercontent.com/taspinar/siml/master/notebooks/img/classification.PNG">
#
#
# There are three popular Classifiers which use three different mathematical approaches to classify data. Previously we have looked at the first two of these; <a href="http://ataspinar.com/2016/05/07/regression-logistic-regression-and-maximum-entropy-part-2-code-examples/" target="_blank">Logistic Regression</a> and the <a href="http://ataspinar.com/2016/02/15/sentiment-analysis-with-the-naive-bayes-classifier/" target="_blank">Naive Bayes</a> classifier. Logistic Regression uses a functional approach to classify data, and the Naive Bayes classifier uses a statistical (Bayesian) approach to classify data.<br><br>
#
# Logistic Regression assumes there is some function $ f(X) $ which forms a correct model of the dataset (i.e. it maps the input values correctly to the output values). This function is defined by its parameters $ \theta_1, \theta_2, ... $. We can use the gradient descent method to find the optimum values of these parameters.<br><br>
#
# The Naive Bayes method is much simpler than that; we do not have to optimize a function, but can calculate the <a href="https://en.wikipedia.org/wiki/Bayesian_probability" target="_blank">Bayesian (conditional) probabilities</a> directly from the training dataset. This can be done quiet fast (by creating a hash table containing the probability distributions of the features) but is generally less accurate.<br><br>
#
# Classification of data can also be done via a third way, by using a geometrical approach. The main idea is to find a line, or a plane, which can separate the two classes in their feature space. Classifiers which are using a geometrical approach are the Perceptron and the SVM (Support Vector Machines) methods.<br><br>
#
# <img src="https://raw.githubusercontent.com/taspinar/siml/master/notebooks/img/three_approaches.PNG">
#
# Below we will discuss the Perceptron classification algorithm. Although Support Vector Machines is used more often, I think a good understanding of the Perceptron algorithm is essential to understanding Support Vector Machines and Neural Networks.<br><br>
#
#
# <h1 style="text-align: left;">Introduction:</h1>
#
# The Perceptron is a lightweight algorithm, which can classify data quiet fast. But it only works in the limited case of a linearly separable, binary dataset. If you have a dataset consisting of only two classes, the Perceptron classifier can be trained to find a linear hyperplane which seperates the two. If the dataset is not linearly separable, the perceptron will fail to find a separating hyperplane.
#
# If the dataset consists of more than two classes we can use the standard approaches in multiclass classification <a href="https://en.wikipedia.org/wiki/Multiclass_classification#Transformation_to_Binary" target="_blank">(one-vs-all and one-vs-one</a>) to transform the multiclass dataset to a binary dataset. For example, if we have a dataset, which consists of three different classes:
# <ul>
#  	<li>In <strong>one-vs-all</strong>,  class I is considered as the positive class and the rest of the classes are considered as the negative class. We can then look for a separating hyperplane between class I and the rest of the dataset (class II and III). This process is repeated for class II and then for class III. So we are trying to find three separating hyperplanes; between class I and the rest of the data, between class II and the rest of the data, etc.
# If the dataset consists of K classes, we end up with K separating hyperplanes.</li>
#  	<li>In <strong>one-vs-one</strong>, class I is considered as the positive class and each of the other classes is considered as the negative class; so first class II is considered as the negative class and then class III is is considered as the negative class. Then this process is repeated with the other classes as the positive class.
# So if the dataset consists of K classes, we are looking for $ K(K-1)/2 $ separating hyperplanes.</li>
# </ul>
#
# Although the one-vs-one can be a bit slower (there is one more iteration layer), it is not difficult to imagine it will be more advantageous in situations  where a (linear) separating hyperplane does not exist between one class and the rest of the data, while it does exists between one class and other classes when they are considered individually. In the image below there is no separating line between the pear-class and the other two classes.
#
# ![title](img/one-vs-one.png)
#
# Another difference is; If the dataset is not <a href="https://en.wikipedia.org/wiki/Linear_separability" target="_blank">linearly seperable</a> [<a href="http://www.ece.utep.edu/research/webfuzzy/docs/kk-thesis/kk-thesis-html/node19.html" target="_blank">2</a>] the perceptron will fail to find a separating hyperplane. The algorithm simply does not converge during its iteration cycle. The SVM on the other hand, can still find a maximum margin minimum cost decision boundary (a separating hyperplane which does not separate 100% of the data, but does it with some small error).
#
#
# <h1>2. The Perceptron Algorithm:</h1>
# It is often said that the perceptron is modeled after neurons in the brain. It has $ m $ input values (which correspond with the $ m $ features of the examples in the training set) and one output value. Each input value $ x_i $ is multiplied by a weight-factor $ w_i $. If the sum of the products between the feature value and weight-factor is larger than zero, the perceptron is activated and 'fires' a signal (+1). Otherwise it is not activated.
#
# ![title](img/perceptron_schematic_overview.PNG)
#
#
# The weighted sum between the input-values and the weight-values, can mathematically be determined with the <a href="https://en.wikipedia.org/wiki/Dot_product" target="_blank">scalar-product</a> $ < w, x >$. To produce the behaviour of 'firing' a signal (+1) we can use the <a href="https://en.wikipedia.org/wiki/Sign_function" target="_blank">signum function</a> $ sgn() $; it maps the output to +1 if the input is positive, and it maps the output to -1 if the input is negative.
#
# Thus, this Perceptron can mathematically be modeled by the function $ y = sgn(b+ < w, x >) $. Here $ b $ is the <a href="http://stackoverflow.com/questions/2480650/role-of-bias-in-neural-networks/2499936#2499936" target="_blank">bias</a>, i.e. the default value when all feature values are zero.
#
# The perceptron algorithm looks as follows:

# %%
def Perceptron(X, Y, b=0, max_iter=10):
    """
    b is the bias,
    X is the input array with n rows (training examples) and m columns (features)
    """
    n,m = np.shape(X)
    #weight-vector
    w = np.zeros(m)
    for ii in range(0,max_iter):
      for jj in xrange(n):
        x_i = X[jj]
        y_i = Y[jj]
        a = b + np.dot(w, x_i)
        if np.sign(y_i*a) != 1:
          w += y_i*x_i
          b += y_i
          print("iteration %s; new weight_vector: %s - new b: %s" % (ii, w, b))

# %% [markdown]
# As you can see, we set the bias-value and all the elements in the weight-vector to zero and iterate over all the examples in the training set.
#
# Here, $ y_i $ is the actual output value of each training example. This is either +1 (if it belongs to the positive class) or -1 (if it does not belong to the positive class).,
# The activation function value $ a = b + < w, x >$ is the predicted output value. It will be $> 0 $ if the prediction is correct and $ < 0 $ if the prediction is incorrect. Therefore, if the prediction made (with the weight vector from the previous training example) is incorrect, $ sgn(y\cdot a) $ will be -1, and the weight vector $ w $ is updated.
#
# We can see that the Perceptron is an <a href="https://en.wikipedia.org/wiki/Online_algorithm" target="_blank">online algorithm</a>; it iterates through the examples in the training set, and for each example in the training set it calculates the value of the activation function $ a $ and updates the values of the weight-vector.
#
# <h2>2.2 Example: 2D</h2>
# Now lets examine the Perceptron algorithm for a linearly separable dataset which exists in 2 dimensions. For this we first have to create this dataset:

# %%
import numpy as np
import random
def generate_data(no_points):
    X = np.zeros(shape=(no_points, 2))
    Y = np.zeros(shape=no_points)
    for ii in range(no_points):
        X[ii][0] = random.randint(1,9)+0.5
        X[ii][1] = random.randint(1,9)+0.5
        Y[ii] = 1 if X[ii][0]+X[ii][1] >= 13 else -1
    return X, Y

# %% [markdown]
# ![title](img/2d_dataset.png)
#
# As we can see in the image above, the dataset contains two linearly separable classes, which are indicated with red and green dots.
#
# Using the Perceptron algorithm on this dataset, will result in.
#
# In the 2D case, the perceptron algorithm looks like:

# %%
X, Y = generate_data(100)
Perceptron(X, Y, max_iter=20)
# Out:
# iteration 0; new weight_vector: [-1.5 -5.5] - new b: -1.0
# iteration 0; new weight_vector: [ 7.  2.] - new b: 0.0
# iteration 0; new weight_vector: [-1.5 -1.5] - new b: -1.0
# iteration 0; new weight_vector: [ 4.  7.] - new b: 0.0
# iteration 0; new weight_vector: [-2.5  1.5] - new b: -1.0
# iteration 0; new weight_vector: [ 7.  6.] - new b: 0.0
# iteration 0; new weight_vector: [ 2.5  2.5] - new b: -1.0
# iteration 0; new weight_vector: [-2.  0.] - new b: -2.0
# iteration 0; new weight_vector: [ 6.5  8.5] - new b: -1.0
# iteration 0; new weight_vector: [ 3.  2.] - new b: -2.0
# iteration 0; new weight_vector: [-3.5 -1.5] - new b: -3.0
# iteration 0; new weight_vector: [ 3.  5.] - new b: -2.0
# iteration 0; new weight_vector: [ 0.5  0.5] - new b: -3.0
# iteration 0; new weight_vector: [-3. -3.] - new b: -4.0
# iteration 0; new weight_vector: [ 5.5  3.5] - new b: -3.0
# iteration 0; new weight_vector: [ 1.  2.] - new b: -4.0
# iteration 0; new weight_vector: [-2.5 -3.5] - new b: -5.0
# iteration 0; new weight_vector: [ 4.  5.] - new b: -4.0
# iteration 0; new weight_vector: [-1.5 -0.5] - new b: -5.0
# iteration 0; new weight_vector: [ 4.  9.] - new b: -4.0
# iteration 0; new weight_vector: [ 2.5  6.5] - new b: -5.0
# iteration 0; new weight_vector: [-2. -1.] - new b: -6.0
# iteration 0; new weight_vector: [ 4.5  6.5] - new b: -5.0
# iteration 0; new weight_vector: [ 3.  0.] - new b: -6.0
# iteration 0; new weight_vector: [-3.5 -2.5] - new b: -7.0
# iteration 0; new weight_vector: [ 4.  4.] - new b: -6.0
# iteration 0; new weight_vector: [ 0.5 -1.5] - new b: -7.0
# iteration 0; new weight_vector: [ 4.  8.] - new b: -6.0
# iteration 0; new weight_vector: [ 0.5  6.5] - new b: -7.0
# iteration 0; new weight_vector: [-1.  1.] - new b: -8.0
# iteration 0; new weight_vector: [ 7.5  7.5] - new b: -7.0
# iteration 0; new weight_vector: [ 4.  0.] - new b: -8.0
# iteration 0; new weight_vector: [ 0.5 -7.5] - new b: -9.0
# iteration 0; new weight_vector: [ 10.  -4.] - new b: -8.0
# iteration 0; new weight_vector: [  5.5 -11.5] - new b: -9.0
# iteration 0; new weight_vector: [ 12.  -2.] - new b: -8.0
# iteration 0; new weight_vector: [ 3.5 -5.5] - new b: -9.0
# iteration 0; new weight_vector: [-4. -7.] - new b: -10.0
# iteration 0; new weight_vector: [ 3.5  2.5] - new b: -9.0
# iteration 0; new weight_vector: [-5. -1.] - new b: -10.0
# iteration 0; new weight_vector: [ 2.5  4.5] - new b: -9.0
# iteration 0; new weight_vector: [-4.  1.] - new b: -10.0
# iteration 0; new weight_vector: [ 3.5  9.5] - new b: -9.0
# iteration 0; new weight_vector: [ 0.  1.] - new b: -10.0
# iteration 0; new weight_vector: [ 4.5  9.5] - new b: -9.0
# iteration 1; new weight_vector: [ 3.  4.] - new b: -10.0
# iteration 1; new weight_vector: [-1.5  0.5] - new b: -11.0
# iteration 1; new weight_vector: [ 7.  8.] - new b: -10.0
# iteration 1; new weight_vector: [-1.5  4.5] - new b: -11.0
# iteration 1; new weight_vector: [-8. -1.] - new b: -12.0
# iteration 1; new weight_vector: [ 1.5  3.5] - new b: -11.0
# iteration 1; new weight_vector: [-3.  0.] - new b: -12.0
# iteration 1; new weight_vector: [ 2.5  7.5] - new b: -11.0
# iteration 1; new weight_vector: [-2.  5.] - new b: -12.0
# iteration 1; new weight_vector: [-8.5 -0.5] - new b: -13.0
# iteration 1; new weight_vector: [ 0.  8.] - new b: -12.0
# iteration 1; new weight_vector: [-3.5  1.5] - new b: -13.0
# iteration 1; new weight_vector: [  4.  11.] - new b: -12.0
# iteration 1; new weight_vector: [-2.5  7.5] - new b: -13.0
# iteration 1; new weight_vector: [-4.  3.] - new b: -14.0
# iteration 1; new weight_vector: [ 2.5  9.5] - new b: -13.0
# iteration 1; new weight_vector: [ 0.  5.] - new b: -14.0
# iteration 1; new weight_vector: [-3.5  1.5] - new b: -15.0
# iteration 1; new weight_vector: [ 5.  8.] - new b: -14.0
# iteration 1; new weight_vector: [ 0.5  6.5] - new b: -15.0
# iteration 1; new weight_vector: [-3.  1.] - new b: -16.0
# iteration 1; new weight_vector: [ 3.5  9.5] - new b: -15.0
# iteration 1; new weight_vector: [-2.  4.] - new b: -16.0
# iteration 1; new weight_vector: [-3.5 -5.5] - new b: -17.0
# iteration 1; new weight_vector: [ 2.  4.] - new b: -16.0
# iteration 1; new weight_vector: [-2.5 -3.5] - new b: -17.0
# iteration 1; new weight_vector: [ 4.  4.] - new b: -16.0
# iteration 1; new weight_vector: [ 2.5 -2.5] - new b: -17.0
# iteration 1; new weight_vector: [ 12.   2.] - new b: -16.0
# iteration 1; new weight_vector: [ 5.5 -0.5] - new b: -17.0
# iteration 1; new weight_vector: [-2. -5.] - new b: -18.0
# iteration 1; new weight_vector: [ 5.5  1.5] - new b: -17.0
# iteration 1; new weight_vector: [ 2. -4.] - new b: -18.0
# iteration 1; new weight_vector: [ 5.5  5.5] - new b: -17.0
# iteration 1; new weight_vector: [ 2.  4.] - new b: -18.0
# iteration 1; new weight_vector: [ 0.5 -1.5] - new b: -19.0
# iteration 1; new weight_vector: [ 9.  5.] - new b: -18.0
# iteration 1; new weight_vector: [ 5.5 -2.5] - new b: -19.0
# iteration 1; new weight_vector: [-1. -5.] - new b: -20.0
# iteration 1; new weight_vector: [ 8.5 -1.5] - new b: -19.0
# iteration 1; new weight_vector: [ 4. -9.] - new b: -20.0
# iteration 1; new weight_vector: [ 10.5   0.5] - new b: -19.0
# iteration 1; new weight_vector: [ 2. -3.] - new b: -20.0
# iteration 1; new weight_vector: [ 9.5  6.5] - new b: -19.0
# iteration 1; new weight_vector: [ 1.  3.] - new b: -20.0
# iteration 1; new weight_vector: [-2.5 -5.5] - new b: -21.0
# iteration 1; new weight_vector: [ 2.  3.] - new b: -20.0
# iteration 2; new weight_vector: [-6.5 -0.5] - new b: -21.0
# iteration 2; new weight_vector: [-1.  8.] - new b: -20.0
# iteration 2; new weight_vector: [-7.5  2.5] - new b: -21.0
# iteration 2; new weight_vector: [ 2.  7.] - new b: -20.0
# iteration 2; new weight_vector: [-2.5  3.5] - new b: -21.0
# iteration 2; new weight_vector: [  3.  11.] - new b: -20.0
# iteration 2; new weight_vector: [-1.5  8.5] - new b: -21.0
# iteration 2; new weight_vector: [-8.  3.] - new b: -22.0
# iteration 2; new weight_vector: [  0.5  11.5] - new b: -21.0
# iteration 2; new weight_vector: [-3.  5.] - new b: -22.0
# iteration 2; new weight_vector: [  4.5  10.5] - new b: -21.0
# iteration 2; new weight_vector: [-2.  7.] - new b: -22.0
# iteration 2; new weight_vector: [-3.5  2.5] - new b: -23.0
# iteration 2; new weight_vector: [ 3.  9.] - new b: -22.0
# iteration 2; new weight_vector: [ 0.5  4.5] - new b: -23.0
# iteration 2; new weight_vector: [-4. -3.] - new b: -24.0
# iteration 2; new weight_vector: [ 4.5  3.5] - new b: -23.0
# iteration 2; new weight_vector: [ 0.  2.] - new b: -24.0
# iteration 2; new weight_vector: [  6.5  10.5] - new b: -23.0
# iteration 2; new weight_vector: [ 1.  5.] - new b: -24.0
# iteration 2; new weight_vector: [-0.5 -4.5] - new b: -25.0
# iteration 2; new weight_vector: [ 5.  5.] - new b: -24.0
# iteration 2; new weight_vector: [ 0.5 -2.5] - new b: -25.0
# iteration 2; new weight_vector: [ 7.  5.] - new b: -24.0
# iteration 2; new weight_vector: [ 5.5 -1.5] - new b: -25.0
# iteration 2; new weight_vector: [-1. -4.] - new b: -26.0
# iteration 2; new weight_vector: [ 6.5  2.5] - new b: -25.0
# iteration 2; new weight_vector: [ 3. -3.] - new b: -26.0
# iteration 2; new weight_vector: [ 6.5  6.5] - new b: -25.0
# iteration 2; new weight_vector: [ 3.  5.] - new b: -26.0
# iteration 2; new weight_vector: [ 1.5 -0.5] - new b: -27.0
# iteration 2; new weight_vector: [ 10.   6.] - new b: -26.0
# iteration 2; new weight_vector: [ 6.5 -1.5] - new b: -27.0
# iteration 2; new weight_vector: [ 0. -4.] - new b: -28.0
# iteration 2; new weight_vector: [ 9.5 -0.5] - new b: -27.0
# iteration 2; new weight_vector: [ 5. -8.] - new b: -28.0
# iteration 2; new weight_vector: [ 11.5   1.5] - new b: -27.0
# iteration 2; new weight_vector: [ 3. -2.] - new b: -28.0
# iteration 2; new weight_vector: [ 10.5   7.5] - new b: -27.0
# iteration 2; new weight_vector: [ 2.  4.] - new b: -28.0
# iteration 2; new weight_vector: [-1.5 -4.5] - new b: -29.0
# iteration 2; new weight_vector: [ 3.  4.] - new b: -28.0
# iteration 3; new weight_vector: [-5.5  0.5] - new b: -29.0
# iteration 3; new weight_vector: [ 0.  9.] - new b: -28.0
# iteration 3; new weight_vector: [-6.5  3.5] - new b: -29.0
# iteration 3; new weight_vector: [ 3.  8.] - new b: -28.0
# iteration 3; new weight_vector: [-1.5  4.5] - new b: -29.0
# iteration 3; new weight_vector: [  4.  12.] - new b: -28.0
# iteration 3; new weight_vector: [-0.5  9.5] - new b: -29.0
# iteration 3; new weight_vector: [-7.  4.] - new b: -30.0
# iteration 3; new weight_vector: [  1.5  12.5] - new b: -29.0
# iteration 3; new weight_vector: [-2.  6.] - new b: -30.0
# iteration 3; new weight_vector: [  5.5  11.5] - new b: -29.0
# iteration 3; new weight_vector: [-1.  8.] - new b: -30.0
# iteration 3; new weight_vector: [-2.5  3.5] - new b: -31.0
# iteration 3; new weight_vector: [  4.  10.] - new b: -30.0
# iteration 3; new weight_vector: [ 1.5  5.5] - new b: -31.0
# iteration 3; new weight_vector: [-3. -2.] - new b: -32.0
# iteration 3; new weight_vector: [ 5.5  4.5] - new b: -31.0
# iteration 3; new weight_vector: [ 1.  3.] - new b: -32.0
# iteration 3; new weight_vector: [  7.5  11.5] - new b: -31.0
# iteration 3; new weight_vector: [ 2.  6.] - new b: -32.0
# iteration 3; new weight_vector: [ 0.5 -3.5] - new b: -33.0
# iteration 3; new weight_vector: [ 6.  6.] - new b: -32.0
# iteration 3; new weight_vector: [ 1.5 -1.5] - new b: -33.0
# iteration 3; new weight_vector: [ 8.  6.] - new b: -32.0
# iteration 3; new weight_vector: [ 6.5 -0.5] - new b: -33.0
# iteration 3; new weight_vector: [ 0. -3.] - new b: -34.0
# iteration 3; new weight_vector: [ 7.5  3.5] - new b: -33.0
# iteration 3; new weight_vector: [ 4. -2.] - new b: -34.0
# iteration 3; new weight_vector: [ 7.5  7.5] - new b: -33.0
# iteration 3; new weight_vector: [ 4.  6.] - new b: -34.0
# iteration 3; new weight_vector: [ 2.5  0.5] - new b: -35.0
# iteration 3; new weight_vector: [ 11.   7.] - new b: -34.0
# iteration 3; new weight_vector: [ 7.5 -0.5] - new b: -35.0
# iteration 3; new weight_vector: [ 1. -3.] - new b: -36.0
# iteration 3; new weight_vector: [ 10.5   0.5] - new b: -35.0
# iteration 3; new weight_vector: [ 6. -7.] - new b: -36.0
# iteration 3; new weight_vector: [ 12.5   2.5] - new b: -35.0
# iteration 3; new weight_vector: [ 4. -1.] - new b: -36.0
# iteration 3; new weight_vector: [ 11.5   8.5] - new b: -35.0
# iteration 3; new weight_vector: [ 3.  5.] - new b: -36.0
# iteration 3; new weight_vector: [-3.5  1.5] - new b: -37.0
# iteration 3; new weight_vector: [  4.  10.] - new b: -36.0
# iteration 3; new weight_vector: [ 0.5  1.5] - new b: -37.0
# iteration 3; new weight_vector: [  5.  10.] - new b: -36.0
# iteration 4; new weight_vector: [ 3.5  4.5] - new b: -37.0
# iteration 4; new weight_vector: [-5.  1.] - new b: -38.0
# iteration 4; new weight_vector: [ 0.5  9.5] - new b: -37.0
# iteration 4; new weight_vector: [-6.  4.] - new b: -38.0
# iteration 4; new weight_vector: [ 3.5  8.5] - new b: -37.0
# iteration 4; new weight_vector: [-1.  5.] - new b: -38.0
# iteration 4; new weight_vector: [  4.5  12.5] - new b: -37.0
# iteration 4; new weight_vector: [  0.  10.] - new b: -38.0
# iteration 4; new weight_vector: [-6.5  4.5] - new b: -39.0
# iteration 4; new weight_vector: [  2.  13.] - new b: -38.0
# iteration 4; new weight_vector: [-1.5  6.5] - new b: -39.0
# iteration 4; new weight_vector: [  6.  12.] - new b: -38.0
# iteration 4; new weight_vector: [-0.5  8.5] - new b: -39.0
# iteration 4; new weight_vector: [-5.  1.] - new b: -40.0
# iteration 4; new weight_vector: [ 3.5  7.5] - new b: -39.0
# iteration 4; new weight_vector: [ 0.  2.] - new b: -40.0
# iteration 4; new weight_vector: [  6.5  10.5] - new b: -39.0
# iteration 4; new weight_vector: [ 1.  5.] - new b: -40.0
# iteration 4; new weight_vector: [-0.5 -4.5] - new b: -41.0
# iteration 4; new weight_vector: [ 5.  5.] - new b: -40.0
# iteration 4; new weight_vector: [ 0.5 -2.5] - new b: -41.0
# iteration 4; new weight_vector: [ 7.  5.] - new b: -40.0
# iteration 4; new weight_vector: [ 5.5 -1.5] - new b: -41.0
# iteration 4; new weight_vector: [ 13.   5.] - new b: -40.0
# iteration 4; new weight_vector: [ 9.5 -0.5] - new b: -41.0
# iteration 4; new weight_vector: [ 5. -3.] - new b: -42.0
# iteration 4; new weight_vector: [ 8.5  6.5] - new b: -41.0
# iteration 4; new weight_vector: [ 7.  1.] - new b: -42.0
# iteration 4; new weight_vector: [ 0.5 -1.5] - new b: -43.0
# iteration 4; new weight_vector: [ 10.   2.] - new b: -42.0
# iteration 4; new weight_vector: [ 5.5 -5.5] - new b: -43.0
# iteration 4; new weight_vector: [ 12.   4.] - new b: -42.0
# iteration 4; new weight_vector: [ 3.5  0.5] - new b: -43.0
# iteration 4; new weight_vector: [ 11.  10.] - new b: -42.0
# iteration 4; new weight_vector: [ 2.5  6.5] - new b: -43.0
# iteration 4; new weight_vector: [-1. -2.] - new b: -44.0
# iteration 4; new weight_vector: [ 3.5  6.5] - new b: -43.0
# iteration 5; new weight_vector: [-5.  3.] - new b: -44.0
# iteration 5; new weight_vector: [  0.5  11.5] - new b: -43.0
# iteration 5; new weight_vector: [-6.  6.] - new b: -44.0
# iteration 5; new weight_vector: [  3.5  10.5] - new b: -43.0
# iteration 5; new weight_vector: [-1.  7.] - new b: -44.0
# iteration 5; new weight_vector: [-2.5 -2.5] - new b: -45.0
# iteration 5; new weight_vector: [ 6.  6.] - new b: -44.0
# iteration 5; new weight_vector: [ 2.5 -0.5] - new b: -45.0
# iteration 5; new weight_vector: [ 10.   9.] - new b: -44.0
# iteration 5; new weight_vector: [ 3.5  5.5] - new b: -45.0
# iteration 5; new weight_vector: [-1. -2.] - new b: -46.0
# iteration 5; new weight_vector: [ 7.5  4.5] - new b: -45.0
# iteration 5; new weight_vector: [ 4. -1.] - new b: -46.0
# iteration 5; new weight_vector: [ 10.5   7.5] - new b: -45.0
# iteration 5; new weight_vector: [ 5.  2.] - new b: -46.0
# iteration 5; new weight_vector: [-4.5  0.5] - new b: -47.0
# iteration 5; new weight_vector: [  1.  10.] - new b: -46.0
# iteration 5; new weight_vector: [-3.5  2.5] - new b: -47.0
# iteration 5; new weight_vector: [  3.  10.] - new b: -46.0
# iteration 5; new weight_vector: [ 1.5  3.5] - new b: -47.0
# iteration 5; new weight_vector: [ 11.   8.] - new b: -46.0
# iteration 5; new weight_vector: [ 4.5  5.5] - new b: -47.0
# iteration 5; new weight_vector: [-3.  1.] - new b: -48.0
# iteration 5; new weight_vector: [ 4.5  7.5] - new b: -47.0
# iteration 5; new weight_vector: [ 1.  2.] - new b: -48.0
# iteration 5; new weight_vector: [  4.5  11.5] - new b: -47.0
# iteration 5; new weight_vector: [ 3.  6.] - new b: -48.0
# iteration 5; new weight_vector: [-0.5 -1.5] - new b: -49.0
# iteration 5; new weight_vector: [ 8.  8.] - new b: -48.0
# iteration 5; new weight_vector: [ 4.5  0.5] - new b: -49.0
# iteration 5; new weight_vector: [ 14.   4.] - new b: -48.0
# iteration 5; new weight_vector: [ 9.5 -3.5] - new b: -49.0
# iteration 5; new weight_vector: [ 16.   6.] - new b: -48.0
# iteration 5; new weight_vector: [ 7.5  2.5] - new b: -49.0
# iteration 5; new weight_vector: [ 0.  1.] - new b: -50.0
# iteration 5; new weight_vector: [  7.5  10.5] - new b: -49.0
# iteration 5; new weight_vector: [-1.  7.] - new b: -50.0
# iteration 5; new weight_vector: [  6.5  12.5] - new b: -49.0
# iteration 5; new weight_vector: [ 0.  9.] - new b: -50.0
# iteration 5; new weight_vector: [-3.5  0.5] - new b: -51.0
# iteration 5; new weight_vector: [ 1.  9.] - new b: -50.0
# iteration 6; new weight_vector: [-0.5  3.5] - new b: -51.0
# iteration 6; new weight_vector: [  8.  11.] - new b: -50.0
# iteration 6; new weight_vector: [-0.5  7.5] - new b: -51.0
# iteration 6; new weight_vector: [  9.  14.] - new b: -50.0
# iteration 6; new weight_vector: [ 2.5  8.5] - new b: -51.0
# iteration 6; new weight_vector: [-4.  3.] - new b: -52.0
# iteration 6; new weight_vector: [  4.5  11.5] - new b: -51.0
# iteration 6; new weight_vector: [ 1.  5.] - new b: -52.0
# iteration 6; new weight_vector: [  8.5  10.5] - new b: -51.0
# iteration 6; new weight_vector: [ 2.  7.] - new b: -52.0
# iteration 6; new weight_vector: [-2.5 -0.5] - new b: -53.0
# iteration 6; new weight_vector: [ 6.  6.] - new b: -52.0
# iteration 6; new weight_vector: [ 2.5  0.5] - new b: -53.0
# iteration 6; new weight_vector: [ 9.  9.] - new b: -52.0
# iteration 6; new weight_vector: [ 3.5  3.5] - new b: -53.0
# iteration 6; new weight_vector: [  9.  13.] - new b: -52.0
# iteration 6; new weight_vector: [ 4.5  5.5] - new b: -53.0
# iteration 6; new weight_vector: [-3.  1.] - new b: -54.0
# iteration 6; new weight_vector: [ 4.5  7.5] - new b: -53.0
# iteration 6; new weight_vector: [ 1.  2.] - new b: -54.0
# iteration 6; new weight_vector: [  4.5  11.5] - new b: -53.0
# iteration 6; new weight_vector: [ 3.  6.] - new b: -54.0
# iteration 6; new weight_vector: [-0.5 -1.5] - new b: -55.0
# iteration 6; new weight_vector: [ 8.  8.] - new b: -54.0
# iteration 6; new weight_vector: [ 4.5  0.5] - new b: -55.0
# iteration 6; new weight_vector: [ 14.   4.] - new b: -54.0
# iteration 6; new weight_vector: [ 9.5 -3.5] - new b: -55.0
# iteration 6; new weight_vector: [ 16.   6.] - new b: -54.0
# iteration 6; new weight_vector: [ 7.5  2.5] - new b: -55.0
# iteration 6; new weight_vector: [ 0.  1.] - new b: -56.0
# iteration 6; new weight_vector: [  7.5  10.5] - new b: -55.0
# iteration 6; new weight_vector: [-1.  7.] - new b: -56.0
# iteration 6; new weight_vector: [  6.5  12.5] - new b: -55.0
# iteration 6; new weight_vector: [ 0.  9.] - new b: -56.0
# iteration 6; new weight_vector: [-3.5  0.5] - new b: -57.0
# iteration 6; new weight_vector: [ 1.  9.] - new b: -56.0
# iteration 7; new weight_vector: [-5.5  3.5] - new b: -57.0
# iteration 7; new weight_vector: [ 4.  8.] - new b: -56.0
# iteration 7; new weight_vector: [-2.5  2.5] - new b: -57.0
# iteration 7; new weight_vector: [  6.  11.] - new b: -56.0
# iteration 7; new weight_vector: [ 2.5  4.5] - new b: -57.0
# iteration 7; new weight_vector: [ 10.  10.] - new b: -56.0
# iteration 7; new weight_vector: [ 3.5  6.5] - new b: -57.0
# iteration 7; new weight_vector: [-1. -1.] - new b: -58.0
# iteration 7; new weight_vector: [ 7.5  5.5] - new b: -57.0
# iteration 7; new weight_vector: [ 1.  2.] - new b: -58.0
# iteration 7; new weight_vector: [  7.5  10.5] - new b: -57.0
# iteration 7; new weight_vector: [ 2.  5.] - new b: -58.0
# iteration 7; new weight_vector: [  8.5  12.5] - new b: -57.0
# iteration 7; new weight_vector: [ 7.  6.] - new b: -58.0
# iteration 7; new weight_vector: [ 0.5  3.5] - new b: -59.0
# iteration 7; new weight_vector: [  8.  10.] - new b: -58.0
# iteration 7; new weight_vector: [ 4.5  4.5] - new b: -59.0
# iteration 7; new weight_vector: [  8.  14.] - new b: -58.0
# iteration 7; new weight_vector: [ 6.5  8.5] - new b: -59.0
# iteration 7; new weight_vector: [ 3.  1.] - new b: -60.0
# iteration 7; new weight_vector: [ 11.5  10.5] - new b: -59.0
# iteration 7; new weight_vector: [ 8.  3.] - new b: -60.0
# iteration 7; new weight_vector: [ 2.5 -3.5] - new b: -61.0
# iteration 7; new weight_vector: [ 9.  6.] - new b: -60.0
# iteration 7; new weight_vector: [ 0.5  2.5] - new b: -61.0
# iteration 7; new weight_vector: [  8.  12.] - new b: -60.0
# iteration 7; new weight_vector: [-0.5  8.5] - new b: -61.0
# iteration 7; new weight_vector: [  7.  14.] - new b: -60.0
# iteration 7; new weight_vector: [  0.5  10.5] - new b: -61.0
# iteration 7; new weight_vector: [-3.  2.] - new b: -62.0
# iteration 7; new weight_vector: [  1.5  10.5] - new b: -61.0
# iteration 8; new weight_vector: [-5.  5.] - new b: -62.0
# iteration 8; new weight_vector: [ 4.5  9.5] - new b: -61.0
# iteration 8; new weight_vector: [-2.  4.] - new b: -62.0
# iteration 8; new weight_vector: [  6.5  12.5] - new b: -61.0
# iteration 8; new weight_vector: [ 3.  6.] - new b: -62.0
# iteration 8; new weight_vector: [ 10.5  11.5] - new b: -61.0
# iteration 8; new weight_vector: [ 4.  8.] - new b: -62.0
# iteration 8; new weight_vector: [-0.5  0.5] - new b: -63.0
# iteration 8; new weight_vector: [ 8.  7.] - new b: -62.0
# iteration 8; new weight_vector: [ 4.5  1.5] - new b: -63.0
# iteration 8; new weight_vector: [ 11.  10.] - new b: -62.0
# iteration 8; new weight_vector: [ 5.5  4.5] - new b: -63.0
# iteration 8; new weight_vector: [  9.  14.] - new b: -62.0
# iteration 8; new weight_vector: [ 7.5  8.5] - new b: -63.0
# iteration 8; new weight_vector: [ 4.  1.] - new b: -64.0
# iteration 8; new weight_vector: [ 12.5  10.5] - new b: -63.0
# iteration 8; new weight_vector: [ 9.  3.] - new b: -64.0
# iteration 8; new weight_vector: [ 2.5  0.5] - new b: -65.0
# iteration 8; new weight_vector: [ 12.   4.] - new b: -64.0
# iteration 8; new weight_vector: [ 7.5 -3.5] - new b: -65.0
# iteration 8; new weight_vector: [ 14.   6.] - new b: -64.0
# iteration 8; new weight_vector: [ 5.5  2.5] - new b: -65.0
# iteration 8; new weight_vector: [ 13.  12.] - new b: -64.0
# iteration 8; new weight_vector: [ 4.5  8.5] - new b: -65.0
# iteration 8; new weight_vector: [ 1.  0.] - new b: -66.0
# iteration 8; new weight_vector: [ 5.5  8.5] - new b: -65.0
# iteration 9; new weight_vector: [-3.  5.] - new b: -66.0
# iteration 9; new weight_vector: [  2.5  13.5] - new b: -65.0
# iteration 9; new weight_vector: [-4.  8.] - new b: -66.0
# iteration 9; new weight_vector: [  5.5  12.5] - new b: -65.0
# iteration 9; new weight_vector: [ 1.  9.] - new b: -66.0
# iteration 9; new weight_vector: [-0.5 -0.5] - new b: -67.0
# iteration 9; new weight_vector: [ 8.  8.] - new b: -66.0
# iteration 9; new weight_vector: [ 4.5  1.5] - new b: -67.0
# iteration 9; new weight_vector: [ 12.  11.] - new b: -66.0
# iteration 9; new weight_vector: [ 5.5  7.5] - new b: -67.0
# iteration 9; new weight_vector: [ 1.  0.] - new b: -68.0
# iteration 9; new weight_vector: [ 9.5  6.5] - new b: -67.0
# iteration 9; new weight_vector: [ 6.  1.] - new b: -68.0
# iteration 9; new weight_vector: [ 12.5   9.5] - new b: -67.0
# iteration 9; new weight_vector: [ 7.  4.] - new b: -68.0
# iteration 9; new weight_vector: [-2.5  2.5] - new b: -69.0
# iteration 9; new weight_vector: [  3.  12.] - new b: -68.0
# iteration 9; new weight_vector: [-1.5  4.5] - new b: -69.0
# iteration 9; new weight_vector: [  5.  12.] - new b: -68.0
# iteration 9; new weight_vector: [ 3.5  5.5] - new b: -69.0
# iteration 9; new weight_vector: [ 13.  10.] - new b: -68.0
# iteration 9; new weight_vector: [ 6.5  7.5] - new b: -69.0
# iteration 9; new weight_vector: [-1.  3.] - new b: -70.0
# iteration 9; new weight_vector: [ 6.5  9.5] - new b: -69.0
# iteration 9; new weight_vector: [ 3.  4.] - new b: -70.0
# iteration 9; new weight_vector: [  6.5  13.5] - new b: -69.0
# iteration 9; new weight_vector: [ 5.  8.] - new b: -70.0
# iteration 9; new weight_vector: [ 1.5  0.5] - new b: -71.0
# iteration 9; new weight_vector: [ 10.  10.] - new b: -70.0
# iteration 9; new weight_vector: [ 6.5  2.5] - new b: -71.0
# iteration 9; new weight_vector: [ 16.   6.] - new b: -70.0
# iteration 9; new weight_vector: [ 11.5  -1.5] - new b: -71.0
# iteration 9; new weight_vector: [ 18.   8.] - new b: -70.0
# iteration 9; new weight_vector: [ 9.5  4.5] - new b: -71.0
# iteration 9; new weight_vector: [ 2.  3.] - new b: -72.0
# iteration 9; new weight_vector: [  9.5  12.5] - new b: -71.0
# iteration 9; new weight_vector: [ 1.  9.] - new b: -72.0
# iteration 9; new weight_vector: [  8.5  14.5] - new b: -71.0
# iteration 9; new weight_vector: [  2.  11.] - new b: -72.0
# iteration 9; new weight_vector: [-1.5  2.5] - new b: -73.0
# iteration 9; new weight_vector: [  3.  11.] - new b: -72.0
# iteration 10; new weight_vector: [-3.5  5.5] - new b: -73.0
# iteration 10; new weight_vector: [  6.  10.] - new b: -72.0
# iteration 10; new weight_vector: [-0.5  4.5] - new b: -73.0
# iteration 10; new weight_vector: [  8.  13.] - new b: -72.0
# iteration 10; new weight_vector: [ 4.5  6.5] - new b: -73.0
# iteration 10; new weight_vector: [ 12.  12.] - new b: -72.0
# iteration 10; new weight_vector: [ 5.5  8.5] - new b: -73.0
# iteration 10; new weight_vector: [ 1.  1.] - new b: -74.0
# iteration 10; new weight_vector: [ 9.5  7.5] - new b: -73.0
# iteration 10; new weight_vector: [ 6.  2.] - new b: -74.0
# iteration 10; new weight_vector: [ 12.5  10.5] - new b: -73.0
# iteration 10; new weight_vector: [ 7.  5.] - new b: -74.0
# iteration 10; new weight_vector: [-2.5  3.5] - new b: -75.0
# iteration 10; new weight_vector: [  3.  13.] - new b: -74.0
# iteration 10; new weight_vector: [-1.5  5.5] - new b: -75.0
# iteration 10; new weight_vector: [  5.  13.] - new b: -74.0
# iteration 10; new weight_vector: [ 3.5  6.5] - new b: -75.0
# iteration 10; new weight_vector: [ 13.  11.] - new b: -74.0
# iteration 10; new weight_vector: [ 6.5  8.5] - new b: -75.0
# iteration 10; new weight_vector: [-1.  4.] - new b: -76.0
# iteration 10; new weight_vector: [  6.5  10.5] - new b: -75.0
# iteration 10; new weight_vector: [ 3.  5.] - new b: -76.0
# iteration 10; new weight_vector: [  6.5  14.5] - new b: -75.0
# iteration 10; new weight_vector: [ 5.  9.] - new b: -76.0
# iteration 10; new weight_vector: [ 1.5  1.5] - new b: -77.0
# iteration 10; new weight_vector: [ 10.  11.] - new b: -76.0
# iteration 10; new weight_vector: [ 6.5  3.5] - new b: -77.0
# iteration 10; new weight_vector: [ 16.   7.] - new b: -76.0
# iteration 10; new weight_vector: [ 11.5  -0.5] - new b: -77.0
# iteration 10; new weight_vector: [ 18.   9.] - new b: -76.0
# iteration 10; new weight_vector: [ 9.5  5.5] - new b: -77.0
# iteration 10; new weight_vector: [ 2.  4.] - new b: -78.0
# iteration 10; new weight_vector: [  9.5  13.5] - new b: -77.0
# iteration 10; new weight_vector: [  1.  10.] - new b: -78.0
# iteration 10; new weight_vector: [  8.5  15.5] - new b: -77.0
# iteration 10; new weight_vector: [  2.  12.] - new b: -78.0
# iteration 10; new weight_vector: [-1.5  3.5] - new b: -79.0
# iteration 10; new weight_vector: [  3.  12.] - new b: -78.0
# iteration 11; new weight_vector: [-3.5  6.5] - new b: -79.0
# iteration 11; new weight_vector: [  6.  11.] - new b: -78.0
# iteration 11; new weight_vector: [-0.5  5.5] - new b: -79.0
# iteration 11; new weight_vector: [  8.  14.] - new b: -78.0
# iteration 11; new weight_vector: [ 4.5  7.5] - new b: -79.0
# iteration 11; new weight_vector: [ 12.  13.] - new b: -78.0
# iteration 11; new weight_vector: [ 5.5  9.5] - new b: -79.0
# iteration 11; new weight_vector: [ 1.  2.] - new b: -80.0
# iteration 11; new weight_vector: [ 9.5  8.5] - new b: -79.0
# iteration 11; new weight_vector: [ 6.  3.] - new b: -80.0
# iteration 11; new weight_vector: [ 12.5  11.5] - new b: -79.0
# iteration 11; new weight_vector: [ 7.  6.] - new b: -80.0
# iteration 11; new weight_vector: [-1.5  2.5] - new b: -81.0
# iteration 11; new weight_vector: [  6.  12.] - new b: -80.0
# iteration 11; new weight_vector: [-2.5  8.5] - new b: -81.0
# iteration 11; new weight_vector: [  5.  14.] - new b: -80.0
# iteration 11; new weight_vector: [ -1.5  10.5] - new b: -81.0
# iteration 11; new weight_vector: [  6.  19.] - new b: -80.0
# iteration 11; new weight_vector: [  2.5  10.5] - new b: -81.0
# iteration 12; new weight_vector: [ 11.  16.] - new b: -80.0
# iteration 12; new weight_vector: [  2.5  12.5] - new b: -81.0
# iteration 12; new weight_vector: [-4.  7.] - new b: -82.0
# iteration 12; new weight_vector: [  5.5  11.5] - new b: -81.0
# iteration 12; new weight_vector: [-1.  6.] - new b: -82.0
# iteration 12; new weight_vector: [  7.5  14.5] - new b: -81.0
# iteration 12; new weight_vector: [ 4.  8.] - new b: -82.0
# iteration 12; new weight_vector: [ 11.5  13.5] - new b: -81.0
# iteration 12; new weight_vector: [  5.  10.] - new b: -82.0
# iteration 12; new weight_vector: [ 0.5  2.5] - new b: -83.0
# iteration 12; new weight_vector: [ 9.  9.] - new b: -82.0
# iteration 12; new weight_vector: [ 2.5  5.5] - new b: -83.0
# iteration 12; new weight_vector: [  9.  14.] - new b: -82.0
# iteration 12; new weight_vector: [ 3.5  8.5] - new b: -83.0
# iteration 12; new weight_vector: [ 2. -1.] - new b: -84.0
# iteration 12; new weight_vector: [ 7.5  8.5] - new b: -83.0
# iteration 12; new weight_vector: [ 3.  1.] - new b: -84.0
# iteration 12; new weight_vector: [ 9.5  8.5] - new b: -83.0
# iteration 12; new weight_vector: [ 3.  6.] - new b: -84.0
# iteration 12; new weight_vector: [ 10.5  12.5] - new b: -83.0
# iteration 12; new weight_vector: [ 7.  7.] - new b: -84.0
# iteration 12; new weight_vector: [ 2.5 -0.5] - new b: -85.0
# iteration 12; new weight_vector: [ 9.  9.] - new b: -84.0
# iteration 12; new weight_vector: [ 0.5  5.5] - new b: -85.0
# iteration 12; new weight_vector: [  8.  15.] - new b: -84.0
# iteration 12; new weight_vector: [ -0.5  11.5] - new b: -85.0
# iteration 12; new weight_vector: [  7.  17.] - new b: -84.0
# iteration 12; new weight_vector: [  0.5  13.5] - new b: -85.0
# iteration 12; new weight_vector: [-3.  5.] - new b: -86.0
# iteration 12; new weight_vector: [  1.5  13.5] - new b: -85.0
# iteration 13; new weight_vector: [ 11.  18.] - new b: -84.0
# iteration 13; new weight_vector: [  6.5  14.5] - new b: -85.0
# iteration 13; new weight_vector: [ 0.  9.] - new b: -86.0
# iteration 13; new weight_vector: [  8.5  17.5] - new b: -85.0
# iteration 13; new weight_vector: [  5.  11.] - new b: -86.0
# iteration 13; new weight_vector: [ 0.5  3.5] - new b: -87.0
# iteration 13; new weight_vector: [  9.  10.] - new b: -86.0
# iteration 13; new weight_vector: [ 5.5  4.5] - new b: -87.0
# iteration 13; new weight_vector: [ 12.  13.] - new b: -86.0
# iteration 13; new weight_vector: [ 6.5  7.5] - new b: -87.0

# %% [markdown]
# As we can see, the weight vector and the bias ( which together determine the separating hyperplane ) are updated when $ y_i \cdot a $ is not positive.
#
# The result is nicely illustrated in this gif (reload if nothing if happening):
#
# <img src="https://github.com/taspinar/siml/raw/master/notebooks/img/perceptron.gif">
#
# We can extend this to a dataset in any number of dimensions, and as long as it is linearly separable, the Perceptron algorithm will converge.

# %% [markdown]
# <h2>2.3 Kernel Perceptrons:</h2>
#
# One of the benefits of this Perceptron is that it is a very 'lightweight' algorithm; it is computationally very fast and easy to implement for datasets which are linearly separable. But if the dataset is not linearly separable, it will not converge.
#
# For such datasets, the Perceptron can still be used if the correct kernel is applied. In practice this is never done, and Support Vector Machines are used whenever a Kernel needs to be applied. Some of these Kernels are:
# <table>
# <tbody>
# <tr>
# <td width="256">Linear:</td>
# <td width="256">$ < w, x > $</td>
# </tr>
# <tr>
# <td width="256">Polynomial:</td>
# <td width="256">$ (<w, x> + c)^d $ with $ c >= 0$</td>
# </tr>
# <tr>
# <td width="256">Laplacian RBF:</td>
# <td width="256">$ exp(-\lambda \  |\ w - x\ | ) $</td>
# </tr>
# <tr>
# <td width="256">Gaussian RBF:</td>
# <td width="256">$ exp(-\lambda \ |\ w - x\ |^2 ) $</td>
# </tr>
# </tbody>
# </table>
#
# For more information about Kernel functions, a comprehensive list of kernels, and their source code, please <a href="http://crsouza.com/2010/03/17/kernel-functions-for-machine-learning-applications/" target="_blank">click here</a>.
